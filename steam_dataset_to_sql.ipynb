# %%
import pandas as pd 
import json 
import mysql.connector  
import itertools 
import ast
from mysql.connector import errorcode

# %% [markdown]
# # Load clean Steam dataset

# %%
steam_dataset_1 = pd.read_csv("steam_dataset_clean_1.csv", compression='gzip')   
# steam_dataset_1['Release date'] = pd.to_datetime(steam_dataset_1['Release date'])
steam_dataset_1
# Out:
#          AppID                          Name Release date Estimated owners  \
# 0        20200  Alien Monster Bowling League   2008-10-21        0 - 20000
# 1       655370                  Train Bandit   2017-10-12        0 - 20000
# 2      1732930                  Jolt Project   2021-11-17        0 - 20000
# 3      1355720                      Henosis™   2020-07-23        0 - 20000
# 4      1139950         Two Weeks in Painland   2020-02-03        0 - 20000
# ...        ...                           ...          ...              ...
# 44615  1162700             Midnight Protocol   2021-10-13    20000 - 50000
# 44616   831810              Bane of Asphodel   2018-04-21    20000 - 50000
# 44617  1457600          Amazing Joes Journey   2021-01-05        0 - 20000
# 44618   958400                Project CARS 3   2020-08-27  200000 - 500000
# 44619   861540                Dicey Dungeons   2019-08-13  200000 - 500000
#
#        Required age  Price                                     About the game  \
# 0                 0  19.99  Galactic Bowling is an exaggerated and stylize...
# 1                 0   0.99  THE LAW!! Looks to be a showdown atop a train....
# 2                 0   4.99  Jolt Project: The army now has a new robotics ...
# 3                 0   5.99  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 4                 0   0.00  ABOUT THE GAME Play as a hacker who has arrang...
# ...             ...    ...                                                ...
# 44615             0  14.99  You assume the mantle of a prominent hacktivis...
# 44616             0   0.00  Bane of Asphodel is an Action-Adventure Game s...
# 44617             0   0.99  Amazing Joe's Journey is a simple point &amp; ...
# 44618             0  59.99  OWN YOUR JOURNEY • 200+ elite-brand race &amp;...
# 44619             0  14.99  Become a giant walking dice and battle to the ...
#
#                                      Supported languages  \
# 0                                            ['English']
# 1      ['English', 'French', 'Italian', 'German', 'Sp...
# 2                     ['English', 'Portuguese - Brazil']
# 3      ['English', 'French', 'Italian', 'German', 'Sp...
# 4                         ['English', 'Spanish - Spain']
# ...                                                  ...
# 44615  ['English', 'German', 'Russian', 'Simplified C...
# 44616                                        ['English']
# 44617                              ['English', 'Polish']
# 44618  ['English', 'French', 'Italian', 'German', 'Sp...
# 44619  ['English', 'Simplified Chinese', 'Korean', 'G...
#
#                          Full audio languages  \
# 0                                          []
# 1                                          []
# 2                                          []
# 3                                          []
# 4                                          []
# ...                                       ...
# 44615                                      []
# 44616                                      []
# 44617                                      []
# 44618  ['English', 'Spanish - Latin America']
# 44619                                      []
#
#                                                  Reviews  ... Recommendations  \
# 0                                                     []  ...               0
# 1                                                     []  ...               0
# 2                                                     []  ...               0
# 3                                                     []  ...               0
# 4                                                     []  ...               0
# ...                                                  ...  ...             ...
# 44615  ['If the movie Hackers has left a lasting impr...  ...             131
# 44616                                                 []  ...               0
# 44617                                                 []  ...               0
# 44618                                                 []  ...            1767
# 44619  ['There are enough ideas here for three whole ...  ...            7394
#
#                                                    Notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      This Game may contain content not appropriate ...
# ...                                                  ...
# 44615  The game narrative refers to computer hacking ...
# 44616                                                NaN
# 44617                                                NaN
# 44618                                                NaN
# 44619                                                NaN
#
#       Average playtime forever             Developers  \
# 0                            0  Perpetual FX Creative
# 1                            0           Rusty Moyher
# 2                            0                    NaN
# 3                            0      Odd Critter Games
# 4                            0          Unusual Games
# ...                        ...                    ...
# 44615                       93          LuGus Studios
# 44616                        0                    NaN
# 44617                        0                    NaN
# 44618                      546   Slightly Mad Studios
# 44619                      622         Terry Cavanagh
#
#                        Publishers  \
# 0           Perpetual FX Creative
# 1                    Wild Rooster
# 2                             NaN
# 3               Odd Critter Games
# 4                   Unusual Games
# ...                           ...
# 44615         Iceberg Interactive
# 44616                         NaN
# 44617                         NaN
# 44618  BANDAI NAMCO Entertainment
# 44619              Terry Cavanagh
#
#                                               Categories  \
# 0      ['Single-player', 'Multi-player', 'Steam Achie...
# 1      ['Single-player', 'Steam Achievements', 'Full ...
# 2                                      ['Single-player']
# 3           ['Single-player', 'Full controller support']
# 4                ['Single-player', 'Steam Achievements']
# ...                                                  ...
# 44615  ['Single-player', 'Steam Achievements', 'Steam...
# 44616    ['Single-player', 'Partial Controller Support']
# 44617                                  ['Single-player']
# 44618  ['Single-player', 'Multi-player', 'PvP', 'Onli...
# 44619  ['Single-player', 'Steam Achievements', 'Full ...
#
#                                                  Genres  \
# 0                         ['Casual', 'Indie', 'Sports']
# 1                                   ['Action', 'Indie']
# 2          ['Action', 'Adventure', 'Indie', 'Strategy']
# 3                      ['Adventure', 'Casual', 'Indie']
# 4                                ['Adventure', 'Indie']
# ...                                                 ...
# 44615            ['Action', 'Indie', 'RPG', 'Strategy']
# 44616  ['Action', 'Adventure', 'Free to Play', 'Indie']
# 44617                            ['Adventure', 'Indie']
# 44618                                        ['Racing']
# 44619                             ['Indie', 'Strategy']
#
#                                                     Tags  \
# 0               ['Indie', 'Casual', 'Sports', 'Bowling']
# 1      ['Indie', 'Action', 'Pixel Graphics', '2D', 'R...
# 2                                                     []
# 3      ['2D Platformer', 'Atmospheric', 'Surreal', 'M...
# 4      ['Indie', 'Adventure', 'Nudity', 'Violent', 'S...
# ...                                                  ...
# 44615  ['Singleplayer', 'Hacking', 'Typing', 'Story R...
# 44616  ['Indie', 'Action', 'Adventure', 'Free to Play...
# 44617                                                 []
# 44618  ['Racing', 'Arcade', 'Action', 'Sports', 'Auto...
# 44619  ['Roguelike Deckbuilder', 'Card Battler', 'Dec...
#
#                                              Screenshots  \
# 0      ['https://cdn.akamai.steamstatic.com/steam/app...
# 1      ['https://cdn.akamai.steamstatic.com/steam/app...
# 2      ['https://cdn.akamai.steamstatic.com/steam/app...
# 3      ['https://cdn.akamai.steamstatic.com/steam/app...
# 4      ['https://cdn.akamai.steamstatic.com/steam/app...
# ...                                                  ...
# 44615  ['https://cdn.akamai.steamstatic.com/steam/app...
# 44616  ['https://cdn.akamai.steamstatic.com/steam/app...
# 44617  ['https://cdn.akamai.steamstatic.com/steam/app...
# 44618  ['https://cdn.akamai.steamstatic.com/steam/app...
# 44619  ['https://cdn.akamai.steamstatic.com/steam/app...
#
#                                                   Movies
# 0      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 1      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 2      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 3      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 4      ['http://cdn.akamai.steamstatic.com/steam/apps...
# ...                                                  ...
# 44615  ['http://cdn.akamai.steamstatic.com/steam/apps...
# 44616  ['http://cdn.akamai.steamstatic.com/steam/apps...
# 44617  ['http://cdn.akamai.steamstatic.com/steam/apps...
# 44618  ['http://cdn.akamai.steamstatic.com/steam/apps...
# 44619  ['http://cdn.akamai.steamstatic.com/steam/apps...
#
# [44620 rows x 33 columns]

# %%
steam_dataset_2 = pd.read_csv("steam_dataset_clean_2.csv", compression='gzip')   
# steam_dataset_2['Release date'] = pd.to_datetime(steam_dataset_2['Release date'])
steam_dataset_2
# Out:
#          AppID                              Name Release date  \
# 0      1812840            The Labyrinth of Greed   2021-11-29
# 1       458700                  Cursor Challenge   2016-04-05
# 2       237740  Angry Video Game Nerd Adventures   2013-09-20
# 3         6080      Thrillville®: Off the Rails™   2009-07-08
# 4       620700                   EVIL POSSESSION   2017-05-16
# ...        ...                               ...          ...
# 44613  3593600                      Starry Trace   2025-04-14
# 44614  3600970                   Paragon Of Time   2025-04-10
# 44615  3543710           A Few Days With : Hazel   2025-04-11
# 44616  3265370                          MosGhost   2025-04-01
# 44617  3183790            Defense Of Fort Burton   2025-04-10
#
#       Estimated owners  Required age  Price  \
# 0        20000 - 50000             0  12.99
# 1            0 - 20000             0   0.99
# 2      100000 - 200000             0   4.99
# 3        20000 - 50000             0   9.99
# 4            0 - 20000             0   0.00
# ...                ...           ...    ...
# 44613        0 - 20000             0   1.21
# 44614        0 - 20000             0   2.99
# 44615        0 - 20000             0   2.69
# 44616        0 - 20000             0   7.99
# 44617        0 - 20000             0   9.99
#
#                                           About the game  \
# 0      In The labyrinth of greed you have to play as ...
# 1      Do you want to test your SKILLS and your REFLE...
# 2      'The most rewarding game of 2013!' Influenced ...
# 3      Thrillville™: Off the Rails lives up to its na...
# 4      SURVIVAL HORROR in first person. We incarnate ...
# ...                                                  ...
# 44613  Welcome to Starry Trace ! A relaxing yet brain...
# 44614  You stand at the edge of time, trying to save ...
# 44615  Join Hazel, an attractive young lady, and enjo...
# 44616  Story : Andrei moved to Moscow for work and re...
# 44617  Face series of battles defending the good peop...
#
#                                      Supported languages  \
# 0                                            ['English']
# 1                                            ['English']
# 2                                            ['English']
# 3      ['English', 'French', 'German', 'Italian', 'Sp...
# 4      ['English', 'German', 'Spanish - Spain', 'Simp...
# ...                                                  ...
# 44613  ['English', 'Japanese', 'Simplified Chinese', ...
# 44614                                        ['English']
# 44615  ['English', 'French', 'Italian', 'German', 'Sp...
# 44616  ['English', 'Russian', 'French', 'Italian', 'G...
# 44617                                        ['English']
#
#                                     Full audio languages Reviews  ...  \
# 0                                            ['English']      []  ...
# 1                                                     []      []  ...
# 2                                            ['English']      []  ...
# 3      ['English', 'French', 'German', 'Italian', 'Sp...      []  ...
# 4                                  ['English', 'French']      []  ...
# ...                                                  ...     ...  ...
# 44613                                                 []      []  ...
# 44614                                                 []      []  ...
# 44615                                                 []      []  ...
# 44616                                                 []      []  ...
# 44617                                        ['English']      []  ...
#
#       Recommendations                                              Notes  \
# 0                   0                                                NaN
# 1                   0                                                NaN
# 2                2543                                                NaN
# 3                 552                                                NaN
# 4                   0                                                NaN
# ...               ...                                                ...
# 44613               0                                                NaN
# 44614               0                                                NaN
# 44615               0  The mature content is exclusively female nudit...
# 44616               0                                                NaN
# 44617               0                                                NaN
#
#       Average playtime forever       Developers        Publishers  \
# 0                            0              NaN    Gigantum Games
# 1                           23  Insane Dreamers   Insane Dreamers
# 2                          107  FreakZone Games  Screenwave Media
# 3                          701         Frontier         LucasArts
# 4                            0              NaN               NaN
# ...                        ...              ...               ...
# 44613                        0              NaN               NaN
# 44614                        0              NaN               NaN
# 44615                        0     Hentai Panda      Hentai Panda
# 44616                        0              NaN               NaN
# 44617                        0  Ledx Fun Studio   Ledx Fun Studio
#
#                                               Categories  \
# 0                                      ['Single-player']
# 1      ['Single-player', 'Co-op', 'Steam Trading Cards']
# 2      ['Single-player', 'Steam Achievements', 'Full ...
# 3      ['Single-player', 'Multi-player', 'PvP', 'Shar...
# 4      ['Single-player', 'Steam Achievements', 'Full ...
# ...                                                  ...
# 44613  ['Single-player', 'Steam Achievements', 'Full ...
# 44614  ['Single-player', 'Full controller support', '...
# 44615  ['Single-player', 'Steam Achievements', 'Steam...
# 44616                ['Single-player', 'Family Sharing']
# 44617  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                                   Genres  \
# 0                                 ['Adventure', 'Indie']
# 1                                    ['Casual', 'Indie']
# 2                       ['Action', 'Adventure', 'Indie']
# 3      ['Action', 'Adventure', 'Racing', 'Simulation'...
# 4                       ['Action', 'Adventure', 'Indie']
# ...                                                  ...
# 44613                    ['Casual', 'Indie', 'Strategy']
# 44614                      ['Action', 'Casual', 'Indie']
# 44615                                ['Casual', 'Indie']
# 44616                                     ['Simulation']
# 44617   ['Action', 'Casual', 'Strategy', 'Early Access']
#
#                                                     Tags  \
# 0      ['Adventure', 'Puzzle', 'Arcade', '2D', 'Voxel...
# 1      ['Casual', 'Indie', '2D', 'Action', 'Co-op', '...
# 2      ['Platformer', 'Indie', 'Action', 'Difficult',...
# 3      ['Simulation', 'Adventure', 'Strategy', 'Actio...
# 4      ['Indie', 'Adventure', 'Action', 'Horror', 'Su...
# ...                                                  ...
# 44613  ['Casual', 'Strategy', 'Puzzle', 'Relaxing', '...
# 44614  ['Action Roguelike', 'Bullet Hell', 'Hack and ...
# 44615                                                 []
# 44616  ['Simulation', 'Walking Simulator', 'Idler', '...
# 44617                                                 []
#
#                                              Screenshots  \
# 0      ['https://cdn.akamai.steamstatic.com/steam/app...
# 1      ['https://cdn.akamai.steamstatic.com/steam/app...
# 2      ['https://cdn.akamai.steamstatic.com/steam/app...
# 3      ['https://cdn.akamai.steamstatic.com/steam/app...
# 4      ['https://cdn.akamai.steamstatic.com/steam/app...
# ...                                                  ...
# 44613  ['https://shared.akamai.steamstatic.com/store_...
# 44614  ['https://shared.akamai.steamstatic.com/store_...
# 44615  ['https://shared.akamai.steamstatic.com/store_...
# 44616  ['https://shared.akamai.steamstatic.com/store_...
# 44617  ['https://shared.akamai.steamstatic.com/store_...
#
#                                                   Movies
# 0      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 1      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 2      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 3      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 4      ['http://cdn.akamai.steamstatic.com/steam/apps...
# ...                                                  ...
# 44613  ['http://video.akamai.steamstatic.com/store_tr...
# 44614  ['http://video.akamai.steamstatic.com/store_tr...
# 44615  ['http://video.akamai.steamstatic.com/store_tr...
# 44616  ['http://video.akamai.steamstatic.com/store_tr...
# 44617  ['http://video.akamai.steamstatic.com/store_tr...
#
# [44618 rows x 33 columns]

# %%
steam_dataset = pd.concat([steam_dataset_1, steam_dataset_2]) 
steam_dataset
# Out:
#          AppID                          Name Release date Estimated owners  \
# 0        20200  Alien Monster Bowling League   2008-10-21        0 - 20000
# 1       655370                  Train Bandit   2017-10-12        0 - 20000
# 2      1732930                  Jolt Project   2021-11-17        0 - 20000
# 3      1355720                      Henosis™   2020-07-23        0 - 20000
# 4      1139950         Two Weeks in Painland   2020-02-03        0 - 20000
# ...        ...                           ...          ...              ...
# 44613  3593600                  Starry Trace   2025-04-14        0 - 20000
# 44614  3600970               Paragon Of Time   2025-04-10        0 - 20000
# 44615  3543710       A Few Days With : Hazel   2025-04-11        0 - 20000
# 44616  3265370                      MosGhost   2025-04-01        0 - 20000
# 44617  3183790        Defense Of Fort Burton   2025-04-10        0 - 20000
#
#        Required age  Price                                     About the game  \
# 0                 0  19.99  Galactic Bowling is an exaggerated and stylize...
# 1                 0   0.99  THE LAW!! Looks to be a showdown atop a train....
# 2                 0   4.99  Jolt Project: The army now has a new robotics ...
# 3                 0   5.99  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 4                 0   0.00  ABOUT THE GAME Play as a hacker who has arrang...
# ...             ...    ...                                                ...
# 44613             0   1.21  Welcome to Starry Trace ! A relaxing yet brain...
# 44614             0   2.99  You stand at the edge of time, trying to save ...
# 44615             0   2.69  Join Hazel, an attractive young lady, and enjo...
# 44616             0   7.99  Story : Andrei moved to Moscow for work and re...
# 44617             0   9.99  Face series of battles defending the good peop...
#
#                                      Supported languages Full audio languages  \
# 0                                            ['English']                   []
# 1      ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 2                     ['English', 'Portuguese - Brazil']                   []
# 3      ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 4                         ['English', 'Spanish - Spain']                   []
# ...                                                  ...                  ...
# 44613  ['English', 'Japanese', 'Simplified Chinese', ...                   []
# 44614                                        ['English']                   []
# 44615  ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 44616  ['English', 'Russian', 'French', 'Italian', 'G...                   []
# 44617                                        ['English']          ['English']
#
#       Reviews  ... Recommendations  \
# 0          []  ...               0
# 1          []  ...               0
# 2          []  ...               0
# 3          []  ...               0
# 4          []  ...               0
# ...       ...  ...             ...
# 44613      []  ...               0
# 44614      []  ...               0
# 44615      []  ...               0
# 44616      []  ...               0
# 44617      []  ...               0
#
#                                                    Notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      This Game may contain content not appropriate ...
# ...                                                  ...
# 44613                                                NaN
# 44614                                                NaN
# 44615  The mature content is exclusively female nudit...
# 44616                                                NaN
# 44617                                                NaN
#
#       Average playtime forever             Developers             Publishers  \
# 0                            0  Perpetual FX Creative  Perpetual FX Creative
# 1                            0           Rusty Moyher           Wild Rooster
# 2                            0                    NaN                    NaN
# 3                            0      Odd Critter Games      Odd Critter Games
# 4                            0          Unusual Games          Unusual Games
# ...                        ...                    ...                    ...
# 44613                        0                    NaN                    NaN
# 44614                        0                    NaN                    NaN
# 44615                        0           Hentai Panda           Hentai Panda
# 44616                        0                    NaN                    NaN
# 44617                        0        Ledx Fun Studio        Ledx Fun Studio
#
#                                               Categories  \
# 0      ['Single-player', 'Multi-player', 'Steam Achie...
# 1      ['Single-player', 'Steam Achievements', 'Full ...
# 2                                      ['Single-player']
# 3           ['Single-player', 'Full controller support']
# 4                ['Single-player', 'Steam Achievements']
# ...                                                  ...
# 44613  ['Single-player', 'Steam Achievements', 'Full ...
# 44614  ['Single-player', 'Full controller support', '...
# 44615  ['Single-player', 'Steam Achievements', 'Steam...
# 44616                ['Single-player', 'Family Sharing']
# 44617  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                                  Genres  \
# 0                         ['Casual', 'Indie', 'Sports']
# 1                                   ['Action', 'Indie']
# 2          ['Action', 'Adventure', 'Indie', 'Strategy']
# 3                      ['Adventure', 'Casual', 'Indie']
# 4                                ['Adventure', 'Indie']
# ...                                                 ...
# 44613                   ['Casual', 'Indie', 'Strategy']
# 44614                     ['Action', 'Casual', 'Indie']
# 44615                               ['Casual', 'Indie']
# 44616                                    ['Simulation']
# 44617  ['Action', 'Casual', 'Strategy', 'Early Access']
#
#                                                     Tags  \
# 0               ['Indie', 'Casual', 'Sports', 'Bowling']
# 1      ['Indie', 'Action', 'Pixel Graphics', '2D', 'R...
# 2                                                     []
# 3      ['2D Platformer', 'Atmospheric', 'Surreal', 'M...
# 4      ['Indie', 'Adventure', 'Nudity', 'Violent', 'S...
# ...                                                  ...
# 44613  ['Casual', 'Strategy', 'Puzzle', 'Relaxing', '...
# 44614  ['Action Roguelike', 'Bullet Hell', 'Hack and ...
# 44615                                                 []
# 44616  ['Simulation', 'Walking Simulator', 'Idler', '...
# 44617                                                 []
#
#                                              Screenshots  \
# 0      ['https://cdn.akamai.steamstatic.com/steam/app...
# 1      ['https://cdn.akamai.steamstatic.com/steam/app...
# 2      ['https://cdn.akamai.steamstatic.com/steam/app...
# 3      ['https://cdn.akamai.steamstatic.com/steam/app...
# 4      ['https://cdn.akamai.steamstatic.com/steam/app...
# ...                                                  ...
# 44613  ['https://shared.akamai.steamstatic.com/store_...
# 44614  ['https://shared.akamai.steamstatic.com/store_...
# 44615  ['https://shared.akamai.steamstatic.com/store_...
# 44616  ['https://shared.akamai.steamstatic.com/store_...
# 44617  ['https://shared.akamai.steamstatic.com/store_...
#
#                                                   Movies
# 0      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 1      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 2      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 3      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 4      ['http://cdn.akamai.steamstatic.com/steam/apps...
# ...                                                  ...
# 44613  ['http://video.akamai.steamstatic.com/store_tr...
# 44614  ['http://video.akamai.steamstatic.com/store_tr...
# 44615  ['http://video.akamai.steamstatic.com/store_tr...
# 44616  ['http://video.akamai.steamstatic.com/store_tr...
# 44617  ['http://video.akamai.steamstatic.com/store_tr...
#
# [89238 rows x 33 columns]

# %%
steam_dataset.fillna('', inplace = True) 
steam_dataset
# Out:
#          AppID                          Name Release date Estimated owners  \
# 0        20200  Alien Monster Bowling League   2008-10-21        0 - 20000
# 1       655370                  Train Bandit   2017-10-12        0 - 20000
# 2      1732930                  Jolt Project   2021-11-17        0 - 20000
# 3      1355720                      Henosis™   2020-07-23        0 - 20000
# 4      1139950         Two Weeks in Painland   2020-02-03        0 - 20000
# ...        ...                           ...          ...              ...
# 44613  3593600                  Starry Trace   2025-04-14        0 - 20000
# 44614  3600970               Paragon Of Time   2025-04-10        0 - 20000
# 44615  3543710       A Few Days With : Hazel   2025-04-11        0 - 20000
# 44616  3265370                      MosGhost   2025-04-01        0 - 20000
# 44617  3183790        Defense Of Fort Burton   2025-04-10        0 - 20000
#
#        Required age  Price                                     About the game  \
# 0                 0  19.99  Galactic Bowling is an exaggerated and stylize...
# 1                 0   0.99  THE LAW!! Looks to be a showdown atop a train....
# 2                 0   4.99  Jolt Project: The army now has a new robotics ...
# 3                 0   5.99  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 4                 0   0.00  ABOUT THE GAME Play as a hacker who has arrang...
# ...             ...    ...                                                ...
# 44613             0   1.21  Welcome to Starry Trace ! A relaxing yet brain...
# 44614             0   2.99  You stand at the edge of time, trying to save ...
# 44615             0   2.69  Join Hazel, an attractive young lady, and enjo...
# 44616             0   7.99  Story : Andrei moved to Moscow for work and re...
# 44617             0   9.99  Face series of battles defending the good peop...
#
#                                      Supported languages Full audio languages  \
# 0                                            ['English']                   []
# 1      ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 2                     ['English', 'Portuguese - Brazil']                   []
# 3      ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 4                         ['English', 'Spanish - Spain']                   []
# ...                                                  ...                  ...
# 44613  ['English', 'Japanese', 'Simplified Chinese', ...                   []
# 44614                                        ['English']                   []
# 44615  ['English', 'French', 'Italian', 'German', 'Sp...                   []
# 44616  ['English', 'Russian', 'French', 'Italian', 'G...                   []
# 44617                                        ['English']          ['English']
#
#       Reviews  ... Recommendations  \
# 0          []  ...               0
# 1          []  ...               0
# 2          []  ...               0
# 3          []  ...               0
# 4          []  ...               0
# ...       ...  ...             ...
# 44613      []  ...               0
# 44614      []  ...               0
# 44615      []  ...               0
# 44616      []  ...               0
# 44617      []  ...               0
#
#                                                    Notes  \
# 0
# 1
# 2
# 3
# 4      This Game may contain content not appropriate ...
# ...                                                  ...
# 44613
# 44614
# 44615  The mature content is exclusively female nudit...
# 44616
# 44617
#
#       Average playtime forever             Developers             Publishers  \
# 0                            0  Perpetual FX Creative  Perpetual FX Creative
# 1                            0           Rusty Moyher           Wild Rooster
# 2                            0
# 3                            0      Odd Critter Games      Odd Critter Games
# 4                            0          Unusual Games          Unusual Games
# ...                        ...                    ...                    ...
# 44613                        0
# 44614                        0
# 44615                        0           Hentai Panda           Hentai Panda
# 44616                        0
# 44617                        0        Ledx Fun Studio        Ledx Fun Studio
#
#                                               Categories  \
# 0      ['Single-player', 'Multi-player', 'Steam Achie...
# 1      ['Single-player', 'Steam Achievements', 'Full ...
# 2                                      ['Single-player']
# 3           ['Single-player', 'Full controller support']
# 4                ['Single-player', 'Steam Achievements']
# ...                                                  ...
# 44613  ['Single-player', 'Steam Achievements', 'Full ...
# 44614  ['Single-player', 'Full controller support', '...
# 44615  ['Single-player', 'Steam Achievements', 'Steam...
# 44616                ['Single-player', 'Family Sharing']
# 44617  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                                  Genres  \
# 0                         ['Casual', 'Indie', 'Sports']
# 1                                   ['Action', 'Indie']
# 2          ['Action', 'Adventure', 'Indie', 'Strategy']
# 3                      ['Adventure', 'Casual', 'Indie']
# 4                                ['Adventure', 'Indie']
# ...                                                 ...
# 44613                   ['Casual', 'Indie', 'Strategy']
# 44614                     ['Action', 'Casual', 'Indie']
# 44615                               ['Casual', 'Indie']
# 44616                                    ['Simulation']
# 44617  ['Action', 'Casual', 'Strategy', 'Early Access']
#
#                                                     Tags  \
# 0               ['Indie', 'Casual', 'Sports', 'Bowling']
# 1      ['Indie', 'Action', 'Pixel Graphics', '2D', 'R...
# 2                                                     []
# 3      ['2D Platformer', 'Atmospheric', 'Surreal', 'M...
# 4      ['Indie', 'Adventure', 'Nudity', 'Violent', 'S...
# ...                                                  ...
# 44613  ['Casual', 'Strategy', 'Puzzle', 'Relaxing', '...
# 44614  ['Action Roguelike', 'Bullet Hell', 'Hack and ...
# 44615                                                 []
# 44616  ['Simulation', 'Walking Simulator', 'Idler', '...
# 44617                                                 []
#
#                                              Screenshots  \
# 0      ['https://cdn.akamai.steamstatic.com/steam/app...
# 1      ['https://cdn.akamai.steamstatic.com/steam/app...
# 2      ['https://cdn.akamai.steamstatic.com/steam/app...
# 3      ['https://cdn.akamai.steamstatic.com/steam/app...
# 4      ['https://cdn.akamai.steamstatic.com/steam/app...
# ...                                                  ...
# 44613  ['https://shared.akamai.steamstatic.com/store_...
# 44614  ['https://shared.akamai.steamstatic.com/store_...
# 44615  ['https://shared.akamai.steamstatic.com/store_...
# 44616  ['https://shared.akamai.steamstatic.com/store_...
# 44617  ['https://shared.akamai.steamstatic.com/store_...
#
#                                                   Movies
# 0      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 1      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 2      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 3      ['http://cdn.akamai.steamstatic.com/steam/apps...
# 4      ['http://cdn.akamai.steamstatic.com/steam/apps...
# ...                                                  ...
# 44613  ['http://video.akamai.steamstatic.com/store_tr...
# 44614  ['http://video.akamai.steamstatic.com/store_tr...
# 44615  ['http://video.akamai.steamstatic.com/store_tr...
# 44616  ['http://video.akamai.steamstatic.com/store_tr...
# 44617  ['http://video.akamai.steamstatic.com/store_tr...
#
# [89238 rows x 33 columns]

# %% [markdown]
# # Connect to MySQL

# %%
def get_sql_connection():
  credentials_file = "credentials.json" 

  with open(credentials_file, "r") as f: 
      credentials = json.load(f) 
      sql_credential = credentials.get("sql")
      database = sql_credential.get("database")
      password = sql_credential.get("password") 


  mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = password, 
    database = database
  )  

  if mydb: 
     print("Connection to database success")
     
  return mydb   
   
def check_sql_connection(db_connection):
    # If connection is open and alive 
    # https://stackoverflow.com/questions/33239480/how-to-check-if-a-mysql-connection-is-open-in-python
    if db_connection.is_connected():
        return db_connection 
    
    # else reconnect to database
    else:
        print("Connection closed. Reconnecting to database")
        return get_sql_connection()

# %%
mydb = get_sql_connection() 
cursor = mydb.cursor()
# Out:
# Connection to database success

# %% [markdown]
# # Create Database Table

# %% [markdown]
# Column Information
# 1. **AppID**: unique identifier for the game
# 2. **Name**: the name of the game
# 3. **Release date**: when the game was released
# 4. **Estimated owners**: estimated owners who own the game
# 5. **Peak CCU**: number of concurrent users, yesterday
# 6. **Required age**: age required to play (0 if for all audiences)
# 7. **Price**: price of game in USD (0.0 if free)
# 8. **DiscountDLC count**: number of DLC the game has (0 if none)
# 9. **About the game**: a detailed description of the game
# 10. **Supported languages**: comma-separated enumeration of supporting languages
# 11. **Full audio languages**: comma-separated enumeration of languages with audio support
# 12. **Reviews**: users’ reviews about the game
# 13. **Header image**: Header image URL in the Steam store
# 14. **Website**: game website
# 15. **Support URL**: game support team URL
# 16. **Support email**: game support team email
# 17. **Windows**: if the game is supported on Windows
# 18. **Mac**: if the game is supported on Mac
# 19. **Linux**: if the game is supported on Linux
# 20. **Metacritic score**: weighted average of reviews from professional critics and publications (the higher the better, plus you don’t need to own the game to score)
# 21. **Metacritic URL**: URL that aggregates reviews for the game, determining the Metacritic score (if no score, empty)
# 22. **User score**: ratio of positive to negative reviews and usually categorized in semantic buckets like ‘Overwhelmingly positive’, ‘Very positive’, and such (0 if there are no scores for the game, and is according to the SteamSpy website)
# 23. **Positive**: positive votes that users give to the game (0 if no information, and comes from SteamSpy)
# 24. **Negative**: negative votes that users give to the game (0 if no information, and comes from SteamSpy)
# 25. **Score rank**: score rank of the game based on user reviews
# 26. **Achievements**: number of achievements in the game (0 if none)
# 27. **Recommendations**: users’ recommendations about the game (0 if none)
# 28. **Notes**: extra information about the game content
# 29. **Average playtime forever**: average playtime of the player base who owns the games in minutes
# 30. **Average playtime two weeks**: average playtime of the player base who owns the games in minutes during the last two weeks
# 31. **Median playtime forever**: median playtime of the player base who owns the games in minutes
# 32. **Median playtime two weeks**: median playtime of the player base who owns the games in minutes during the last two weeks
# 33. **Developers**: the company that developed the game
# 34. **Publishers**: the company that published the game
# 35. **Categories**: list of categories that the game belongs to
# 36. **Genres**: list of genres that the game belongs to
# 37. **Tags**: labels that help users and developers categorize and discover games on the Steam platform
# 38. **Screenshots**: screenshot/snippets of the game
# 39. **Movies**: videos of what the game is about

# %% [markdown]
# ## Create Core Tables

# %%
# https://dev.mysql.com/doc/connector-python/en/connector-python-example-ddl.html  
core_table = {} 

core_table['games'] = """
CREATE TABLE games ( 
    game_id INT AUTO_INCREMENT PRIMARY KEY, 
    app_id INT UNIQUE,
    name TEXT, 
    date_released DATE,  
    required_age INT, 
    price DECIMAL(10, 2), 
    description TEXT, 
    achievements INT
);
"""

core_table['game_extra_info'] = """ 
CREATE TABLE game_extra_info ( 
    app_id INT PRIMARY KEY, 
    estimated_owners VARCHAR(50),   
    extra_description TEXT, 
    avg_playtime_mins INT,  
    header_image TEXT, 
    website TEXT,  
    support_url TEXT, 
    support_email TEXT, 
    window_supported BOOLEAN, 
    mac_supported BOOLEAN, 
    linux_supported BOOLEAN
); 
""" 

core_table['game_review'] = """ 
CREATE TABLE game_review (  
    app_id INT PRIMARY KEY, 
    reviews TEXT, 
    metacritic_score INT, 
    metacritic_url TEXT, 
    positive_vote INT, 
    negative_vote INT, 
    recommendations INT
);
""" 

core_table['companies'] = """ 
CREATE TABLE companies ( 
    company_id INT AUTO_INCREMENT PRIMARY KEY,  
    name VARCHAR(255) UNIQUE
);
"""  

core_table['languages'] = """ 
CREATE TABLE languages ( 
    language_id INT AUTO_INCREMENT PRIMARY KEY, 
    name VARCHAR(255) UNIQUE
);
""" 

core_table['categories'] = """ 
CREATE TABLE categories ( 
    category_id INT AUTO_INCREMENT PRIMARY KEY, 
    name VARCHAR(255) UNIQUE
); 
"""  

core_table['genres'] = """ 
CREATE TABLE genres ( 
    genre_id INT AUTO_INCREMENT PRIMARY KEY, 
    name VARCHAR(255) UNIQUE
);
""" 

core_table['tags'] = """ 
CREATE TABLE tags ( 
    tag_id INT AUTO_INCREMENT PRIMARY KEY, 
    name VARCHAR(100) UNIQUE
);
"""  

core_table['screenshots'] = """ 
CREATE TABLE IF NOT EXISTS game_screenshots ( 
    screenshot_id INT AUTO_INCREMENT PRIMARY KEY,
    app_id INT,
    screenshot_url VARCHAR(500),
    UNIQUE KEY unique_app_screenshot (app_id, screenshot_url)
);
""" 

core_table['movies'] = """ 
CREATE TABLE IF NOT EXISTS game_movies ( 
    movie_id INT AUTO_INCREMENT PRIMARY KEY,
    app_id INT,
    movie_url VARCHAR(500),
    UNIQUE KEY unique_app_movie (app_id, movie_url)
);
"""

# %%
for table_name, table_description in core_table.items():
    try:
        print(f"Creating table {table_name}")
        cursor.execute(table_description) 
        print("Created successfully \n")
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("Already exists \n")
        else:
            print(err.msg, "\n")
# Out:
# Creating table games
# Already exists
#
# Creating table game_extra_info
# Already exists
#
# Creating table game_review
# Already exists
#
# Creating table companies
# Already exists
#
# Creating table languages
# Already exists
#
# Creating table categories
# Already exists
#
# Creating table genres
# Already exists
#
# Creating table tags
# Already exists
#
# Creating table screenshots
# Created successfully
#
# Creating table movies
# Created successfully

# %% [markdown]
# ## Create Relational Tables

# %%
relational_table = {}  

relational_table['game_developer_publisher'] = """
CREATE TABLE game_developer_publisher (  
    app_id INT, 
    developer_id INT, 
    publisher_id INT,
    PRIMARY KEY (app_id),
    FOREIGN KEY (developer_id) REFERENCES companies(company_id),
    FOREIGN KEY (publisher_id) REFERENCES companies(company_id)
);
""" 

relational_table['game_languages'] = """
CREATE TABLE game_languages (  
    app_id INT, 
    supported_language_id INT,
    audio_language_id INT,
    FOREIGN KEY (supported_language_id) REFERENCES languages(language_id),
    FOREIGN KEY (audio_language_id) REFERENCES languages(language_id)
);
"""  

relational_table['game_categories'] = """
CREATE TABLE game_categories (  
    app_id INT, 
    category_id INT,
    PRIMARY KEY (app_id, category_id),
    FOREIGN KEY (category_id) REFERENCES categories(category_id)
);
"""   

relational_table['game_genres'] = """
CREATE TABLE game_genres (  
    app_id INT, 
    genre_id INT,
    PRIMARY KEY (app_id, genre_id),
    FOREIGN KEY (genre_id) REFERENCES genres(genre_id)
);
"""   

relational_table['game_tags'] = """
CREATE TABLE IF NOT EXISTS game_tags (  
    app_id INT, 
    tag_id INT,
    PRIMARY KEY (app_id, tag_id),
    FOREIGN KEY (tag_id) REFERENCES tags(tag_id)
);
"""

# %%
for table_name, table_description in relational_table.items():
    try:
        print(f"Creating table {table_name}")
        cursor.execute(table_description) 
        print("Created successfully \n")
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("Already exists \n")
        else:
            print(err.msg, "\n")
# Out:
# Creating table game_developer_publisher
# Already exists
#
# Creating table game_languages
# Already exists
#
# Creating table game_categories
# Already exists
#
# Creating table game_genres
# Already exists
#
# Creating table game_tags
# Created successfully

# %% [markdown]
# ## Verify tables are created

# %%
# https://www.geeksforgeeks.org/python/how-to-show-all-tables-in-mysql-using-python/# 
cursor.execute("show tables") 
result = cursor.fetchall()

for table in result:
    print(table)
# Out:
# ('categories',)
# ('companies',)
# ('game_categories',)
# ('game_developer_publisher',)
# ('game_extra_info',)
# ('game_genres',)
# ('game_languages',)
# ('game_movies',)
# ('game_review',)
# ('game_screenshots',)
# ('game_tags',)
# ('games',)
# ('genres',)
# ('languages',)
# ('tags',)

# %% [markdown]
# # Insert Data to Database Table

# %% [markdown]
# ## Core Table

# %% [markdown]
# In each of the core table, I converted them into an array of tuples so that I can perform batch insert into MySQL to speed up the process

# %%
def insert_all_data_verification (mydb, table_name, data): 
    try:  
        mydb = check_sql_connection(mydb)  
        cursor = mydb.cursor() 
        
        select_query = f"SELECT COUNT(*) FROM {table_name}"  
        cursor.execute(select_query)  
        result = cursor.fetchone()
        data_count = result[0] 

        if (data_count == len(data)): 
            print(f"All data was inserted successfully: {data_count} out of {len(data)}") 
        else: 
            print(f"Not all data was inserted successfully: {data_count} out of {len(data)}") 
    
    except Exception as e: 
        print(f"Error has occured: {e}")

# %% [markdown]
# ### Company

# %%
all_developers = steam_dataset['Developers'].explode().dropna().unique()
all_publishers = steam_dataset['Publishers'].explode().dropna().unique() 
print(f"All developers: {all_developers}") 
print(f"All publishers: {all_publishers}")
# Out:
# All developers: ['Perpetual FX Creative' 'Rusty Moyher' '' ... 'Roger Gassmann'
#  'Primal Game Studio' 'Ledx Fun Studio']
# All publishers: ['Perpetual FX Creative' 'Wild Rooster' '' ... 'Waite Industries'
#  'Senatis' 'Ledx Fun Studio']

# %%
all_companies = list(set(all_developers).union(all_publishers)) 
print(f"All companies: {all_companies}")
# Out:
# All companies: ['', 'Enoops', 'DRAGONFIRE STUDIOS', 'AlyStudio', 'RevampedPRO', 'Kanan', 'Nico Tuason', 'SimaGames', 'MY.GAMES', 'holo Indie', 'Never Dream', 'Mage Entertainment', 'Michał Wikliński', 'Banana Cat', 'EZHNO', 'Mambo Dancing Shrimp', 'Aurora - Mídia & Games', 'EnderLost Studios', 'Diamond', 'Metal Fox', 'Application Systems Heidelberg', 'Magic House', 'VR Factory', 'METAGAR', 'Novaquark', 'Ilex Games', 'Chameleon Software', 'Inventive Dingo', '6 Eyes Studio', 'Kuju Entertainment', 'Egor Magurin', 'flanne', 'No Moon', 'PST Games', 'Nicholas Rizzo', 'Lunar Pug Studio', 'Happymeal Inc', '43DM Software', 'Asmodee Digital', 'NetEase Games Montréal', 'Happy Paintings', 'HandMade Games', 'Mature Games', 'Data Becker', 'Zarc Attack', 'webfoot', 'InnoGlow', 'AGEOD', 'Shattered Mirror Studio', 'Unison Shift: Blossom', 'Happy Shabby Games', 'COLNELIUS', 'Chalkseagull', 'Gee Whiz! Entertainment', 'Kouryokutei', 'Thomas van Esdonk', 'Hardsuit Labs', 'WIZNWAR', 'Chanko Studios', 'Function Unknown', 'Shakitum', 'Yuskare', 'Appnori', 'Norven Games', 'André Mello Metello', 'Nexent', 'Nano Games sp z oo', 'Oisoi.studio', 'Tereza Preislerová', 'Glass Knuckle Games', 'P4 GAMES', 'AM Team', 'Crea-ture Studios', 'Mizoriot Creative Company', 'BitBull Ltd', 'PRORTUS', 'stage-nana', 'GRP GAMES LTD', 'Bearwaves', 'Art of Horology', 'SwankyBox', 'Doublesix Games', 'Less is More', 'JOONSPICTURES', 'Holgersson Entertainment', 'Those Awesome Guys', 'DRAGO entertainment', 'Bundem Games', 'Michael Josephs', 'team ok LLC', 'JooGray videogames', 'realTroll', 'BeTomorrow', 'Di9iware software', 'Vecube Studio', 'Smartly Dressed Games', 'Kings Lance Games', 'codapill', 'MiSou Games', 'Stumphead Games', 'Elytra Games', 'Holistic Design', 'The Meta', 'Thorium', 'Joma Rage', 'panstasz', 'Panther Games', 'OWENO', 'Nuclear Tales', 'Summerfall Studios', 'PRG', 'FinalBoss Games', 'Walaber', 'RaafOritme', 'Axe Eel Games', 'Ceiba Software and Arts', 'KUNOS Simulazioni', 'Levi Buck', 'Novus Res', 'Holitass', 'Revolab', 'Mumimumi', 'Housemade', 'Dreadlocks Mobile', 'Sköll Studio', 'Asephy', 'Paction Games ApS', 'Hut 90', 'The Digital Village', 'gamevial', 'Coronado Games', 'BaleYc Studios', 'MAGES Inc', 'Weston Mitchell', 'Scarlet String Studios', 'Wangyuan Shengtang Entertainment Technology CO', 'White Owls Inc', 'CVS-Gaming', 'Gamez Studio', 'Udonpa', 'NOIR1987', 'David Moralejo Sánchez', 'a bonfire of souls', 'Ionized Games', 'Nementic Games', 'Hiragana Works', 'GLASS STAR STUDIO, LLC', 'MATCHB', 'Bean Juice Studios', 'Octoshark Studios', 'LU', 'MAD Virtual Reality Studio', 'POISON', 'G.rev', 'HEXWORKS', 'Ranida Games', 'Paleo Entertainment', 'Frostkeep Studios', 'Cubic Pie', 'Happy Snake Games', 'nullablepandas', 'Big City Lab', 'Free Reign Entertainment', 'Team NINJA', 'Sweet Dog Studios', 'ILMxLAB', 'ecoddr', 'Jayjay-1992', 'Zeekerss', 'Keith Avery', 'Team Pollysoft', 'Ekuator Games', 'Continuum XR', 'Spellbound', 'Navegante Entertainment', 'White Vortex', 'OrionSoft', 'Jens P Behrens', 'GOOSTRONAUT GAMES', 'LR Studio', 'Tau Ceti Labs', 'OneManOnMars Art', 'Gamtropy', 'Polyslash', 'End Game Interactive', 'CCYY', 'InterActive Vision', 'Micro Forté', 'Inscape', 'MiniBoss', 'RockGame SA', '2 Ton Studios', 'TWhippp Games', 'Skeleton Crew Studios', 'Ocelot Society', 'SY Games', 'MAGITEC', 'Eden Games', 'Ovilex Software', 'Deep Type Games', 'Elraim Studio', 'Lunch Money Games', 'Tall Story Studios', 'MrTheKunzer', 'Ubisoft Shanghaï', 'Get Color Games', 'Liron Peer', 'eigoMANGA', 'Danilo H Gomes', 'MJ Lovegrove', 'Headbang Club', 'Thunderful', 'Atelier Melon-Kissa', 'Vreski Games', 'Ramjet Anvil', 'Hooting Banana Studios', 'SurgutGames', 'Cat In A Jar Games', 'Anton Klock', 'Apeirogon Games', 'Yager Development', 'Capcom USA', 'Blindflug Studios', 'Sounding Stone', 'Hexdraw', 'Fullbright', 'Pcat', 'Vagabond Dog', 'Bite Through Entertainment', 'smolblockboi', 'Connor Sherlock', 'Big Shield Games', 'ReticentOwl', 'Cornbilt, LLC', 'Midquest Games', 'Super Goodwin', ...

# %%
company_tuples = [(company,) for company in all_companies]
company_tuples
# Out:
# [('',),
#  ('Enoops',),
#  ('DRAGONFIRE STUDIOS',),
#  ('AlyStudio',),
#  ('RevampedPRO',),
#  ('Kanan',),
#  ('Nico Tuason',),
#  ('SimaGames',),
#  ('MY.GAMES',),
#  ('holo Indie',),
#  ('Never Dream',),
#  ('Mage Entertainment',),
#  ('Michał Wikliński',),
#  ('Banana Cat',),
#  ('EZHNO',),
#  ('Mambo Dancing Shrimp',),
#  ('Aurora - Mídia & Games',),
#  ('EnderLost Studios',),
#  ('Diamond',),
#  ('Metal Fox',),
#  ('Application Systems Heidelberg',),
#  ('Magic House',),
#  ('VR Factory',),
#  ('METAGAR',),
#  ('Novaquark',),
#  ('Ilex Games',),
#  ('Chameleon Software',),
#  ('Inventive Dingo',),
#  ('6 Eyes Studio',),
#  ('Kuju Entertainment',),
#  ('Egor Magurin',),
#  ('flanne',),
#  ('No Moon',),
#  ('PST Games',),
#  ('Nicholas Rizzo',),
#  ('Lunar Pug Studio',),
#  ('Happymeal Inc',),
#  ('43DM Software',),
#  ('Asmodee Digital',),
#  ('NetEase Games Montréal',),
#  ('Happy Paintings',),
#  ('HandMade Games',),
#  ('Mature Games',),
#  ('Data Becker',),
#  ('Zarc Attack',),
#  ('webfoot',),
#  ('InnoGlow',),
#  ('AGEOD',),
#  ('Shattered Mirror Studio',),
#  ('Unison Shift: Blossom',),
#  ('Happy Shabby Games',),
#  ('COLNELIUS',),
#  ('Chalkseagull',),
#  ('Gee Whiz! Entertainment',),
#  ('Kouryokutei',),
#  ('Thomas van Esdonk',),
#  ('Hardsuit Labs',),
#  ('WIZNWAR',),
#  ('Chanko Studios',),
#  ('Function Unknown',),
#  ('Shakitum',),
#  ('Yuskare',),
#  ('Appnori',),
#  ('Norven Games',),
#  ('André Mello Metello',),
#  ('Nexent',),
#  ('Nano Games sp z oo',),
#  ('Oisoi.studio',),
#  ('Tereza Preislerová',),
#  ('Glass Knuckle Games',),
#  ('P4 GAMES',),
#  ('AM Team',),
#  ('Crea-ture Studios',),
#  ('Mizoriot Creative Company',),
#  ('BitBull Ltd',),
#  ('PRORTUS',),
#  ('stage-nana',),
#  ('GRP GAMES LTD',),
#  ('Bearwaves',),
#  ('Art of Horology',),
#  ('SwankyBox',),
#  ('Doublesix Games',),
#  ('Less is More',),
#  ('JOONSPICTURES',),
#  ('Holgersson Entertainment',),
#  ('Those Awesome Guys',),
#  ('DRAGO entertainment',),
#  ('Bundem Games',),
#  ('Michael Josephs',),
#  ('team ok LLC',),
#  ('JooGray videogames',),
#  ('realTroll',),
#  ('BeTomorrow',),
#  ('Di9iware software',),
#  ('Vecube Studio',),
#  ('Smartly Dressed Games',),
#  ('Kings Lance Games',),
#  ('codapill',),
#  ('MiSou Games',),
#  ('Stumphead Games',),
#  ('Elytra Games',),
#  ('Holistic Design',),
#  ('The Meta',),
#  ('Thorium',),
#  ('Joma Rage',),
#  ('panstasz',),
#  ('Panther Games',),
#  ('OWENO',),
#  ('Nuclear Tales',),
#  ('Summerfall Studios',),
#  ('PRG',),
#  ('FinalBoss Games',),
#  ('Walaber',),
#  ('RaafOritme',),
#  ('Axe Eel Games',),
#  ('Ceiba Software and Arts',),
#  ('KUNOS Simulazioni',),
#  ('Levi Buck',),
#  ('Novus Res',),
#  ('Holitass',),
#  ('Revolab',),
#  ('Mumimumi',),
#  ('Housemade',),
#  ('Dreadlocks Mobile',),
#  ('Sköll Studio',),
#  ('Asephy',),
#  ('Paction Games ApS',),
#  ('Hut 90',),
#  ('The Digital Village',),
#  ('gamevial',),
#  ('Coronado Games',),
#  ('BaleYc Studios',),
#  ('MAGES Inc',),
#  ('Weston Mitchell',),
#  ('Scarlet String Studios',),
#  ('Wangyuan Shengtang Entertainment Technology CO',),
#  ('White Owls Inc',),
#  ('CVS-Gaming',),
#  ('Gamez Studio',),
#  ('Udonpa',),
#  ('NOIR1987',),
#  ('David Moralejo Sánchez',),
#  ('a bonfire of souls',),
#  ('Ionized Games',),
#  ('Nementic Games',),
#  ('Hiragana Works',),
#  ('GLASS STAR STUDIO, LLC',),
#  ('MATCHB',),
#  ('Bean Juice Studios',),
#  ('Octoshark Studios',),
#  ('LU',),
#  ('MAD Virtual Reality Studio',),
#  ('POISON',),
#  ('G.rev',),
#  ('HEXWORKS',),
#  ('Ranida Games',),
#  ('Paleo Entertainment',),
#  ('Frostkeep Studios',),
#  ('Cubic Pie',),
#  ('Happy Snake Games',),
#  ('nullablepandas',),
#  ('Big City Lab',),
#  ('Free Reign Entertainment',),
#  ('Team NINJA',),
#  ('Sweet Dog Studios',),
#  ('ILMxLAB',),
#  ('ecoddr',),
#  ('Jayjay-1992',),
#  ('Zeekerss',),
#  ('Keith Avery',),
#  ('Team Pollysoft',),
#  ('Ekuator Games',),
#  ('Continuum XR',),
#  ('Spellbound',),
#  ('Navegante Entertainment',),
#  ('White Vortex',),
#  ('OrionSoft',),
#  ('Jens P Behrens',),
#  ('GOOSTRONAUT GAMES',),
#  ('LR Studio',),
#  ('Tau Ceti Labs',),
#  ('OneManOnMars Art',),
#  ('Gamtropy',),
#  ('Polyslash',),
#  ('End Game Interactive',),
#  ('CCYY',),
#  ('InterActive Vision',),
#  ('Micro Forté',),
#  ('Inscape',),
#  ('MiniBoss',),
#  ('RockGame SA',),
#  ('2 Ton Studios',),
#  ('TWhippp Games',),
#  ('Skeleton Crew Studios',),
#  ('Ocelot Society',),
#  ('SY Games',),
#  ('MAGITEC',),
#  ('Eden Games',),
#  ('Ovilex Software',),
#  ('Deep Type Games',),
#  ('Elraim Studio',),
#  ('Lunch Money Games',),
#  ('Tall Story Studios',),
#  ('MrTheKunzer',),
#  ('Ubisoft Shanghaï',),
#  ('Get Color Games',),
#  ('Liron Peer',),
#  ('eigoMANGA',),
#  ('Danilo H Gomes',),
#  ('MJ Lovegrove',),
#  ('Headbang Club',),
#  ('Thunderful',),
#  ('Atelier Melon-Kissa',),
#  ('Vreski Games',),
#  ('Ramjet Anvil',),
#  ('Hooting Banana Studios',),
#  ('SurgutGames',),
#  ('Cat In A Jar Games',),
#  ('Anton Klock',),
#  ('Apeirogon Games',),
#  ('Yager Development',),
#  ('Capcom USA',),
#  ('Blindflug Studios',),
#  ('Sounding Stone',),
#  ('Hexdraw',),
#  ('Fullbright',),
#  ('Pcat',),
#  ('Vagabond Dog',),
#  ('Bite Through Entertainment',),
#  ('smolblockboi',),
#  ('Connor Sherlock',),
#  ('Big Shield Games',),
#  ('ReticentOwl',),
#  ('Cornbilt, LLC',),
#  ('Midquest Games',),
#  ('Super Goodwin',),
#  ('Jannik Nickel',),
#  ('TWO B SOFT',),
#  ('Brinemedia',),
#  ('Just Purkey Games',),
#  ('Shouei System',),
#  ('Sundust',),
#  ('Gabriel Chaves Alencar',),
#  ('KaoludKung',),
#  ('Screen South',),
#  ('Wildman',),
#  ('marafrass',),
#  ('43 Studios',),
#  ('Jason Oda',),
#  ('Bobby Zeal',),
#  ('CyberGnosis Game Studio',),
#  ('Team Shanghai Alice',),
#  ('Cinemaware',),
#  ('Liquid Static Studio',),
#  ('The Secret Games Company',),
#  ('Big Fish Studios',),
#  ('Oxymoron Games',),
#  ('Layton Hawkes',),
#  ('Redbana Corporation',),
#  ('Waygetter Electronics',),
#  ('Nekofurosiki',),
#  ('World Forge',),
#  ('Reframe Games',),
#  ('DarkKnight',),
#  ('Giant Warrior Studio',),
#  ('notdead',),
#  ('KG Game Studuo',),
#  ('DY STUDIO',),
#  ('Avanquest Software Publishing Ltd',),
#  ('Yummy Yummy Studio',),
#  ('Dimps',),
#  ('kuklam studios',),
#  ('JAST Blue',),
#  ('Anate Studio',),
#  ('Underdog Studio',),
#  ('YKageyama',),
#  ('Erochin',),
#  ('Orenji Games Entertainment',),
#  ('oxblud',),
#  ('SBN3',),
#  ('UAIGolem',),
#  ('Collective Mass',),
#  ('Hanako Games',),
#  ('Laineus',),
#  ('Funky Can Creative',),
#  ('Fontainebleau',),
#  ('Sparkly Games',),
#  ('Be-Rad Entertainment',),
#  ('Henry',),
#  ('Brøderbund Software',),
#  ('Jack Southard',),
#  ('Headbang Games',),
#  ('JMJ Interactive',),
#  ('SQRL Studios',),
#  ('Notion Games',),
#  ('Zemnott',),
#  ('Remal',),
#  ('Lindsay LaPlante',),
#  ('Trinket Studios',),
#  ('Hugimugi',),
#  ('Richard H',),
#  ('Drool',),
#  ('Dieselmine',),
#  ('Christopher Lore',),
#  ('N3V Games',),
#  ('Accidently Awesome',),
#  ('João Victor da Silva',),
#  ('Shunpei Maeda',),
#  ('Strange Scaffold',),
#  ('OneManTeam',),
#  ('Contraddiction Games',),
#  ('Jumpdrive Studios',),
#  ('Madcraft Studios',),
#  ('PETA',),
#  ('JoyFul Software',),
#  ('Sunnyside Games',),
#  ('KID Corp.',),
#  ('What a Studio',),
#  ('Liquid Entertainment',),
#  ('electrolyte',),
#  ('Compile Heart',),
#  ('Team Tyrant',),
#  ("Jane's Combat Simulations",),
#  ('Ibzy Studios',),
#  ('Public Void',),
#  ('Moonless Formless',),
#  ('4Fishing',),
#  ('Lymo Games',),
#  ('Hectiq',),
#  ('IBRAHIM SAWFAN',),
#  ('Button Factory Games',),
#  ('Bit Golem',),
#  ('Orcsoft',),
#  ('Euphoric Brothers',),
#  ('Andrealphus Games',),
#  ('Blank Dream Studios',),
#  ('Bearplane',),
#  ('BekkerDev Studio',),
#  ('Amita Innovation',),
#  ('HaDe Games',),
#  ('Chautauqua Software',),
#  ('Signal Space Lab',),
#  ('Feral Cat Den',),
#  ('vestman',),
#  ('Bad Ridge Games',),
#  ('Hardwired Studios',),
#  ('Impact Gameworks',),
#  ('Lion Games Studios',),
#  ('Silvestre Gore Art',),
#  ('Wolf & Wood Interactive',),
#  ('Sol Press',),
#  ('JFi Games',),
#  ('vemu games',),
#  ('Minelli',),
#  ('Jeremy Waltman',),
#  ('Horizon Edge',),
#  ('JIMMY DIAMOND',),
#  ('Sector-K Games',),
#  ('Dracoders',),
#  ('Trash Eyes',),
#  ('1C Online Games',),
#  ('Right Pedal Studios',),
#  ('NekoNeko Soft',),
#  ('26PM',),
#  ('Paulo Henrique Pedrassi',),
#  ('Stave Studios',),
#  ('doublesix',),
#  ('NewGen SA',),
#  ('Bomi Games',),
#  ('Brave Giant',),
#  ('Studio Whisky Tango Inc',),
#  ('Manekoware',),
#  ('DarkDes Labs',),
#  ('Halftone Studios',),
#  ('Sprout Games',),
#  ('Neo Crystal Games',),
#  ('Time Ajar',),
#  ('Nerdboot',),
#  ('Studio Aurum',),
#  ('Male Doll Everyone',),
#  ('Kipwak Studio',),
#  ('Frima Studio',),
#  ('The Game Kitchen',),
#  ('Meadowhill Interactive',),
#  ('MK-ULTRA Games',),
#  ('Tatti',),
#  ('Nanasi Project',),
#  ('LoopGame',),
#  ('Tatamibeya',),
#  ('2tainment GmbH',),
#  ('semiwork',),
#  ('VladProduction',),
#  ('HitGrab Game Labs',),
#  ('Atapki',),
#  ('Monkey Stories',),
#  ('NIGORO',),
#  ('Redivided Studios',),
#  ('Amata',),
#  ('New World Interactive',),
#  ('MaxKriegerVG',),
#  ('Strandline Games',),
#  ('Moose Attack Studios',),
#  ('Blaze Epic',),
#  ('2nd Studio',),
#  ('BearfoxBear',),
#  ('BlueMoon Software',),
#  ('Conifer Games',),
#  ('Three More Years',),
#  ('Callial',),
#  ('Fancy Skeleton Games',),
#  ('Looking Glass Studios',),
#  ('Ironbird Creations',),
#  ('Bad Yolk Games',),
#  ('Amano Games',),
#  ('AURORA Games',),
#  ('ORANGE POPCORN',),
#  ('FunTech',),
#  ('JP McHargue',),
#  ('Rebel Egg Games',),
#  ('Sabotage',),
#  ('Soulflee',),
#  ('Lion Castle Entertainment',),
#  ('Ritual Interactive',),
#  ('Brace Yourself Games',),
#  ('kan.kikuchi',),
#  ('Artificial Captain',),
#  ('Intercept Games',),
#  ('Playstark',),
#  ('Oslo Albet',),
#  ('Image Space Incorporated',),
#  ('Andrew Willman',),
#  ('Furniture & Mattress',),
#  ('HIJIKI',),
#  ('LimboJimbo84',),
#  ('NEURON-AGE',),
#  ('Tranquility games',),
#  ('HUNTERS',),
#  ('Trickster Arts',),
#  ('HoneyHeart',),
#  ('Toasted Games',),
#  ('Curve Digital',),
#  ('Aleksander Krimsky',),
#  ('Contamination Studios',),
#  ('Mayhem Studios',),
#  ('Cimugames',),
#  ('Oversight Productions',),
#  ('Moonbit',),
#  ('Lucky VR Inc',),
#  ('Bynine',),
#  ('Chilman',),
#  ('Chibig',),
#  ('HuntingSwan',),
#  ('Horizont Computergrafik',),
#  ('Playtonic Friends',),
#  ('Eteru Studio',),
#  ('Point Blank Games',),
#  ('Pixonic',),
#  ('Bipedal Dog',),
#  ('Capstone Software',),
#  ('Jackbox Games',),
#  ('Lukifah',),
#  ('Pixelian Studio',),
#  ('GeeSeki',),
#  ('Hexapede Engine',),
#  ('The Blackmouth Games',),
#  ('Tier-4 Games',),
#  ('Enno LLC',),
#  ('Nordcurrent Labs',),
#  ('Oaky Games',),
#  ('Terri Vellmann',),
#  ('I AM A DOG studio',),
#  ('Erik Svedäng',),
#  ('Ruki.Nanase',),
#  ('AV1 Productions',),
#  ('Mr.Skull Game Studio',),
#  ('Sombr Studio LLC',),
#  ('SoBad',),
#  ('Dream Compass',),
#  ('Clovelt',),
#  ('Bling Bling Games GmbH',),
#  ('Soap Interactive',),
#  ('CryTechGames',),
#  ('dotBunny',),
#  ('Vladimir Pliashkun',),
#  ('Simplicity Games',),
#  ('LFiO Studio',),
#  ('Good Bit',),
#  ('OAKgames',),
#  ('Dark One',),
#  ('Iriya72',),
#  ('Vagabond',),
#  ('DevHour Games',),
#  ('MAGIX Software GmbH',),
#  ('2OO2',),
#  ('Guys From Andromeda LLC',),
#  ('Waden Kane Game Studios',),
#  ('Graveck',),
#  ('Nichengun',),
#  ('WS net',),
#  ('John Segerstedt',),
#  ('Boss Team Games',),
#  ('Solid Neon Games',),
#  ('Namco Networks America, Inc.',),
#  ('Cinnamon Switch',),
#  ('Exploding Tuba Studios',),
#  ('NUU',),
#  ('Among Giants',),
#  ('Beau Blyth',),
#  ('Selecta Play',),
#  ('SandVUE',),
#  ('Nintendo Software Technology',),
#  ('Andreas Baum',),
#  ('Basement Dweller Games',),
#  ('Niobium Studios',),
#  ('Spinfoam Games',),
#  ('Beast Games SA',),
#  ('Raptisoft Games',),
#  ('Salty Karma',),
#  ('Google',),
#  ('Antique Gear Games',),
#  ('Shit-Happens-Software',),
#  ('Team Carnal Instinct',),
#  ('SolidFace Technology Inc',),
#  ('Turbo the Moon',),
#  ('Glorified Studios',),
#  ('Collapse Games',),
#  ('Locus Ludus',),
#  ('tomboyDrive',),
#  ('Oxeye Game Studio',),
#  ('Radin Games',),
#  ('Hungry Planet Games',),
#  ('Josh Hague',),
#  ('Varia Games',),
#  ('Slug Disco Studios',),
#  ('Demimonde',),
#  ('Syndicate Atomic LLC',),
#  ('Black Vein Productions',),
#  ('JioJo（抠脚脚太郎）',),
#  ('Climax Studios',),
#  ('Wicked Studios',),
#  ('Piranaking',),
#  ('CommonWombat',),
#  ('MJM Creative Works and ideas',),
#  ('TeraHard',),
#  ('Harvester Games',),
#  ('Studio Sterneck',),
#  ('Stigma Studios',),
#  ('Fuzzy',),
#  ('UKZ Arts',),
#  ('guyzware',),
#  ('Toucan Studio',),
#  ('Me Vs Game',),
#  ('Retreaux Games',),
#  ('Daniel A Ramirez',),
#  ('HyperSloth',),
#  ('Kane Carter',),
#  ('Oldice Games',),
#  ('Humble Hearts',),
#  ('Grimlore Games',),
#  ('Infinite Whys',),
#  ('0UP GAMES',),
#  ('H3Soft',),
#  ('Laush Studio',),
#  ('GooodMon',),
#  ('IndiePub',),
#  ('Marvelous First Studio',),
#  ('Chaos Cactus',),
#  ('Necavare',),
#  ('yondray',),
#  ('A Tenda com Games',),
#  ('Homewreckers Studio',),
#  ('Zepetto Co',),
#  ('Gamepires',),
#  ('Matheus Antonio',),
#  ('Rhizome Games',),
#  ('Naarassusi Game',),
#  ('btf',),
#  ('Nepos Games',),
#  ('Josh Bossie',),
#  ('Sandbox Interactive',),
#  ('limitless games',),
#  ('Florent Vieillescazes',),
#  ('Artax Games',),
#  ('Retisi',),
#  ('slimelvl2',),
#  ('Tasty Stewdios LLC',),
#  ('SOLIDS Studio',),
#  ('Nodding Heads Games',),
#  ('Alastair John Jack',),
#  ('Huard Ouadi',),
#  ('Scarlet Whale',),
#  ('Kilted Camel',),
#  ('5minlab Corporation',),
#  ('Schizotypy Games',),
#  ('Ysbryd Games',),
#  ('rupiwood',),
#  ('Under the Bed Games',),
#  ('Sweatyhand',),
#  ('wemakeagame',),
#  ('Mustafa CELIK',),
#  ('Hadoque',),
#  ('notreallythin',),
#  ('窝窝社',),
#  ('Ubisoft Blue Byte',),
#  ('Odooh Games',),
#  ('Nugroho Industries',),
#  ('bhv Software GmbH & Co. KG',),
#  ('One Bit Studio',),
#  ('Poorly Drawn Squid',),
#  ('Royal Games Studio',),
#  ('PolyDigital',),
#  ('La Moustache Studio',),
#  ('Takashi Sowa',),
#  ('Ismael Rodriguez',),
#  ('EP Games',),
#  ('Kevin Blüml',),
#  ('Stupid Stupid Games',),
#  ('Umeshu Lovers Studio',),
#  ('Master Technologies',),
#  ('拾英工作室',),
#  ('Heavy Sheep',),
#  ('Dreamlit Entertainment',),
#  ('Bontemps Games',),
#  ('IZZLE',),
#  ('Longplay Games',),
#  ('Jirai Games',),
#  ('Graphite Lab',),
#  ('Xendra',),
#  ('Napas Torteeka',),
#  ('Muzzy Lane',),
#  ('Draknek and Friends',),
#  ('Boxsun',),
#  ('Warcave',),
#  ('SmallBigSquare',),
#  ('kouri',),
#  ('Oaksand Games',),
#  ('Merscom',),
#  ('The 8-Bit Guy',),
#  ('Bango House',),
#  ('Stage Clear Studios',),
#  ('Mow Mow',),
#  ('Phosphor Games Studio',),
#  ('Torpor Games',),
#  ('SugarHyped',),
#  ('zelun',),
#  ('Christophe Mercier',),
#  ('Randumb Studios',),
#  ('Dysnomia',),
#  ('Team OFK',),
#  ('Rotten Mage',),
#  ('Redaster Studio',),
#  ('XSGames',),
#  ('Sharkbowl Games',),
#  ('Jon Nielsen',),
#  ('Kitewing Studio',),
#  ('Fractured Rogue Studios',),
#  ('Atzi Games',),
#  ('Team Yokkyufuman',),
#  ('Sad Owl Studios',),
#  ('GuGames Development',),
#  ('Wooden Monkeys',),
#  ('Hues Games',),
#  ('Thunderfox Studio',),
#  ('AIHASTO',),
#  ('Protoculture Games',),
#  ('Stardock Entertainment',),
#  ('Broke Studio',),
#  ('Wild Grip',),
#  ('Jim Magnusson',),
#  ('Flying Carpets Games',),
#  ('High North Studios AS',),
#  ('CelleC Games',),
#  ('Andrii Vintsevych',),
#  ('Water Phoenix',),
#  ('Null Games',),
#  ('Wyse Games',),
#  ('Jamhammer Games Inc',),
#  ('Anegar Games',),
#  ('GapTax',),
#  ('ENOOPS Games',),
#  ('Encore',),
#  ('Silverware Games, Inc.',),
#  ('Dan Walters',),
#  ('幻想禁',),
#  ('White Faction Studio',),
#  ('Odd Meter',),
#  ('Sport1 GmbH',),
#  ('Yume Creations',),
#  ('Beep Games',),
#  ('Titmouse',),
#  ('Horgee Games',),
#  ('Don VS Dodo',),
#  ('SOGA Std',),
#  ('NovaStar',),
#  ('Sinergia Studios',),
#  ('Mez Dev Studio',),
#  ('Mobile21',),
#  ('Caracal Games',),
#  ('Light',),
#  ('White Rabbit Interactive',),
#  ('VIOE',),
#  ('RedDotGames',),
#  ('Dandylion',),
#  ('GrahamOfLegend',),
#  ('Container Studio',),
#  ('Woodsy Studio',),
#  ('Nalua Studio',),
#  ('SmallGreenHill',),
#  ('Disruptive Games',),
#  ('Leon Matthew Simanjuntak',),
#  ('ILIKESCIFI Games',),
#  ('Angel Star Studios',),
#  ('North Modding Company',),
#  ('Bizarre Creations',),
#  ('Rivero Games',),
#  ('MediaCity Games',),
#  ('Pulsetense Games',),
#  ('Sakura Studios',),
#  ('CrackedGhostGames',),
#  ('Herrero Games',),
#  ('VampireK.K.',),
#  ('Pandamonium Entertainment',),
#  ('CT Matthews',),
#  ('Stadlbauer',),
#  ('npckc',),
#  ('ICAD/VisionLab PUC-Rio',),
#  ('Three Souls Interactive',),
#  ('Dragon Level',),
#  ('Force Of Habit',),
#  ('Coastalbyte Games',),
#  ('DualWielded',),
#  ('AJB GAMES STUDIO',),
#  ('Reborn Entertainment',),
#  ('Reglest5 Games',),
#  ('PhobiaGamesNet',),
#  ('Steve Gal',),
#  ('Owen Bell',),
#  ('Starbyte',),
#  ('COWCAT',),
#  ('Wowa',),
#  ('NEOPOPCORN Corp',),
#  ('PrimoSalmon',),
#  ('Sarubara Michiru',),
#  ('pinkjuicegames',),
#  ('Tambouille',),
#  ('Spytihněv',),
#  ('Seize Studios',),
#  ('Y8.com',),
#  ('Burning Sunset',),
#  ('Werys Ltd',),
#  ('Fivemid',),
#  ('Live Wire',),
#  ('Bitlock Studio',),
#  ('Svarog Studios',),
#  ('Retroware',),
#  ('Aerilon Studios',),
#  ('RED STAR GAMES',),
#  ('Propaganda Code',),
#  ('Vintage Digital Revival',),
#  ('Outerloop Games',),
#  ('Electric Eggplant',),
#  ('Pixelfoot Games',),
#  ('Gamenergy studio',),
#  ('Nerve Software, LLC',),
#  ('Cold Symmetry',),
#  ('NaissusWorks',),
#  ('Neilson Koerner-Safrata',),
#  ('PGM Studio',),
#  ('Sewer Cat',),
#  ('WizardWorks Software',),
#  ('Nextgen Reality Pty Ltd',),
#  ('Viacom International',),
#  ('Matrix Goat Studios',),
#  ('Zen Studios',),
#  ('Catland',),
#  ('Fengraf Games',),
#  ('Spicy Fox',),
#  ('Tezcatek',),
#  ('Bad Kids Games',),
#  ('Toni Domínguez',),
#  ('Dark Dimension',),
#  ('Vega Mobile',),
#  ('Gogiii',),
#  ('Double Robot',),
#  ('PING YI LIN',),
#  ('HiSv Studio',),
#  ('Glacier LTD',),
#  ('LateNightCoffee',),
#  ('Treetop',),
#  ('evolvedlabs',),
#  ('Spikkeee',),
#  ('Bold Head Interactive',),
#  ('Neumont College of Computer Science',),
#  ('The Acceleration Agency',),
#  ('FreeAnimals_Software',),
#  ('North Star Digital Studios',),
#  ('Proscenium',),
#  ('ECC GAMES SA',),
#  ('Whalebox Studio',),
#  ('koker_007',),
#  ('SWAIN GAMES',),
#  ('Pioneer LDC',),
#  ('Ambitious Games',),
#  ('NCSOFT',),
#  ('5th Planet Games Development',),
#  ('Ritual Games',),
#  ('Beemoov',),
#  ('Acke Hallgren',),
#  ('4Head Studios',),
#  ('Lovebird Game Studios',),
#  ('Noclip',),
#  ('HideWorks',),
#  ('Hanoi Studios',),
#  ('Pumpkin Head Studio',),
#  ('Teawork Dev',),
#  ('Jagger Game Studio',),
#  ('BitSits Games',),
#  ('planetrenox',),
#  ('DarkTigerDevelopments',),
#  ('Lemonbomb Entertainment',),
#  ('Crimson Herring Studios Inc.',),
#  ('Reverie Foundry',),
#  ('Yakiniku Banzai',),
#  ('Anya Johanna DeNiro',),
#  ('Cosmic Picnic',),
#  ('Escalation Studios',),
#  ('ThiGames',),
#  ('边境游戏工作室',),
#  ('2K Games',),
#  ('GorillaSoftWorks',),
#  ('Kloonigames',),
#  ('ektomarch',),
#  ('1337 & Senri AB',),
#  ('G CHOICE',),
#  ('Weirdfellows',),
#  ('Midnight Games',),
#  ('Cabbusoft',),
#  ('PapStache',),
#  ('Atelier 801',),
#  ('XDEVS',),
#  ('Devious Oatmeal',),
#  ('Housemarque',),
#  ('Goliath Games',),
#  ('Triple Cerberus Studios',),
#  ('Galaktus',),
#  ('Black Salt Games',),
#  ('SkagoGames',),
#  ('Towerfag',),
#  ('A Shell in the Pit',),
#  ('Flight School Studio',),
#  ('UPLAY Online',),
#  ('Icedrop Games',),
#  ('Adventure Hat',),
#  ('Leonard Menchiari',),
#  ('RAYKA STUDIO',),
#  ('Magyu Studio',),
#  ('Hamra Digital',),
#  ('DreamCatcher Interactive',),
#  ('RedFox Games',),
#  ('Adam Sklar',),
#  ('Twisted Pixel Games',),
#  ('Abstraction Games',),
#  ('Electronic Motion Games',),
#  ('Butterflyware',),
#  ('Unusual Undertaking',),
#  ('ShazySoft',),
#  ('Black Market Games',),
#  ('Studio Goya',),
#  ('Holmgard Games',),
#  ('OVERKILL Software',),
#  ('RS34',),
#  ('Shared Dreams Studios',),
#  ('Dino Trnka',),
#  ('Double Uppercut Games',),
#  ('Retrospec',),
#  ('Rovio Stars',),
#  ('LukasH',),
#  ('Deeli network',),
#  ('Valkyrie Entertainment',),
#  ('EfrenStudios',),
#  ('TECHHOME',),
#  ('KLH Studios LLC',),
#  ('COMINO Inc.',),
#  ('Keybol Games',),
#  ('Erdem Sen',),
#  ('MoFunZone Inc',),
#  ('The N Main Shop',),
#  ('Split Second Games',),
#  ('Dr Puzzler',),
#  ('Not Dead Design',),
#  ('Ecliptic Studios',),
#  ('HAL College of Technology & Design',),
#  ('Hippo Rider',),
#  ('Mono Studio',),
#  ('NinePlus Studio',),
#  ('Cube Roots',),
#  ('Wild Rooster',),
#  ('Ernestas Norvaišas',),
#  ('Maithonis Studios',),
#  ('BerserkBoy Games',),
#  ('Irem',),
#  ('Heiden',),
#  ('VNka',),
#  ('Degica Games',),
#  ('Pingfang Games',),
#  ('Virgin Interactive Entertainment (Europe) Ltd.',),
#  ('Malte Weiß',),
#  ('Lazerpants Studios LLC',),
#  ('Kaida Studios',),
#  ('跳跃网络',),
#  ('Digital Fusion',),
#  ('tokoronyori',),
#  ('Neo Kuriyo',),
#  ('SoundByte Interactive',),
#  ('Pixel Quality Games',),
#  ('Third Sphere Game Studios',),
#  ('Flying Fire, LLC',),
#  ('Viva Media',),
#  ('Mischief',),
#  ('Black Sea Games',),
#  ('Owlcat Games',),
#  ('Rotorist Workshop',),
#  ('Semidome Inc',),
#  ('Left Field Productions',),
#  ('Ionborn Entertainment',),
#  ('Giant Margarita',),
#  ('Slightly Mad Studios',),
#  ('Catvin Catowsky',),
#  ('Nuligine',),
#  ('Mercator',),
#  ('Sergey Romanko',),
#  ('Code-Monkeys',),
#  ('Mega Boss Game Studio',),
#  ('SimpleSoft',),
#  ('pixel.lu',),
#  ('Dystopian Ruler',),
#  ('The Best Worst Gamers Publishing',),
#  ('Psychronic Game Studios',),
#  ('Wise Games',),
#  ('Lost Robots',),
#  ('LisiSoft',),
#  ('No One Studios',),
#  ('Inductance',),
#  ('sc Reea srl',),
#  ('Turtle Sandbox',),
#  ('Deck13',),
#  ('makaroll',),
#  ('Digital Matters Publishing',),
#  ('Hexage',),
#  ('Inters Media',),
#  ('Bodgamestudio',),
#  ('IV Games',),
#  ('Blue.Owl',),
#  ('Fancy + Punk',),
#  ('Vircom Interactive',),
#  ('BraveWolf',),
#  ('N-Body Solutions',),
#  ('Gamester',),
#  ('SuckerFree Games',),
#  ('Wild Shadow Studios',),
#  ('MindFly Studio',),
#  ('Linked Rooms Games',),
#  ('Clever Plays',),
#  ('Dream Safe',),
#  ('Sproubbit Studio',),
#  ('WinterSpring Games',),
#  ('GreenGuy',),
#  ('Meowza Games',),
#  ('Bil Deerbuch',),
#  ('Marco Noordergraaf',),
#  ('RedBrickStone Games',),
#  ('Opala Project',),
#  ('QubicGames S.A.',),
#  ('Decane',),
#  ('Lightbulb Crew',),
#  ('earrgames',),
#  ('Eclipse Games',),
#  ('Funky Logic Studios',),
#  ('Gus Jewell',),
#  ('Damian Sommer',),
#  ('Westeford',),
#  ('Sleeping Eight Studio',),
#  ('Oval Games',),
#  ('Plug In Digital',),
#  ('Somnium Space Ltd',),
#  ('Evil Boobs Cult',),
#  ('Colorspace Studio',),
#  ('SPS',),
#  ('Stormcloud Games',),
#  ('RGByte Software',),
#  ('Hermes Interactive',),
#  ('UGround Game Studio',),
#  ('Freeze Tag Inc.',),
#  ('Hex Code Coven',),
#  ('Magicom Multimedia Corp',),
#  ('DTF games',),
#  ('Nocturna Video Games Studio',),
#  ('Bisong Taiwo',),
#  ('VINE',),
#  ('Eyedrop',),
#  ...]

# %%
company_insert_query = "INSERT IGNORE INTO companies (name) VALUES (%s)" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor() 
    
    cursor.executemany(company_insert_query, company_tuples)
    mydb.commit() 

except Exception as e: 
    print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "companies", company_tuples)
# Out:
# Not all data was inserted successfully: 22020 out of 22502

# %% [markdown]
# ### Categories

# %%
# Convert stringified lists into actual Python lists
def safe_eval(val):
    try:
        return ast.literal_eval(val)
    except:
        return []

# %%
all_categories = steam_dataset['Categories'].apply(lambda x: safe_eval(x)).explode().dropna().unique()
all_categories = set(all_categories)
all_categories
# Out:
# {'Captions available',
#  'Co-op',
#  'Commentary available',
#  'Cross-Platform Multiplayer',
#  'Family Sharing',
#  'Full controller support',
#  'HDR available',
#  'In-App Purchases',
#  'Includes Source SDK',
#  'Includes level editor',
#  'LAN Co-op',
#  'LAN PvP',
#  'MMO',
#  'Mods',
#  'Mods (require HL2)',
#  'Multi-player',
#  'Online Co-op',
#  'Online PvP',
#  'Partial Controller Support',
#  'PvP',
#  'Remote Play Together',
#  'Remote Play on Phone',
#  'Remote Play on TV',
#  'Remote Play on Tablet',
#  'Shared/Split Screen',
#  'Shared/Split Screen Co-op',
#  'Shared/Split Screen PvP',
#  'Single-player',
#  'Stats',
#  'Steam Achievements',
#  'Steam Cloud',
#  'Steam Leaderboards',
#  'Steam Timeline',
#  'Steam Trading Cards',
#  'Steam Turn Notifications',
#  'Steam Workshop',
#  'SteamVR Collectibles',
#  'Tracked Controller Support',
#  'Tracked Motion Controller Support',
#  'VR Only',
#  'VR Support',
#  'VR Supported',
#  'Valve Anti-Cheat enabled'}

# %%
category_tuples = [(category,) for category in all_categories]
category_tuples
# Out:
# [('Shared/Split Screen PvP',),
#  ('Commentary available',),
#  ('Steam Trading Cards',),
#  ('Full controller support',),
#  ('Includes Source SDK',),
#  ('Steam Leaderboards',),
#  ('SteamVR Collectibles',),
#  ('Mods',),
#  ('In-App Purchases',),
#  ('PvP',),
#  ('Shared/Split Screen',),
#  ('LAN PvP',),
#  ('Single-player',),
#  ('Tracked Controller Support',),
#  ('VR Support',),
#  ('Valve Anti-Cheat enabled',),
#  ('Remote Play on Tablet',),
#  ('Steam Cloud',),
#  ('Captions available',),
#  ('Cross-Platform Multiplayer',),
#  ('Tracked Motion Controller Support',),
#  ('Remote Play Together',),
#  ('HDR available',),
#  ('LAN Co-op',),
#  ('Includes level editor',),
#  ('Steam Timeline',),
#  ('Co-op',),
#  ('Remote Play on TV',),
#  ('Online PvP',),
#  ('Partial Controller Support',),
#  ('Steam Achievements',),
#  ('Steam Workshop',),
#  ('Mods (require HL2)',),
#  ('Online Co-op',),
#  ('Multi-player',),
#  ('VR Only',),
#  ('VR Supported',),
#  ('Shared/Split Screen Co-op',),
#  ('Steam Turn Notifications',),
#  ('Remote Play on Phone',),
#  ('MMO',),
#  ('Family Sharing',),
#  ('Stats',)]

# %%
category_insert_query = "INSERT IGNORE INTO categories (name) VALUES (%s)" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor() 

    cursor.executemany(category_insert_query, category_tuples)
    mydb.commit() 

except Exception as e:  
    print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "categories", category_tuples)
# Out:
# All data was inserted successfully: 43 out of 43

# %% [markdown]
# ### Genres

# %%
all_genres = steam_dataset['Genres'].apply(lambda x: safe_eval(x)).explode().dropna().unique()
all_genres = set(all_genres)
all_genres
# Out:
# {'360 Video',
#  'Accounting',
#  'Action',
#  'Adventure',
#  'Animation & Modeling',
#  'Audio Production',
#  'Casual',
#  'Design & Illustration',
#  'Documentary',
#  'Early Access',
#  'Education',
#  'Episodic',
#  'Free to Play',
#  'Game Development',
#  'Gore',
#  'Indie',
#  'Massively Multiplayer',
#  'Movie',
#  'Nudity',
#  'Photo Editing',
#  'RPG',
#  'Racing',
#  'Sexual Content',
#  'Short',
#  'Simulation',
#  'Software Training',
#  'Sports',
#  'Strategy',
#  'Tutorial',
#  'Utilities',
#  'Video Production',
#  'Violent',
#  'Web Publishing'}

# %%
genre_tuples = [(genre,) for genre in all_genres]
genre_tuples
# Out:
# [('Racing',),
#  ('Adventure',),
#  ('Massively Multiplayer',),
#  ('Sexual Content',),
#  ('Audio Production',),
#  ('Gore',),
#  ('Strategy',),
#  ('Game Development',),
#  ('360 Video',),
#  ('Sports',),
#  ('Video Production',),
#  ('Casual',),
#  ('Web Publishing',),
#  ('Animation & Modeling',),
#  ('Design & Illustration',),
#  ('Movie',),
#  ('Free to Play',),
#  ('Simulation',),
#  ('Accounting',),
#  ('Episodic',),
#  ('Education',),
#  ('Documentary',),
#  ('Indie',),
#  ('Tutorial',),
#  ('RPG',),
#  ('Short',),
#  ('Nudity',),
#  ('Early Access',),
#  ('Software Training',),
#  ('Action',),
#  ('Utilities',),
#  ('Photo Editing',),
#  ('Violent',)]

# %%
genre_insert_query = "INSERT IGNORE INTO genres (name) VALUES (%s)" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor()  
    
    cursor.executemany(genre_insert_query, genre_tuples)
    mydb.commit() 

except Exception as e:  
    print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "genres", genre_tuples)
# Out:
# All data was inserted successfully: 33 out of 33

# %% [markdown]
# ### Tags

# %%
all_tags = steam_dataset['Tags'].apply(lambda x: safe_eval(x)).explode().dropna().unique()
all_tags = set(all_tags)
all_tags
# Out:
# {'1980s',
#  "1990's",
#  '2.5D',
#  '2D',
#  '2D Fighter',
#  '2D Platformer',
#  '360 Video',
#  '3D',
#  '3D Fighter',
#  '3D Platformer',
#  '3D Vision',
#  '4 Player Local',
#  '4X',
#  '6DOF',
#  '8-bit Music',
#  'ATV',
#  'Abstract',
#  'Action',
#  'Action RPG',
#  'Action RTS',
#  'Action Roguelike',
#  'Action-Adventure',
#  'Addictive',
#  'Adventure',
#  'Agriculture',
#  'Aliens',
#  'Alternate History',
#  'Ambient',
#  'America',
#  'Animation & Modeling',
#  'Anime',
#  'Arcade',
#  'Archery',
#  'Arena Shooter',
#  'Artificial Intelligence',
#  'Assassin',
#  'Asymmetric VR',
#  'Asynchronous Multiplayer',
#  'Atmospheric',
#  'Audio Production',
#  'Auto Battler',
#  'Automation',
#  'Automobile Sim',
#  'BMX',
#  'Base-Building',
#  'Baseball',
#  'Based On A Novel',
#  'Basketball',
#  'Batman',
#  'Battle Royale',
#  "Beat 'em up",
#  'Beautiful',
#  'Benchmark',
#  'Bikes',
#  'Birds',
#  'Blood',
#  'Board Game',
#  'Boomer Shooter',
#  'Boss Rush',
#  'Bowling',
#  'Boxing',
#  'Building',
#  'Bullet Hell',
#  'Bullet Time',
#  'CRPG',
#  'Capitalism',
#  'Card Battler',
#  'Card Game',
#  'Cartoon',
#  'Cartoony',
#  'Casual',
#  'Cats',
#  'Character Action Game',
#  'Character Customization',
#  'Chess',
#  'Choices Matter',
#  'Choose Your Own Adventure',
#  'Cinematic',
#  'City Builder',
#  'Class-Based',
#  'Classic',
#  'Clicker',
#  'Co-op',
#  'Co-op Campaign',
#  'Coding',
#  'Cold War',
#  'Collectathon',
#  'Colony Sim',
#  'Colorful',
#  'Combat',
#  'Combat Racing',
#  'Comedy',
#  'Comic Book',
#  'Competitive',
#  'Conspiracy',
#  'Controller',
#  'Conversation',
#  'Cooking',
#  'Cozy',
#  'Crafting',
#  'Creature Collector',
#  'Cricket',
#  'Crime',
#  'Crowdfunded',
#  'Cult Classic',
#  'Cute',
#  'Cyberpunk',
#  'Cycling',
#  'Dark',
#  'Dark Comedy',
#  'Dark Fantasy',
#  'Dark Humor',
#  'Dating Sim',
#  'Deckbuilding',
#  'Demons',
#  'Design & Illustration',
#  'Destruction',
#  'Detective',
#  'Dice',
#  'Difficult',
#  'Dinosaurs',
#  'Diplomacy',
#  'Documentary',
#  'Dog',
#  'Dragons',
#  'Drama',
#  'Driving',
#  'Dungeon Crawler',
#  'Dungeons & Dragons',
#  'Dwarf',
#  'Dynamic Narration',
#  'Dystopian',
#  'Early Access',
#  'Economy',
#  'Education',
#  'Electronic',
#  'Electronic Music',
#  'Elf',
#  'Emotional',
#  'Epic',
#  'Episodic',
#  'Escape Room',
#  'Experience',
#  'Experimental',
#  'Exploration',
#  'Extraction Shooter',
#  'FMV',
#  'FPS',
#  'Faith',
#  'Family Friendly',
#  'Fantasy',
#  'Farming',
#  'Farming Sim',
#  'Fast-Paced',
#  'Feature Film',
#  'Female Protagonist',
#  'Fighting',
#  'First-Person',
#  'Fishing',
#  'Flight',
#  'Football',
#  'Football (American)',
#  'Football (Soccer)',
#  'Foreign',
#  'Fox',
#  'Free to Play',
#  'Funny',
#  'Futuristic',
#  'Gambling',
#  'Game Development',
#  'GameMaker',
#  'Games Workshop',
#  'Gaming',
#  'God Game',
#  'Golf',
#  'Gore',
#  'Gothic',
#  'Grand Strategy',
#  'Great Soundtrack',
#  'Grid-Based Movement',
#  'Gun Customization',
#  'Hack and Slash',
#  'Hacking',
#  'Hand-drawn',
#  'Hardware',
#  'Heist',
#  'Hentai',
#  'Hero Shooter',
#  'Hex Grid',
#  'Hidden Object',
#  'Historical',
#  'Hobby Sim',
#  'Hockey',
#  'Horror',
#  'Horses',
#  'Hunting',
#  'Idler',
#  'Illuminati',
#  'Immersive',
#  'Immersive Sim',
#  'Indie',
#  'Instrumental Music',
#  'Intentionally Awkward Controls',
#  'Interactive Fiction',
#  'Inventory Management',
#  'Investigation',
#  'Isometric',
#  'JRPG',
#  'Jet',
#  'Job Simulator',
#  'Jump Scare',
#  'Kickstarter',
#  'LEGO',
#  'LGBTQ+',
#  'Lara Croft',
#  'Lemmings',
#  'Level Editor',
#  'Life Sim',
#  'Linear',
#  'Local Co-Op',
#  'Local Multiplayer',
#  'Logic',
#  'Loot',
#  'Looter Shooter',
#  'Lore-Rich',
#  'Lovecraftian',
#  'MMORPG',
#  'MOBA',
#  'Magic',
#  'Mahjong',
#  'Management',
#  'Mars',
#  'Martial Arts',
#  'Massively Multiplayer',
#  'Masterpiece',
#  'Match 3',
#  'Mature',
#  'Mechs',
#  'Medical Sim',
#  'Medieval',
#  'Memes',
#  'Metroidvania',
#  'Military',
#  'Mini Golf',
#  'Minigames',
#  'Minimalist',
#  'Mining',
#  'Mod',
#  'Moddable',
#  'Modern',
#  'Motocross',
#  'Motorbike',
#  'Mouse only',
#  'Movie',
#  'Multiplayer',
#  'Multiple Endings',
#  'Music',
#  'Music-Based Procedural Generation',
#  'Musou',
#  'Mystery',
#  'Mystery Dungeon',
#  'Mythology',
#  'NSFW',
#  'Narration',
#  'Narrative',
#  'Nature',
#  'Naval',
#  'Naval Combat',
#  'Ninja',
#  'Noir',
#  'Nonlinear',
#  'Nostalgia',
#  'Nudity',
#  'Offroad',
#  'Old School',
#  'On-Rails Shooter',
#  'Online Co-Op',
#  'Open World',
#  'Open World Survival Craft',
#  'Otome',
#  'Outbreak Sim',
#  'Parkour',
#  'Parody',
#  'Party',
#  'Party Game',
#  'Party-Based RPG',
#  'Perma Death',
#  'Philosophical',
#  'Photo Editing',
#  'Physics',
#  'Pinball',
#  'Pirates',
#  'Pixel Graphics',
#  'Platformer',
#  'Point & Click',
#  'Political',
#  'Political Sim',
#  'Politics',
#  'Pool',
#  'Post-apocalyptic',
#  'Precision Platformer',
#  'Procedural Generation',
#  'Programming',
#  'Psychedelic',
#  'Psychological',
#  'Psychological Horror',
#  'Puzzle',
#  'Puzzle-Platformer',
#  'PvE',
#  'PvP',
#  'Quick-Time Events',
#  'RPG',
#  'RPGMaker',
#  'RTS',
#  'Racing',
#  'Real Time Tactics',
#  'Real-Time',
#  'Real-Time with Pause',
#  'Realistic',
#  'Reboot',
#  'Relaxing',
#  'Remake',
#  'Replay Value',
#  'Resource Management',
#  'Retro',
#  'Rhythm',
#  'Robots',
#  'Rock Music',
#  'Rogue-like',
#  'Rogue-lite',
#  'Roguelike Deckbuilder',
#  'Roguevania',
#  'Romance',
#  'Rome',
#  'Rugby',
#  'Runner',
#  'Sailing',
#  'Sandbox',
#  'Satire',
#  'Sci-fi',
#  'Science',
#  'Score Attack',
#  'Sequel',
#  'Sexual Content',
#  "Shoot 'Em Up",
#  'Shooter',
#  'Shop Keeper',
#  'Short',
#  'Side Scroller',
#  'Silent Protagonist',
#  'Simulation',
#  'Singleplayer',
#  'Skateboarding',
#  'Skating',
#  'Skiing',
#  'Sniper',
#  'Snooker',
#  'Snow',
#  'Snowboarding',
#  'Soccer',
#  'Social Deduction',
#  'Software',
#  'Software Training',
#  'Sokoban',
#  'Solitaire',
#  'Souls-like',
#  'Soundtrack',
#  'Space',
#  'Space Sim',
#  'Spaceships',
#  'Spectacle fighter',
#  'Spelling',
#  'Split Screen',
#  'Sports',
#  'Stealth',
#  'Steam Machine',
#  'Steampunk',
#  'Story Rich',
#  'Strategy',
#  'Strategy RPG',
#  'Stylized',
#  'Submarine',
#  'Superhero',
#  'Supernatural',
#  'Surreal',
#  'Survival',
#  'Survival Horror',
#  'Swordplay',
#  'Tabletop',
#  'Tactical',
#  'Tactical RPG',
#  'Tanks',
#  'Team-Based',
#  'Tennis',
#  'Text-Based',
#  'Third Person',
#  'Third-Person Shooter',
#  'Thriller',
#  'Tile-Matching',
#  'Time Attack',
#  'Time Management',
#  'Time Manipulation',
#  'Time Travel',
#  'Top-Down',
#  'Top-Down Shooter',
#  'Touch-Friendly',
#  'Tower Defense',
#  'TrackIR',
#  'Trading',
#  'Trading Card Game',
#  'Traditional Roguelike',
#  'Trains',
#  'Transhumanism',
#  'Transportation',
#  'Trivia',
#  'Turn-Based',
#  'Turn-Based Combat',
#  'Turn-Based Strategy',
#  'Turn-Based Tactics',
#  'Tutorial',
#  'Twin Stick Shooter',
#  'Typing',
#  'Underground',
#  'Underwater',
#  'Unforgiving',
#  'Utilities',
#  'VR',
#  'VR Only',
#  'Vampire',
#  'Vehicular Combat',
#  'Video Production',
#  'Vikings',
#  'Villain Protagonist',
#  'Violent',
#  'Visual Novel',
#  'Voice Control',
#  'Volleyball',
#  'Voxel',
#  'Walking Simulator',
#  'War',
#  'Wargame',
#  'Warhammer 40K',
#  'Web Publishing',
#  'Well-Written',
#  'Werewolves',
#  'Western',
#  'Wholesome',
#  'Word Game',
#  'World War I',
#  'World War II',
#  'Wrestling',
#  'Zombies',
#  'e-sports'}

# %%
tag_tuples = [(tag,) for tag in all_tags]
tag_tuples
# Out:
# [('Party-Based RPG',),
#  ('Musou',),
#  ('Werewolves',),
#  ('Thriller',),
#  ('Hobby Sim',),
#  ('Strategy',),
#  ('Atmospheric',),
#  ('Offroad',),
#  ('1980s',),
#  ('Bikes',),
#  ('Psychological Horror',),
#  ('Parkour',),
#  ('Surreal',),
#  ('Historical',),
#  ('Education',),
#  ('Comic Book',),
#  ('Shop Keeper',),
#  ('Underwater',),
#  ('Mahjong',),
#  ('Early Access',),
#  ('Pool',),
#  ('Medical Sim',),
#  ('Arcade',),
#  ('Aliens',),
#  ('Runner',),
#  ('Football',),
#  ('World War I',),
#  ('Well-Written',),
#  ('Casual',),
#  ('Dragons',),
#  ('Psychological',),
#  ('Precision Platformer',),
#  ('LEGO',),
#  ('Dungeon Crawler',),
#  ('Mining',),
#  ('Music-Based Procedural Generation',),
#  ('Life Sim',),
#  ('Sniper',),
#  ('Electronic',),
#  ('Rock Music',),
#  ('Birds',),
#  ('Automation',),
#  ('Cats',),
#  ('Psychedelic',),
#  ('Silent Protagonist',),
#  ('Fishing',),
#  ('RPG',),
#  ('Quick-Time Events',),
#  ('Software Training',),
#  ('Action',),
#  ('Software',),
#  ('Dark',),
#  ('Mouse only',),
#  ('Escape Room',),
#  ('Split Screen',),
#  ('Party Game',),
#  ('Co-op Campaign',),
#  ('Hero Shooter',),
#  ('Roguelike Deckbuilder',),
#  ('Remake',),
#  ('Design & Illustration',),
#  ('Cult Classic',),
#  ('First-Person',),
#  ('Card Game',),
#  ('Volleyball',),
#  ('Rugby',),
#  ('Point & Click',),
#  ('Spectacle fighter',),
#  ('Skiing',),
#  ('Coding',),
#  ('Level Editor',),
#  ('Hex Grid',),
#  ('Space Sim',),
#  ('Assassin',),
#  ('Spaceships',),
#  ('ATV',),
#  ('Open World',),
#  ('Hidden Object',),
#  ('VR',),
#  ('Cycling',),
#  ('Souls-like',),
#  ('Intentionally Awkward Controls',),
#  ('America',),
#  ('Steampunk',),
#  ('Realistic',),
#  ('Hentai',),
#  ('Space',),
#  ('Adventure',),
#  ('Sci-fi',),
#  ('Dystopian',),
#  ('Villain Protagonist',),
#  ('Ninja',),
#  ('Game Development',),
#  ('Programming',),
#  ('Fox',),
#  ('Outbreak Sim',),
#  ('Vampire',),
#  ('Movie',),
#  ('Idler',),
#  ('Foreign',),
#  ('Elf',),
#  ('Time Attack',),
#  ('2D',),
#  ("Beat 'em up",),
#  ('Old School',),
#  ('Action RTS',),
#  ('Transhumanism',),
#  ('Utilities',),
#  ('Resource Management',),
#  ('Story Rich',),
#  ('Bullet Time',),
#  ('Open World Survival Craft',),
#  ('Motorbike',),
#  ('Solitaire',),
#  ('Baseball',),
#  ('Illuminati',),
#  ('Local Co-Op',),
#  ('Extraction Shooter',),
#  ('Addictive',),
#  ('Games Workshop',),
#  ('Relaxing',),
#  ('Classic',),
#  ('Moddable',),
#  ('Replay Value',),
#  ('Voice Control',),
#  ('Hockey',),
#  ('Simulation',),
#  ('Horses',),
#  ('Faith',),
#  ('Masterpiece',),
#  ('RTS',),
#  ('Agriculture',),
#  ('Logic',),
#  ('Swordplay',),
#  ('Minimalist',),
#  ('Hand-drawn',),
#  ('Metroidvania',),
#  ('Time Management',),
#  ('Nudity',),
#  ('War',),
#  ('Boss Rush',),
#  ('Grand Strategy',),
#  ('Feature Film',),
#  ('Wholesome',),
#  ('Minigames',),
#  ('3D Fighter',),
#  ('Ambient',),
#  ('Immersive',),
#  ('Third-Person Shooter',),
#  ('Mystery Dungeon',),
#  ('Futuristic',),
#  ('Arena Shooter',),
#  ('Party',),
#  ('Chess',),
#  ('Management',),
#  ('Mythology',),
#  ('Political',),
#  ('Western',),
#  ('Drama',),
#  ('Character Customization',),
#  ('Benchmark',),
#  ('3D',),
#  ('Linear',),
#  ('Nature',),
#  ('Dog',),
#  ('Investigation',),
#  ('Mature',),
#  ('Multiple Endings',),
#  ('Snooker',),
#  ('Lovecraftian',),
#  ('2D Platformer',),
#  ('Dinosaurs',),
#  ('Tennis',),
#  ('Mars',),
#  ('Dungeons & Dragons',),
#  ('Experience',),
#  ('RPGMaker',),
#  ('Hunting',),
#  ('6DOF',),
#  ('Based On A Novel',),
#  ('Instrumental Music',),
#  ('Noir',),
#  ('Lemmings',),
#  ('Rhythm',),
#  ('Archery',),
#  ('Hardware',),
#  ('Sokoban',),
#  ('Touch-Friendly',),
#  ('Tutorial',),
#  ('PvE',),
#  ('Tactical',),
#  ('Family Friendly',),
#  ('Narration',),
#  ('Platformer',),
#  ('VR Only',),
#  ('NSFW',),
#  ('Martial Arts',),
#  ('Philosophical',),
#  ('Time Manipulation',),
#  ('Procedural Generation',),
#  ('Building',),
#  ('Social Deduction',),
#  ('4X',),
#  ('Looter Shooter',),
#  ('Jump Scare',),
#  ('Emotional',),
#  ('Choices Matter',),
#  ('Football (Soccer)',),
#  ('Conversation',),
#  ('Physics',),
#  ('Supernatural',),
#  ('Sequel',),
#  ('Multiplayer',),
#  ('Difficult',),
#  ('Online Co-Op',),
#  ('Tactical RPG',),
#  ('Romance',),
#  ('Snowboarding',),
#  ('Anime',),
#  ('Real Time Tactics',),
#  ('Time Travel',),
#  ('Short',),
#  ('Heist',),
#  ('Superhero',),
#  ('Hacking',),
#  ('Loot',),
#  ('Creature Collector',),
#  ('Zombies',),
#  ('Basketball',),
#  ('Flight',),
#  ('Gore',),
#  ('Collectathon',),
#  ('Underground',),
#  ('360 Video',),
#  ('Traditional Roguelike',),
#  ('Stylized',),
#  ('Politics',),
#  ('Side Scroller',),
#  ('Unforgiving',),
#  ('Rogue-like',),
#  ('Tanks',),
#  ('Turn-Based Strategy',),
#  ('Real-Time',),
#  ('Stealth',),
#  ('City Builder',),
#  ('Skating',),
#  ('Bowling',),
#  ('Experimental',),
#  ('Music',),
#  ('FPS',),
#  ('Dwarf',),
#  ('Otome',),
#  ("Shoot 'Em Up",),
#  ('Fantasy',),
#  ('Top-Down Shooter',),
#  ('Puzzle-Platformer',),
#  ('Action Roguelike',),
#  ('Twin Stick Shooter',),
#  ('Turn-Based Tactics',),
#  ('LGBTQ+',),
#  ('Nostalgia',),
#  ('Magic',),
#  ('Web Publishing',),
#  ('Shooter',),
#  ('Singleplayer',),
#  ('Farming Sim',),
#  ('Epic',),
#  ('Great Soundtrack',),
#  ('Crowdfunded',),
#  ('Crime',),
#  ('Abstract',),
#  ('Trading Card Game',),
#  ('Documentary',),
#  ('Pinball',),
#  ('TrackIR',),
#  ('Narrative',),
#  ('Score Attack',),
#  ('Soccer',),
#  ('Battle Royale',),
#  ('Text-Based',),
#  ('JRPG',),
#  ('Naval Combat',),
#  ('Asynchronous Multiplayer',),
#  ('Mystery',),
#  ('Snow',),
#  ('CRPG',),
#  ('Turn-Based',),
#  ('Colorful',),
#  ('Interactive Fiction',),
#  ('Match 3',),
#  ('Mechs',),
#  ('PvP',),
#  ('Detective',),
#  ('Steam Machine',),
#  ('Cartoony',),
#  ('FMV',),
#  ('Reboot',),
#  ('Boomer Shooter',),
#  ('Electronic Music',),
#  ('Sandbox',),
#  ('3D Vision',),
#  ('Typing',),
#  ('Golf',),
#  ('Football (American)',),
#  ('Pirates',),
#  ('Asymmetric VR',),
#  ('Fast-Paced',),
#  ('3D Platformer',),
#  ('Cold War',),
#  ('Science',),
#  ('Competitive',),
#  ('MMORPG',),
#  ('Transportation',),
#  ('Turn-Based Combat',),
#  ('Board Game',),
#  ('Local Multiplayer',),
#  ('Sexual Content',),
#  ('4 Player Local',),
#  ('Hack and Slash',),
#  ('Soundtrack',),
#  ('Memes',),
#  ('Motocross',),
#  ('Modern',),
#  ('Bullet Hell',),
#  ('Rogue-lite',),
#  ('2.5D',),
#  ('Isometric',),
#  ('Top-Down',),
#  ('Grid-Based Movement',),
#  ('Artificial Intelligence',),
#  ('Combat',),
#  ('Economy',),
#  ('Perma Death',),
#  ('On-Rails Shooter',),
#  ('MOBA',),
#  ('Team-Based',),
#  ('Crafting',),
#  ('Tabletop',),
#  ('Cute',),
#  ('Diplomacy',),
#  ('Job Simulator',),
#  ('Colony Sim',),
#  ('Post-apocalyptic',),
#  ('Inventory Management',),
#  ('Dark Fantasy',),
#  ('Racing',),
#  ('Skateboarding',),
#  ('Word Game',),
#  ('Audio Production',),
#  ('Visual Novel',),
#  ('Combat Racing',),
#  ('Sports',),
#  ('Video Production',),
#  ('Beautiful',),
#  ('Cooking',),
#  ('Mod',),
#  ('Gun Customization',),
#  ('Kickstarter',),
#  ('Trains',),
#  ('Funny',),
#  ('Cozy',),
#  ('Clicker',),
#  ('Satire',),
#  ('Cyberpunk',),
#  ('Indie',),
#  ('Dark Humor',),
#  ('Driving',),
#  ('Female Protagonist',),
#  ('Alternate History',),
#  ('e-sports',),
#  ('Vehicular Combat',),
#  ('Voxel',),
#  ('Sailing',),
#  ('Fighting',),
#  ('2D Fighter',),
#  ('World War II',),
#  ('Dark Comedy',),
#  ('8-bit Music',),
#  ('Card Battler',),
#  ('Submarine',),
#  ('Survival',),
#  ('Pixel Graphics',),
#  ('Automobile Sim',),
#  ('Tile-Matching',),
#  ('Dynamic Narration',),
#  ('God Game',),
#  ('Roguevania',),
#  ('Puzzle',),
#  ('Conspiracy',),
#  ('Cinematic',),
#  ('Capitalism',),
#  ('Gaming',),
#  ('Farming',),
#  ('Jet',),
#  ('Episodic',),
#  ('Character Action Game',),
#  ('Spelling',),
#  ('Action-Adventure',),
#  ('Strategy RPG',),
#  ('Class-Based',),
#  ('Dice',),
#  ('Military',),
#  ('Walking Simulator',),
#  ('Medieval',),
#  ('Comedy',),
#  ('Trivia',),
#  ('Cartoon',),
#  ('Gambling',),
#  ('Political Sim',),
#  ('Auto Battler',),
#  ('Blood',),
#  ('Animation & Modeling',),
#  ('Lore-Rich',),
#  ('Wargame',),
#  ('Naval',),
#  ('Choose Your Own Adventure',),
#  ('Immersive Sim',),
#  ('Vikings',),
#  ('Lara Croft',),
#  ('Violent',),
#  ('Cricket',),
#  ('Mini Golf',),
#  ('Massively Multiplayer',),
#  ('Parody',),
#  ('Nonlinear',),
#  ('Robots',),
#  ('Controller',),
#  ('Third Person',),
#  ('Horror',),
#  ('Real-Time with Pause',),
#  ('Exploration',),
#  ('Tower Defense',),
#  ('Trading',),
#  ('Batman',),
#  ('Free to Play',),
#  ('Retro',),
#  ('Destruction',),
#  ('Rome',),
#  ('Warhammer 40K',),
#  ('Survival Horror',),
#  ('Boxing',),
#  ('Co-op',),
#  ('GameMaker',),
#  ('Deckbuilding',),
#  ('Dating Sim',),
#  ("1990's",),
#  ('Action RPG',),
#  ('Base-Building',),
#  ('BMX',),
#  ('Photo Editing',),
#  ('Wrestling',),
#  ('Gothic',),
#  ('Demons',)]

# %%
tag_insert_query = "INSERT IGNORE INTO tags (name) VALUES (%s)" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor()   
    
    cursor.executemany(tag_insert_query, tag_tuples)
    mydb.commit() 

except Exception as e:  
    print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "tags", tag_tuples)
# Out:
# All data was inserted successfully: 453 out of 453

# %% [markdown]
# ### Languages

# %%
supported_languages = steam_dataset['Supported languages'].apply(lambda x: safe_eval(x)).explode().dropna().unique()
audio_languages = steam_dataset['Full audio languages'].apply(lambda x: safe_eval(x)).explode().dropna().unique()
all_languages = set(supported_languages).union(audio_languages) 
all_languages
# Out:
# {'Afrikaans',
#  'Albanian',
#  'Arabic',
#  'Armenian',
#  'Azerbaijani',
#  'Bangla',
#  'Basque',
#  'Belarusian',
#  'Bosnian',
#  'Bulgarian',
#  'Catalan',
#  'Croatian',
#  'Czech',
#  'Danish',
#  'Dutch',
#  'English',
#  'Estonian',
#  'Filipino',
#  'Finnish',
#  'French',
#  'Galician',
#  'Georgian',
#  'German',
#  'Greek',
#  'Gujarati',
#  'Hausa',
#  'Hebrew',
#  'Hindi',
#  'Hungarian',
#  'HungarianPolish',
#  'Icelandic',
#  'Igbo',
#  'Indonesian',
#  'Irish',
#  'Italian',
#  'Japanese',
#  'Kazakh',
#  'Khmer',
#  'Kinyarwanda',
#  'Korean',
#  'Kyrgyz',
#  'Latvian',
#  'Lithuanian',
#  'Luxembourgish',
#  'Macedonian',
#  'Malay',
#  'Maori',
#  'Marathi',
#  'Mongolian',
#  'Norwegian',
#  'Persian',
#  'Polish',
#  'Portuguese',
#  'Portuguese - Brazil',
#  'Portuguese - Portugal',
#  'Punjabi (Gurmukhi)',
#  'Quechua',
#  'Romanian',
#  'Russian',
#  'Scots',
#  'Serbian',
#  'Simplified Chinese',
#  'Slovak',
#  'Slovakian',
#  'Slovenian',
#  'Sotho',
#  'Spanish - Latin America',
#  'Spanish - Spain',
#  'Swahili',
#  'Swedish',
#  'Tamil',
#  'Tatar',
#  'Telugu',
#  'Thai',
#  'Traditional Chinese',
#  'Turkish',
#  'Ukrainian',
#  'Urdu',
#  'Uzbek',
#  'Vietnamese',
#  'Welsh',
#  'Xhosa',
#  'Zulu'}

# %%
language_tuples = [(language,) for language in all_languages]
language_tuples
# Out:
# [('Traditional Chinese',),
#  ('Slovak',),
#  ('Urdu',),
#  ('Scots',),
#  ('Tamil',),
#  ('Punjabi (Gurmukhi)',),
#  ('Russian',),
#  ('Basque',),
#  ('Hausa',),
#  ('Portuguese - Brazil',),
#  ('Kyrgyz',),
#  ('Icelandic',),
#  ('Portuguese - Portugal',),
#  ('Romanian',),
#  ('Ukrainian',),
#  ('Telugu',),
#  ('German',),
#  ('Mongolian',),
#  ('Dutch',),
#  ('Macedonian',),
#  ('Hebrew',),
#  ('Kazakh',),
#  ('Danish',),
#  ('Croatian',),
#  ('Indonesian',),
#  ('Lithuanian',),
#  ('French',),
#  ('Quechua',),
#  ('Hindi',),
#  ('Galician',),
#  ('Czech',),
#  ('Kinyarwanda',),
#  ('Albanian',),
#  ('Malay',),
#  ('Hungarian',),
#  ('Thai',),
#  ('Latvian',),
#  ('Persian',),
#  ('Portuguese',),
#  ('Georgian',),
#  ('Khmer',),
#  ('Marathi',),
#  ('Swedish',),
#  ('Xhosa',),
#  ('Greek',),
#  ('Italian',),
#  ('Polish',),
#  ('Catalan',),
#  ('Maori',),
#  ('Bulgarian',),
#  ('Sotho',),
#  ('Filipino',),
#  ('Serbian',),
#  ('Slovakian',),
#  ('Slovenian',),
#  ('Luxembourgish',),
#  ('Vietnamese',),
#  ('Irish',),
#  ('Armenian',),
#  ('Japanese',),
#  ('Uzbek',),
#  ('Simplified Chinese',),
#  ('Arabic',),
#  ('Afrikaans',),
#  ('English',),
#  ('Welsh',),
#  ('Turkish',),
#  ('Igbo',),
#  ('Norwegian',),
#  ('Estonian',),
#  ('Korean',),
#  ('Tatar',),
#  ('HungarianPolish',),
#  ('Swahili',),
#  ('Spanish - Latin America',),
#  ('Finnish',),
#  ('Spanish - Spain',),
#  ('Belarusian',),
#  ('Bangla',),
#  ('Zulu',),
#  ('Bosnian',),
#  ('Azerbaijani',),
#  ('Gujarati',)]

# %%
language_insert_query = "INSERT IGNORE INTO languages (name) VALUES (%s)" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor()   
    
    cursor.executemany(language_insert_query, language_tuples)
    mydb.commit() 

except Exception as e:  
    print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "languages", language_tuples)
# Out:
# All data was inserted successfully: 83 out of 83

# %% [markdown]
# ### Games

# %%
game_batch_data = [] 

for _, row in steam_dataset.iterrows(): 
    game_batch_data.append( 
        (
            row['AppID'],  
            row['Name'],  
            row['Release date'], 
            row['Required age'], 
            row['Price'], 
            row['About the game'], 
            row['Achievements']
        )
    ) 

game_batch_data
# Out:
# [(20200,
#   'Alien Monster Bowling League',
#   '2008-10-21',
#   0,
#   19.99,
#   'Galactic Bowling is an exaggerated and stylized bowling game with an intergalactic twist. Players will engage in fast-paced single and multi-player competition while being submerged in a unique new universe filled with over-the-top humor, wild characters, unique levels, and addictive game play. The title is aimed at players of all ages and skill sets. Through accessible and intuitive controls and game-play, Galactic Bowling allows you to jump right into the action. A single-player campaign and online play allow you to work your way up the ranks of the Galactic Bowling League! Whether you have hours to play or only a few minutes, Galactic Bowling is a fast paced and entertaining experience that will leave you wanting more! Full Single-player story campaign including 11 Characters and Environments. 2 Single-player play modes including Regular and Battle Modes. Head to Head Online Multiplayer play Modes. Super Powers, Special Balls, and Whammies. Unlockable Characters, Environments, and Minigames. Unlock all 30 Steam Achievements!',
#   30),
#  (655370,
#   'Train Bandit',
#   '2017-10-12',
#   0,
#   0.99,
#   "THE LAW!! Looks to be a showdown atop a train. This will be your last fight. Good luck, Train Bandit. WHAT IS THIS GAME? Train Bandit is a simple score attack game. The Law will attack you from both sides. Your weapon is your keyboard. You'll use those keys to kick the living shit out of the law. React quickly by attacking the correct direction. React...or you're dead. THE FEATURES Unlock new bandits Earn Achievements Become Steam's Most Wanted ? Battle elite officers Kick the law's ass",
#   12),
#  (1732930,
#   'Jolt Project',
#   '2021-11-17',
#   0,
#   4.99,
#   "Jolt Project: The army now has a new robotics project, jolt. It's up to you to control it and ensure the success of the missions! There are 9 stages of taking the breath away with the right difficulty and good gameplay. Plus an insane way of survival! Fire missiles at cars, tanks, helicopters and turrets! The fun is guaranteed! Use your mouse to aim and shoot and take out the enemies! In this game you will have to be aware of the various enemies who will do everything to destroy your charges and prevent the success of your mission! Cartoon-style graphics are optimized and fun and generate an excellent gaming environment!",
#   0),
#  (1355720,
#   'Henosis™',
#   '2020-07-23',
#   0,
#   5.99,
#   'HENOSIS™ is a mysterious 2D Platform Puzzler where players are propelled into weird and visceral worlds as they take control of a small, droplet of water while overcoming obstacles and enemies throughout each level. The Player must venture through each world as it collects precious water tokens in order open the exit portal and restore vitality to its drought-ridden home world. Features: Traverse your way through 27 hand-crafted levels Unique player mechanics Battle menacing bosses across 3 distinct worlds* Original artwork &amp; animation Full controller support Localization support * Hidden world included!',
#   0),
#  (1139950,
#   'Two Weeks in Painland',
#   '2020-02-03',
#   0,
#   0.0,
#   'ABOUT THE GAME Play as a hacker who has arranged a deal with a gangster. That’s how the protagonist, Jack, is assigned a mission that should be accomplished in a specific timeframe, which he will find out soon enough. THE GAME’S FEATURES Spy on 4 senior managers within an organization to find out about their personalities. Manage the recruitment process in the organization to improve the work climate. Hack the candidates who want to get into the organization to make your job easier. Try to avoid having your physical health impacted negatively in the process. All of this while you enjoy an interesting story full of humor and action that evolves along with the game.',
#   17),
#  (1469160,
#   'Wartune Reborn',
#   '2021-02-26',
#   0,
#   0.0,
#   "Feel tired of auto-fight? Feel tired of boring numerical combinations? Let us try this amazing and exciting game! Right! Wartune Reborn is the super popular magic epic game as we know. Now, the magnificent magic epic game restarts, reminds you the classical plays and brings great experience. In Cloud City, you are going to maintains the Wartune movement, fighting the abyss monsters to protect the world from chaos. Don't be nervous! With protection of Dinah, Priestess of Light, you will have the power to absorb the chord, incorporate those forces without kings into your own ones, and make contract with and train apotheosis of Sylphs. You can improve yourself in a series of RPG adventures including instances battles, wild fighting, occupation and plunder. At the same time, you can run your own ligeance and castles and ally yourself with other players in the world who attack the Chaos. All of you are going to cooperate to protect the world from the control and destroy of Redoga Drake and bring the brightness back to Cloud City...... Enter Wartune Reborn to enjoy thinking of battles and playing the game! 1. RPG simulation, S- semi TBS battle, castles constructions, occupation &amp; expelling make you the best lords 2. Magical epic plots and original prominent symphony show the ancient and magnificent medieval chapter. 3. Military organization, runes and strategies contribute to super power. 4. Sylph awakening, skills and training, you will cooperate to beat BOSS. 5. Explore the magical world of the wild, jungles, deserts and snow mountains freely in the map of the vast outer city, to find mysterious ancient treasure. 6. Avatar system provides cool fashion, wings, mounts, weapon appearance with arbitrary combination. Wartune Reborn, Magical epic, Expect Heroes! Classical playing brings you amazing experience!",
#   0),
#  (1659180,
#   'TD Worlds',
#   '2022-01-09',
#   0,
#   10.99,
#   'TD Worlds is a dynamic, highly strategical game that challenges your skill. Build an impenetrable defense and get ready to plunge into a new, unknown world to uncover its secrets. In this bizarre universe, each attempt will be unique in its own way, which provides many hours of fun to play. Clear three completely different worlds from darkness, spread your influence everywhere. unique conditions in each game; losing is an important part of game progress. Each defeat reveals something new for you; dynamic storytelling: the more you play, the more you learn about the world; get random rewards after each level; tired of playing? Feel free to leave the game, next time you will continue where you left; experiment with different tactics; Twitch integration - play with your viewers.',
#   62),
#  (1968760,
#   'Legend of Rome - The Wrath of Mars',
#   '2022-05-05',
#   0,
#   9.99,
the streets fulfilling the orders issued by HQ, discover facts about the past of your Heroes and decide when to fight, and when to withdraw. SURVIVE THE UPRISING Learn all the strengths and weaknesses of your assigned team. Find the best combination of personnel, weapons and skills to overcome more and more lethal enemies thrown to quell the uprising. Fight your way through infantry, specialized troops, heavily armed units, special ordnance and armored vehicles. Make your choices in the many story infused events and live with their results. And don’t let the ever increasing ferocity and intensity of forces thrown your way stop you from your one goal. Turning your Heroes into survivors. Not victims. MAIN FEATURES Turn-based tactical rpg with characters of varying classes, and with skill and resource management in immersive WWII setting A deep tactical combat system with multitude of complementing skills, weapons and character abilities Character stories and backgrounds delivered through gameplay as well as numerous historical and fictional events happening under specific game’s circumstances Incredible replay value due to non-linear gameplay',
#   34),
#  (485000,
#   'Cthulhu Realms',
#   '2016-07-01',
#   0,
#   0.0,
#   "Star Realms has gone insane! Introducing Cthulhu Realms! Are you zany enough to play the crazier and creepier cousin of Star Realms? Download and play today to find out why Cthulhu Realms is so crazily addictive! How to Play the Game: In Cthulhu Realms, each player tries to drive their opponent insane or have more sanity than their opponents when the deck runs out. Each player starts the game with a small deck comprised of initiates, goons and followers. Five cards from the deck form a row of available cards on the table; with more than two players, place three available cards between each pair of players. Each turn, you start with five cards in hand, playing those cards in order to put locations into play, boost your own sanity or reduce that of others, collect conjuring power to acquire new cards, and remove cards from the game. You can use the power of your locations once each turn. At the end of your turn, discard any cards still in hand and all entities and artifacts that you played. If you lose all of your sanity, you're out of the game. If you're the only one at the table who's still sane, you win. Otherwise, the game ends when the deck runs out and whoever has the most sanity wins. Darwin Kastle is the designer of the popular Star Realms Deckbuilding Game, and with the digital release of Cthulhu Realms, he once again provides tons of playability for free, and a one-time upgrade to be able play with your friends and more on any device. Free Version • Drive people insane everywhere - play across devices. • Crazyily addictive deckbuilding game. • Tutorial teaches you how to make people crazy in minutes. • Awesome, comical art. • Play VS the AI. • 8 silly campaign missions! Full Game Additional Features • Play the AI on 2 different difficulty settings. • 8 more fun campaign missions. • Battle your friends face to face with Pass and Play. • Play against many more opponents online. • Challenge a friend to online Player v Player combat Cthulhu Realms is also available at your local game store as a physical card game from Tasty Minstrel Games.",
#   0),
#  (1620060,
#   'Clockwork Dungeon',
#   '2021-08-27',
#   0,
#   1.99,
#   'Treasure awaits within the dungeon! There are no guards... but the dungeon was built to protect itself until the end of time, its traps operating like clockwork! Your task is to get the gold and escape alive! The order in which the traps trigger is known in advance, so it is up to you to plan your path to the treasure... and then back again to the exit... Good luck and beware of the traps. Deadly Spikes Flaming Walls Breaking Floors ...And more… to be discovered! FEATURES: 20 hand crafted levels Solve unique puzzles harder than they initially seem Increasing difficulty and complexity A secret hidden bonus level Achievements Full original soundtrack',
#   25),
#  (825930,
#   'Royal Battleships',
#   '2018-04-06',
#   0,
#   2.99,
#   "Sometimes there is nothing better than a tourney in a classic battleships game. You can see a beautifully designed sea battle, familiar to those from your school times. You have to play against the computer and you need to destroy all enemy ships before yours are destroyed. Features: Very beautiful graphics Classic game You can compete with your friends Supporting all platforms (Windows, Mac, Linux, SteamOS) A lot of Steam achievements The gameplay is very simple. When you are preparing for the match, there are some ships of different sizes - from simple battle boat to a huge battleship. You put them on the battlefield and nobody else than you knows their location. Of course, don't know the enemy's positions neither. Thus the battle is absolutely fair and you can only guess where to shoot. Of course, if you hit a battleship for the first time, it will be easy to find the other tiles. However, finding all enemy boats can be a real challenge. Do not forget that this game is not about speed, but about variety, so that the battle is always different. The game perfectly develops strategic thinking and will be useful to both adults and children. In addition, it will help you to plunge into nostalgia for simple classic games.",
#   19),
#  (1454010,
#   'Diary of Lucie',
#   '2020-11-25',
#   0,
#   12.99,
#   "Diary of Lucie is action-roguelite game made with RPG Maker. In addition to simply avoiding the enemy's barrage, strategically use the enemy's bullet to make the battle situation advantageous! In Roguelike mode, Lucie can get 2 types of weapons, 4 types of skills, and abilities with various special effects. Choose the best weapon for you! A bow with high utility from a distance, a sword with a quick melee combo ability, or a wand specializing in magic attacks may be good for you. Every skills has a place to use. Combine your skills as effectively as possible to create a playstyle that suits you. Features of the game -Hard Difficulty : Diary of Lucie is basically designed with Hard difficulty. At first, you will die soon, but you will see yourself and Lucie getting stronger and stronger. -Roguelite : Each time, skills, items, and enemies are all randomly generated. Strategically take care of what you need as quickly as possible. If you're lucky, you can even get a powerful weapon and start from the beginning. Of course you will die soon, but don't be disappointed As you die, your experience and Lucie's abilities will increase more and more! -Variety of play by weapon : Every weapon has its own special ability. Sometimes, depending on the enchantment, the performance may change completely. -Various skill combinations : Skills are acquired at random each time, but you can also choose strategically to farm. Combine various skills effectively. -Cute character motion : Enjoy smooth motion and various dot-graphic motions. -Hidden Story : Don't give up on the challenge! As you progress through Roguelike mode, the story between Lucie's past and the characters will naturally reveal little by little.",
#   0),
#  (22670,
#   'Alien Breed 3: Descent',
#   '2010-11-17',
#   0,
#   9.99,
#   "Alien Breed™ 3: Descent is the final explosive chapter in the Alien Breed™ series, and is a science fiction arcade-shooter with an epic story, swarms of highly intelligent alien enemies, high-impact weapons and stunning environments, developed using Epic Games' Unreal® Engine 3. Descend into hell and once again take control of the hero, Conrad, the ship’s Chief Engineer, in his last stand against the savage alien horde. While the doomed vessel, the Leopold, and the alien space craft plunge deeper into the planet’s atmosphere, with an icy ocean promising a watery grave, you have just hours to defy a grisly death and survive the alien onslaught for the final time. As you struggle deeper into the sinking alien ship, through the freezing waters flooding every corridor, the horrifying truth surrounding the existence of the Breed is finally uncovered… In addition to the thrilling conclusion to the single-player campaign and the relentless and competitive “Survivor” modes, the game offers action-packed, two-player online co-operative battle modes. Key Features Alien Breed™ 3: Descent - The stunning final chapter in the Alien Breed™ trilogy - an action-packed mix of arcade-shooter, survival-horror and tactical weapons upgrades and customisation. The final descent into hell! NEW - Set pieces – battle the breed through flooded levels and hull walk sections. NEW – Third-person action - take control of the hero, Conrad, in the new action-packed, third-person, sections. NEW – Fight the last stand armed with powerful new weaponry: The Project X is a ‘BFG’ that vaporizes everything it comes into contact with. The Electro-Link gun fires bolts of electricity and also sends chain lightning to damage nearby enemies. NEW – Survive new alien enemies – the ‘Electro-shocker’ and dramatic encounters with the final horrifying bosses. Epic single-player Story mode – The final chapter in the single-player campaign mode that concludes the thrilling narrative of the game through huge and challenging environments, including the new research lab level. Single-player Survivor mode – Resist endless waves of intense alien horde attacks in specifically designed arena environments. Single-player Free-play mode – A single-player challenge mode – beat your high score on a previously completed campaign mission. Two-player Co-operative play mode – Work together to defeat the alien horde across three specially customised assault maps for two players online. Two-player Co-operative Survivor mode – Join forces online and try to survive three specifically designed arena environments. Get competitive and challenge others online to beat your survivor abilities on the extensive Leader-boards. Additional Online features – Quick Match/Create Game/Friends Lists/Voice Chat/Leader-boards/Steam Achievements/Co-operative Achievements. Upgrades shop – Search fallen comrades and lockers to accumulate cash, and then tactically spend it on weapons/kit upgrades in the in-game shop. Playable demo/trial – A purpose-designed, action-packed free sample section of Alien Breed™ 3: Descent, called ‘The Prologue’, which also features a time-limited Survivor mode map.",
#   13),
#  (1330820,
#   'Hunting Unlimited 3',
#   '2020-11-06',
#   0,
#   9.99,
#   "When it comes to hunting, there’s nothing more real! Travel throughout the United States, Canada and Zambia to lock your sights on the prey of a lifetime. Unique action-packed missions will get your quarry running and your heart pumping. Track the quarry of your choice: White-tailed Deer, Mule Deer, Pronghorn, Buffalo, Elk, Grizzly, Moose, Mountain Goat, Mountain Lion and Wild Boar. Travel the rough terrain on foot, horse and ATV to search out and bring home that prized trophy. Explore the rugged landscapes of Alberta, Canada, Arizona, Maine, Oregon, Tennessee. Take the hunt to the harsh Zambian landscape to track down Lions, Elephants and Kudu. Perfect your shot at the Target Range before the big hunt. Track your quarry in 50+ action-packed mission challenges or roam the landscape in Free Hunt mode. Experience your perfect shot from a bullet's view with the enhanced Bulletcam. Pick the perfect tools for each of your hunts, selecting from over 30 weapons and accessories. Design your ultimate hunt using Hunting Unlimited 3’s in-game Mission Editor, then trade with your huntin’ buddies via email.",
#   0),
#  (346560,
#   'Hero of the Kingdom II',
#   '2015-02-20',
#   0,
#   7.99,
#   'Sail to the farthest islands to save your sister and defeat pirates. You and your sister had finally found a safe haven in a small fishing village. But more troubles came soon after that. The threat of an unstoppable crew of pirates spread its shadow over the entire kingdom. Your beloved sister was kidnapped by the pirates and taken far away to lands unknown. You have no choice but to embark on a journey to save her. You must be brave. You will travel to the end of the world, helping people, fulfilling quests, learning valuable skills, and finding hundreds of useful items. Explore a beautiful country and sail to far islands. Help people and fulfill many interesting quests. Learn skills such as fishing, hunting and gathering. Find hundreds of useful hidden items. Reach up to 48 achievements.',
#   48),
#  (1097880,
#   'Super Naughty Maid 2',
#   '2019-06-20',
#   0,
#   9.59,
#   "Story Leona, your cute and lewd maid is back for more in Super Naughty Maid 2! With her services coming to an end, she wants to see how her beloved master has improved as she puts him to the test. Features Fully animated artwork brings Leona to life. Improved animation and quality that really shows off the realistic softness of each motion. Multiple scenes and positions to choose from as well as new variations from the previous game. Over 60 minutes of recorded voice. Listen to Leona's perverted thoughts with the lewd voice function. Optional English subtitles",
#   0),
#  (1362670,
#   'Khio',
#   '2020-07-24',
#   0,
#   9.99,
#   'Explore and fight through the desolate frozen wilderness of KHIO and maybe you can piece together your forgotten past and that of the world itself. Gather resources to build tools and camps to stay warm and safe, but always be on guard, no raider will spare you even a moment in the heat of combat. In this winter wasteland, there is only one law, survival of the strongest. Discover different areas from a past civilization Solve puzzles to discover the true reason you were brought here Hunt and trap animals for food Gather resources to craft tools and weapons Stay warm and cook food by starting a fire Build a camp by constructing walls around your campfire Keep your loot secure by adding defenses around your camp Watch out for raider attacks Seek revenge by burning raider camps and stealing their loot Shootdown drones for better weaponry',
#   0),
#  (290870,
#   'Steam Squad',
#   '2016-07-28',
#   0,
#   17.99,
#   'Steam Squad - tactical wargame, where gameplay takes place at the alternative universe with steampunk details during the times of the Great War amongst colorful anime like settings as if drawn by Miyazaki himself. Game is posing a question what if? What if Tianxian Empire was able to colonize Siberia before Russia did and later had started war to extend its ownership over the rest of Europe and America? Players acting for the 3 of the world superpowers - Britain, Tianxia and the Holy Roman Empires have teams of up to 8 units equipped with guns and machinery of the times of WWI in order to complete 30 tactical missions. For instance, you can be asked to capture an area, defend a lodgement or a person, attempt to sabotage, etc. To succeed in the game, players must: Equip their teams according to the chosen strategy - select the right units, ammunition and armory for the mission; Read mission tactical maps; Lead units in the smart way and accurately - they are so easily killed and you have only few of them; Key Features Realisticity and complexity - actions in the game are driven by solid physic based combat mechanics and this is what it makes to be similar to the classics of table games - Warhammer, Infinity the Game; Possibility to use its own and take over enemy equipment - tanks, cannons and mortars; Possibility to equip units according to the tasks of the missions and your preferences; Original weaponry that is similar to the one used during the times of Great War; Battlecam with a depth of field effect and nice color correction, that gives an old film feeling; Beautiful settings as if drawn by Miyazaki himself; Nice little perks like - destroyable environment, interactive fauna and melee weapons; We sincerely want you to enjoy Steam Squad as we tried hard to make it interesting. Your support and feedback is vital for us as they help us to improve and make game even better.',
#   32),
#  (575760,
#   'Project: R.E.B.O.O.T 2',
#   '2017-01-27',
#   0,
#   2.99,
#   "Meet the continuation of the hardcore platformer Project: R.E.B.O.O.T! You have to play for the intelligent robot, created by the best scientists for the annual tournament 'Project: R.E.B.O.O.T'. The best minds from all the planets are programming their robots each year, which must pass 30 challenging levels, equipped with deadly traps and various obstacles. In the game you expect sea hardcore and fun, as well as new, unique locations and a variety of levels. Also do not forget that your main goal to reach the end and prove to everyone that you are the best!",
#   0),
#  (434030,
#   'Aerofly FS 2 Flight Simulator',
#   '2017-11-20',
#   0,
#   37.49,
#   "Aerofly FS 2 lets you explore the world of flying in a quality never seen before. Fly a large selection of highly detailed aircraft or a helicopter with fully animated and interactive 3D cockpits. Aerofly FS 2 is a next generation flight simulator open for add-ons and sets a high value on realistic flight physics, highly detailed aircraft and a stunning, photo realistic scenery. World wide coverage of elevation data and aerial images is included with Aerofly FS 2. At the same time, Aerofly FS 2 features an intuitive user interface and requires virtually no training time. Take your seat in the cockpit and enjoy flying over the famous Golden Gate Bridge or visit Alcatraz Island. Learn the basics of flying at our flight school or jump right into the captain's seat and land the majestic 747 at one of the busiest airports of the world. FEATURES 22 aircraft included: - A320 - B737-500 - B747-400 - B777-300ER - C172, Baron 58 - EC135 and Robinson R22 Beta II helicopters - F-15, F-18, Aermacchi MB-339 - King Air C90 GTx, Learjet 45 - Extra 330, Pitts S-2B biplane, Bücker Jungmeister - Corsair F4U, P-38 Lightning, Sopwith Camel - ASG 29 and Swift S1 gliders - Dash-8 Q400 (available as free DLC) Highly detailed and interactive 3D cockpits Adjustable cockpit lighting at night time Realistic flight physics Interactive Flight school for learning the basics of flying High resolution aerial images and over 200 airports for the South West of the United States World wide elevation and aerial images Display terrain features like mountains, lakes and cities for easy VFR navigation Route editor for easy flight planning Adjustable time of day Adjustable wind, clouds, visibility, thermal activity and turbulence Replay system Different view modes Support for multiple joysticks, throttle units, rudder pedals and more TrackIR support Full Oculus Rift VR support and full Oculus Touch controller support HTC Vive VR support and full Vive Controller support Support for Saitek Multi Panel, Radio Panel, Switch Panel and Saitek TPM",
#   0),
#  (810740,
#   'Turtle Lu',
#   '2018-03-22',
#   0,
#   2.99,
#   "Turtle Lu Turtle Lu is an old-school Action-Adventure game, Explore immense 2D Zones. Day after day, Lu watched creepy little caterpillars crawl past his window. Everywhere. Like the pitter patter of birds on a tin roof, the squirming sensation of moles crawling under the floor. The days flew by, each like the one before, monotonous. Lu lay down with the sunset every night, and awoke to the cock-a-doodle doo of the rooster outside every morning. The months passed by, the spring rain, autumn sun, leaves of fall and now\x85snow is falling on the roof. Lu curled up in his shell and fell into a long, deep sleep. Winter was as it always is, and soon the first rays of the sun broke through the dirty, cobwebbed window. 'It looks like it's time to wake up ' he thought, opening his heavy eyes. As he crept outside his house, he was in for a big surprise. The little caterpillars had grown into giant, dangerous Monsters! Huge, angry bees circled around his home, stingers ready to\x85well, sting! Mad urchins darted from house to house, destroying everything in their paths with fearsome needles! 'This outrage must be stopped!' Lu exclaimed as he set out on his perilous journey\x85 FEATURES : - Beautiful, realistic graphics. - Various levels. - Pleasant sound effects and music.",
#   0),
#  (2073470,
#   'Kanjozoku Game レーサー',
#   '2022-07-16',
#   0,
#   5.99,
#   'Kanjozoku Game レーサー : 90s Osaka Kanjo Illegal street racing. Feel like an street racer and drive on japanese autobahns. True 90s and 2000s JDM Cars to drive and tune. Engine Tuning: Internals, Turbochargers, ECU, Fuel, Intake, Exhaust, etc. Engine Swaps: 2JZ, RB26, VQ35, 4AGE, B16B, 13B, LS3, SR20, CA18, and much more! Body Tuning: Bumpers, Hoods, Fenders, Lights, etc. Suspension Tuning: Wheels, Rims, Tyres, Camber, Coilovers, Spacers etc. Load custom vinyls/liveries to the car. Online Races: Time Attack, Minimum Speed, Do not Crash, Avoid Traffic, etc. Online Car Meets and Hotspots. Drift with RWD and AWD cars. High Speed Police Chases. Rating system: Avoid traffic at high speeds, complete races, escape police chases, play online and PvP with someone else to gain more rating.',
#   0),
#  (589250,
#   'PowersVR',
#   '2020-10-10',
#   0,
#   9.99,
#   "PowersVR lets you be the caped crusader from comic books. Featuring a cast of colorful heroes, you'll get to test out their unique superpowers in Metropolis. Compete in challenges, unlock all superpowers, fight enemies and discover hidden collectibles. With more heroes and challenges yet to come! Metropolis City is a giant VR sandbox, filled with interesting locations and enemies to face. Follow the beams of light to discover new heroes with all new abilities, some beams will lead you to a challenge. Have the right hero? A section of the map becomes an isolated activity in which you compete for a high score! Secret collectibles are scattered in every nook and cranny, gathering them will unlock all sorts of artwork in the Gallery.",
#   4),
#  (677880,
#   'Draw Your Game',
#   '2017-08-10',
#   0,
#   4.99,
#   "“I wish I could make my own video game.” Who among us hasn't thought that at some point? Draw Your Game is a user-friendly application allowing anyone and everyone to create their own video game in a few quick steps: ▶ Draw your game's world on a piece of paper, using four different colors (black, blue, green and red). ▶ Use the 'Draw Your Game' app to take a picture of your drawing. ▶ Wait 10 seconds, while Draw Your Game transforms the drawing into a game. ▶ Play your game, with a character that you can control. ▶ Share your creation with other Draw Your Game users. Four different colors to create the world of your choosing: ▶ Black for stationary floors/ground; ▶ Blue for movable objects that the character can push around; ▶ Green for elements that the character will bounce off of; ▶ Red for objects that will destroy the character or the blue objects. Draw Your Game allows you to create an infinite number of worlds, either on the same sheet of paper or by adding new sheets, one after the other, to create a real story line. There are two available modes: ▶ “Create” mode, to create your own worlds; ▶ “Play” mode, to play in the worlds created by the community, either in “campaign” mode (worlds selected by our team), or in “catalogue” mode, where you can use search criteria to choose a world yourself. There are several ways to play the different worlds, at the creator's choice: ▶ “Escape”: the character must find a way off the paper to escape and win the game; ▶ “Destruction”: the character must push blue objects into red ones to destroy them. Our teams approve each new world before releasing it to the community, and a rating system is used to rank the top worlds against one another. [] ▶ Use fairly wide felt-tip pens. ▶ Choose vivid colors. ▶ Take pictures under good lighting.",
#   43),
#  (1294780,
#   'Pathfinders: Memories',
#   '2021-02-16',
#   0,
#   2.99,
#   "Pathfinders are eager to know more about human History. They have studied different civilizations of the past. With the support of the scientist Albert New, they travel through space and time, visiting these ancient people in person. Their objective is to collect relics from each civilization and create a museum of human memories. To achieve this, they will have to go through dangerous paths, facing obstacles, entrapments, and enemies. Your role is to memorize these obstacles and draw a safe path for them. Is your memory sharp enough to do that? Six different civilizations to visit, and three levels of difficulty. Checkpoints and flags can be used as markers to help you memorize the path. But you will earn a bonus if you don't use them. You can earn optional coins in each level by going through more complex paths.",
#   60),
#  (1342850,
#   'Bright Days in Quarantine',
#   '2020-07-18',
#   0,
#   1.99,
#   "It is hard to adapt to such drastic changes to our daily lives in a world where most of us need to stay at home to help curb a virus pandemic. Keeping a house organized during quarantine can be difficult, especially when you have some remote work to do too. But don’t freak out. It's all about dividing the household chores between all family members.. When is time for one to work, is time for you to clean. But wait! In this all of a sudden hurricane of housework and remote work tasks, the only thing you can do is revisit old hobbies and find joy in the small things. Otherwise, you go insane! Let's find joy too in this frenetic shelter simulation game. All you have to do is to take great care of the house, doing all the scheduled household chores in a way that you still have some spare time. Through 10 phases with increasing levels of difficulty, sweep the floor, dust the furniture, put the trash away, do the laundry, and make sure the fridge is always full! But remember, after doing all the chores, you need to dedicate some time to the little joys available in your new routine BEFORE the clock strikes. If you don’t, you go insane, and it’s Game Over. It’s really hard to finish all the scheduled chores before the clock strikes. But between each cleared level, let’s find little pleasures in things that have passed unnoticed through your days before. And don't forget to join our Discord server to be up to date with the development of our games, meet the developers and have early access to screenshots, videos and demos of your future projects!",
#   10),
#  (1177420,
#   'Uncle Neighbor',
#   '2020-06-19',
#   0,
#   13.99,
#   'Neighbor Uncle/UncleNeighbor: This is a love simulation game. You can play as a newcomer to the town starting a new life and date the 12 uncles The 18R-DLC has now been updated for 12 uncles.730+18R-CG About Uncle The Mysterious Man of the Forest: Albert Hanging redheaded man: Alex Baron, the elfish tinkerer. Cold President: Benson The careful and gentle doctor: Blair Mature Farm Uncle: Gene A somewhat vicious-looking athlete: Giles Annoying cops? : Kane Very enthusiastic florist staff: Marcos Exercise loving fitness instructor: Nick Lovely salesman: Quinn Somewhat shy teacher: Ron About the game 12 uncles can date. Simple game operation. There are seven main plots and three hidden plots for each uncle. Each uncle has a separate interactive mini-game. 300 plot illustrations. instagram：Libing_hua twiter:@LiBing_Hua',
#   73),
#  (793990,
#   'Dupio',
#   '2018-03-06',
#   0,
#   11.99,
#   '«Dupio» — is a fast and challenging non-stop arcade, with minimalistic gameplay. You must play contemporaneously both hands. The game has two screens with purple main characters. The right character is controlled by the mouse.The left hero controlled by keyboard. Avoid red spikes and collect the green circles, survive as long as possible and break your own record. |CONTROL OF THE RIGHT HERO| ● Mouse |CONTROL OF THE LEFT HERO| ● [W] - Move Up ● [S] - Move Down ● [D] - Move Right ● [A] - Move Left produced by',
#   22),
#  (1727670,
#   'Home Office Tasker',
#   '2021-09-08',
#   0,
#   0.99,
#   "You no longer need to go to special applications or use cluttered websites to track your plans, HO Tasker is always open on your desktop, you can bring it on top of all other applications, minimize and expand it in 1 click and never miss a task or deadline again. Programs like this exist for you not to forget about your plans, but what if you forget to look at your to-do list? We have a solution! HO Tasker launches together with the system and is displayed on top of all applications, no unnecessary actions! Turn your PC on and immediately see your goals for the near future. HO Tasker is the best option for your home office! Our app works without live internet connection, and it's easier to figure it out than finding your missing sock.",
#   0),
#  (955490,
#   'Terror In The Atomic Desert',
#   '2019-03-22',
#   0,
#   2.99,
#   "It came from the 1950s! Terror straight out of the Atomic Age explodes onto your computer screen in this homage to 'So bad it's bad' creature flicks such as The Beast of Yucca Flats and Eegah . Your trip down Route 66 quickly turns into a nightmare as local tales of a deadly race of radioactive beast men turn out to be more fact than myth! Match wits with the evil Dr. Arcturis as you race to put a stop to his dastardly experiments. Will you have what it takes to stop Earth from falling into the fiendish clutches of the saucer men from outer space? The choice is yours in 'Terror of the Atomic Desert' . Solve puzzles, evade monsters and match wits with local characters as the choices you make will lead to one of many possible endings. Key Game Features: • First Person Adventure/Puzzle Gameplay • Explore Your Environment on Foot or by Car • Uncover Lore and Interact With Local Characters • A Plot Inspired by 1950s Monster Movies • The first game ever to be presented in TERRORAMAVISION!",
#   11),
#  (552350,
#   'Unhappy Ever After',
#   '2017-01-20',
#   0,
#   0.99,
... and that’s just the start. Since its launch, DogFighter has been updated on numerous occasions. As well as the usual bug fixes and polish we have introduced... Joystick Support Weapon and Control completely rebalanced A new map, new co-op game mode “Wolf Pack” and the new craft; The Mongoose. Configurable Xbox Controller Support Take to the skies and deal lead death to your enemy using a state-of-the-art flight model that gives players unprecedented command of DogFighter’s craft. Complete control of the craft, combined with easily executed advanced manoeuvres such as the Barrel Roll, give DogFighter players the tools they need to master the skies. With environments built to both slay and save you, the environments in DogFighter offer the player a more interactive experience than is usual for the genre. Players can enjoy piloting their craft down mining tunnels, through pyramids and active volcanoes, in environments designed to deliver a more varied, more interactive gaming experience. Fly low, fly fast!",
#   29),
#  (1195610,
#   'March Of Soldiers',
#   '2020-07-01',
#   0,
#   1.99,
#   "March Of Soldiers is a real time strategy single player , It is a military game based on the player's skill and the strength of his financial economy",
#   0),
#  (1095380,
#   'Bepuzzled Kittens Jigsaw Puzzle',
#   '2019-06-11',
#   0,
#   1.99,
#   "This game is great for kitten lovers who like their cats in cute or funny poses! 107 Puzzles! User friendly User Interface 'Magnetic' puzzle pieces to make life easier Calming music What more do you need and at such great value!",
#   0),
#  (1158910,
#   'Dream Detective',
#   '2019-12-04',
#   0,
#   7.99,
# ...
#   "Shortly after moving into a creepy mansion in Louisiana, Sara Lawson is struck with tragedy when her husband mysteriously disappears. Sara’s daughter, Magnolia, believes her father was kidnapped by the ghost of a vengeful pirate seeking to protect his lost fortune. With the locals terrified of the pirate’s curse, you are the family’s last hope. Only a Master Detective with incredible Hidden Object skills can locate Marcus Lawson in Mystery Case Files: 13th Skull! This is a special Collector's Edition release full of exclusive extras you won’t find in the standard version. The Collector’s Edition includes: Bonus gameplay Stunning soundtrack Built-in Smart guide Behind-the-scenes concept art",
#   0),
#  (1769630,
#   "Grim Tales: Crimson Hollow Collector's Edition",
#   '2021-09-24',
#   0,
#   9.99,
#   "Elephant Games proudly presents the newest addition to the Grim Tales series! You've been called in to investigate the disappearance of a girl from a local boarding school. She was last seen with the mysterious Dorian Black. What starts as a simple investigation quickly takes a dark turn when you start falling victim to the magic of Crimson Hollow! Can you save the missing girl before it's too late, or will you fall to darkness? Find out in this spine-tingling hidden-object adventure! This is a special Collector’s Edition release full of exclusive extras you won’t find in the standard version. The Collector’s Edition includes: • The past and the present collide in the bonus game! • Learn more about the Gray family with the collectibles! • Enjoy music, wallpapers and other extras! • Try the integrated Strategy Guide! This is a Hidden Object Puzzle Adventure game, meaning a specific genre of story-driven, point &amp; click adventures. Throughout the game, players are tasked to find a list of objects hidden within a particular scene, and to occasionally complete various mini-games/puzzles.",
#   0),
#  (1898570,
#   'Square Knight',
#   '2022-04-30',
#   0,
#   1.99,
#   "Dodge obstacles, kill monsters, and collect coins. Use your coins wisely, you can level up, reset your status points, heal your HP or buy extra lives. Each level you up, you gain a status point. With these, you can choose which status you want to upgrade. There isn't a max level, by the way, you will level up how many times you can. Level up will help you A LOT .",
#   0),
#  (1821150,
#   'Connectify',
#   '2021-12-10',
#   0,
#   0.99,
#   'Welcome to the Connectify puzzle! The object of the game is to connect dots with the same numbers in a line without crossing other lines. For an easy game, a 3x3 playing field is available, and for fans of complex riddles there is a 6x6 field. If the field is larger, then there will be more points to connect. The game records your time to reward you with stars. If you complete the puzzle faster, than you can get more stars.',
#   68),
#  (1572220,
#   'Guns and Grapples',
#   '2021-11-01',
#   0,
#   11.99,
#   'Guns and Grapples is an action packed 2D precision platforming game featuring grappling hooks, gun fights, competitive leaderboards and epic boss battles. It uses force based physics and has several unique worlds each packed with different enemies, obstacles and challenges to master. Guns Grab your favorite gun and get ready to blast some enemies. Find over 10 different types of weapons from AK47s to flame throwers and Katanas. Tear up bosses as they fight back with their own explosive arsenal. Grapple Grapple your way around the levels to maximize your speed and reach the end in record time! Master grappling all kinds of different obstacles to showcase your skills. Speed Runs Race against the clock to get the fastest time for a level and compete with others via the online leaderboards.',
#   58),
#  (508710,
#   'Project Lounge',
#   '2021-07-09',
#   0,
#   0.99,
#   "Action takes place in player-made locations called Lounges which are made through the Lounge Editor by shaping terrain, setting time of day and placing various objects. The creator of the Lounge is able to set various permissions, privacy settings and invite others to visit. The owner and visitors are also able to populate the Lounge with various Interactable Objects that might just be a simple prop, an arcade machine. The only goal in Project Lounge is to have fun. Features: Lounge Editor - It's just like your usual map editor, with no object caps, just the way we love it on PC. The only limit is your system specifications. Interactable Objects - Drawboards for drawing, Arcades to play, Vinyls to play and more! Earn them by playing the game and receiving drops, even while you're in the Lounge Editor! Steam Inventory - Collect, trade and sell your Interactable Objects through Steam Inventory and show off what you've got to your friends and visitors alike. Steam Workshop - Do you know how to make 3D models? Or perhaps you compose music? If so, you can contribute to Project Lounge at Steam Workshop!",
#   7),
#  (1347130,
#   'Kinetic Edge',
#   '2021-02-05',
#   0,
#   7.99,
#   "Kinetic Edge is a physics game where you control a verity of shapes and objects to complete game modes and challenges. Kinetic Edge is designed to be a fun experience with friends or single player with plenty of game modes to try out. Race - Race with friends to get the best time or against others online. Arena - Knockout other players to make them lose points and stay in the green zone for maximum points gain. Maze - A procedurally generated maze that's different every time. First one out wins! . Golf - A physics crazy golf game you can play with friends. The Gauntlet - Super hard, 7 minutes, no checkpoints, 1 life. You will rage. Kinetic Edge will continue to get updates with requested modes and features. We are heavily community feedback driven so hop onto our discord and talk to us directly!",
#   2),
#  (1689930,
#   'Alley Cat Bowling',
#   '2021-07-23',
#   0,
#   1.99,
#   'Alley Cat Bowling is a crowd-play game designed around the classic ten pin bowling experience. Twitch streamers share the gameplay with their followers, interacting through chat and video. This is a gaming collision of bowling alleys and bowling balls and social video streaming at its finest, with a growing collection of playable bowling balls and bowling alleys. ****Twitch interactive game and twitch is required to play the game****',
#   0),
#  (910540,
#   'Moon River',
#   '2019-01-07',
#   0,
#   3.99,
#   "Moon River is a single player brain-twisting puzzle-platformer where the player is locked in the boundaries of the screen. When they cross any of its edges, they find themselves teleported to the opposite side of the screen. Across 7 levels , the player will face distinctly challenging sets of unique puzzles that get increasingly complex as the game progresses. Featuring rich, carefully-crafted art and an achingly beautiful soundtrack, Moon River is a game bound to burrow deep in any puzzle lover's mind. The game is playable on MacOSX , PC and Linux and is playable with xBox controller or keyboard .",
#   0),
#  (514920,
#   'Crash Wheels',
#   '2018-12-20',
#   0,
#   4.99,
#   'Crash Wheels - arcade racing with the physics of damage. The goal - to reach the finish line. ▪ 32 tracks ▪ Crash test level',
#   1224),
#  (1286030,
#   'Mad Bulldozer',
#   '2020-05-23',
#   0,
#   1.99,
#   "Hello, everyone,I'm glad to introduce our new game now:Mad Bulldozer. In the game, all kinds of bulldozers can spray flame, avoid or use varieties of props, and run crazily on the floating island of the mines. The player can control the bulldozer and knock the opponent down the floating island through collision, he will become more powerful every time he succeeds. You can customize your character and fight local enemies or fight with friends.The game supports 1-8 players (The multiplayer mode must have handle support, and the native game supports Xbox and PS4 handles).",
#   0),
#  (574180,
#   'A Clockwork Ley-Line: Zanei no Yoru ga Akeru Toki',
#   '2021-03-05',
#   0,
#   15.99,
#   "Remnants is a first-person open world survival sandbox which can be played in Single-player, Co-op locally or online in PVE and PVP modes. Tackle starvation, dehydration, thermal conditions, radiation poisoning, and toxic gas inhalation while trying to keep your sanity intact. Shack up, cook some chicken, and make friends or enemies as you discover, explore, learn, build, and develop your skills and strategies needed to survive. Current features: • Locally/Dedicated Hosted Single-player, Co-op, PVE and PVP modes. • Crafting - build a workbench and gather tools to increases your crafting chances • Vehicle construction - build and drive your own vehicles • Character skills and attributes - level up your character increasing your survival chance • Dynamic base building with material tiers • Dynamic weather - thunderstorms to fog to light rain • Weapon attachments - add red-dots and other useful mods to improve your weapons • Harvest and gather resources of all kinds • NPCs - Animals, Mutated Humans and Elites Enemy Types • Farming - Graden beds, compost bin and greenhouses • Cooking - Campfire to stove to pot and grill • Smelting - From stone to iron furnaces • World day-night cycle • Character hunger, thirst, stamina and thermal conditions • Temperature changes based on time-of-day and season • Character clothing and gadget system • Clan system that allows base and item access • Power construction - Connect to the power grid or build your own • Quest system - Find random loot quests around the island to earn rewards • Airdrops with 3 tier drop types • Random town and forest loot spawns • Radiation zones and underground bunkers • Blueprints and schematics - Find and learn how to craft and build new items • Research bench - Research base construction with your hard-earned points to further develop your base DISCLAIMER (PLEASE READ): Early Access is intended for those interested in supporting the project and participating in its continued development. You will most likely experience balancing issues, performance issues, latency issues, bugs and incomplete features. I will try my best to target latency issues to improve the quality of online gameplay the best I can. If you are looking for a complete gaming experience, I would recommend letting the game develop more before trying it out. There are YouTube videos of gameplay showing the current state of the game. Remnants has been solely developed by myself and I've always taken passion in working on it, I feel this is important to mention, so those considering purchasing Early Access can make a more informed decision. Goals of the project: The aim was to create a game that wasn't overly complicated but also provided a strategy-based experience that offered challenges and an overall goal and purpose to playing, rather than just looting and shooting. I wanted the game to be as balanced as possible in PvP while also offering decent PvE content. Remnants requires an internet connection to authenticate to steam!",
#   0),
#  (1680530,
#   '3AM',
#   '2021-10-29',
#   0,
#   9.99,
#   "Gerald wants to play! He also wants your soul! Open world exploration? Check! Spirits wandering the halls? Check! Shooting a livestream while fighting to stay alive? Um, Check! PLAY ALONE IN THE DARK AT 3AM FOR THE FULL EFFECT! CAN YOU GET ALEX OUT OF THIS FREE-ROAM OFFICE BUILDING BY 4AM? Alex is a social media live-streamer who is doing a livestream at a notorious toy factory office building situated close to his home. The building has been abandoned since the late 90's after 15 workers were found dead inside. Other companies have purchased the site over the years, but every time they try and renovate the building, the construction workers walk out and refuse to go back in. And so it's been left to rot. Take control of Alex, and try and find some answers. Once inside the building, he is trapped, and only has an hour to escape. Can you get him out in time and complete the 3AM Challenge? THIS IS NOT YOUR NORMAL HORROR CLICHE GAME WHERE YOU HAVE A CRAPPY FLICKERING FLASHLIGHT TO DEAL WITH! Due to Alex being a Live-Streamer, he uses modern technology to light his scene - a video light! This illuminates the room pretty well. And don't worry, you won't be hunting batteries either! This game goes for realism, and Alex knows how to prepare for his live streams! 😉 His batteries are charged and you'll either complete the game or die before his battery does! This game was inspired by Urban Exploring YouTuber's that go to abandoned buildings at 3AM to do, what's now known as, the '3AM Challenge'. As we all may know, 3AM is known as the devils hour, and is when paranormal activity is at its highest. Give it a try... IF YOU DARE!",
#   0),
#  (550600,
#   'Sphere Complex',
#   '2016-11-18',
#   0,
#   4.99,
#   'Roll, jump and boost a path through over 40 single player levels in Sphere Complex! Race against your self with ghost saves of your best times and compete via our online leader boards. Customize your game with multiple skins and colors or make your own maps using our in-game level editor! Enjoy 3 multiplayer game modes with up to 8 of your friends. You can go head to head in custom race maps, blow each other up in the battle arena or compete in Sphere League to score the most points for your team! However you play, you’re sure to have a ball!',
#   0),
#  (1492590,
#   "Let's Learn Japanese: Deluxe",
#   '2021-01-01',
#   0,
#   2.99,
#   "Have you ever wanted to learn Japanese? Are you studying Japanese and want to improve your skills? Then Let's Learn Japanese: Deluxe is for you! Designed for beginners and those learning Japanese, you will learn about the language basics, the 3 character sets, common words, and pronunciation. FEATURES Information for beginners to help get started. Hiragana and Katakana, Grade 1 through Grade S Kanji, and over 1700 common words. Spoken pronunciation for all words and Hiragana / Katakana. Stroke count and stroke order for every Kanji, Hiragana and Katakana. Test yourself using a flashcard or quiz interface. Choose which areas to test yourself on with recorded progress to indicate your retention. Excellent as a study aid. HOW IT WORKS The information pages will teach you the basics of the language and guide you on how to use the game to begin learning Japanese. The first step in learning Japanese is understanding the character sets (Hiragana, Katakana, and Kanji) and memorizing the symbols and words. This game contains all Hiragana and Katakana, common Kanji, and common words. Using Flashcard mode, you can begin to memorize the character sets and once you feel confident enough, can test your retention using quiz mode. There is also a review mode to view individual characters and words.",
#   4),
#  (1173870,
#   'Endless Knight',
#   '2019-12-31',
#   0,
#   6.99,
#   "Enjoy getting 'legless' with friends? Well, now you can cut each other's arms and legs off as you've always dreamed! Unlike 'proper' games, Endless Knight lets you continue to fight even after you have become separated from your limbs. Sadly the game does not permit the battle to continue after your friends actual death, for 'technical' reasons. Murdered and humiliated all your friends? That's okay, it happens to us all. Lucky for you, Endless Knight also features a not entirely 'tacked-on' single player experience, complete with an absurd story and songs! Slaughtered your way through the wonderfully crafted story mode? Take on the challenging but probably not impossible 'Final Fifty' mode for the ultimate climax of murderous satisfaction. Mmmmmmm. Completed 'Final Fifty'? Oh no, that's pretty much all there is. The mechanics of Endless Knight are different from what you’d find in most fighting games. There are no combos or 'special moves'. The focus is on reaction based blocking, as failure to block will have dire consequences. Due to this alternative focus, Endless Knight might take a few minutes to adapt to, but we hope that once you get the gist, you will love it as much as we do! Played alone or with friends, mastering Endless Knight can be jolly good fun!",
#   11),
#  ...]

# %% [markdown]
# Given that I am getting an "max_allowed_packet" byte error, instead of sending all my batches at once, I will send it in chunks

# %%
game_insert_query = """ 
    INSERT IGNORE INTO games (app_id, name, date_released, required_age, price, description, achievements) 
    VALUES (%s, %s, %s, %s, %s, %s, %s) 
"""

batch_size = 25 

for x in range(0, len(game_batch_data), batch_size): 
    batch_data = game_batch_data[x: x+ batch_size] 

    try: 
        mydb = check_sql_connection(mydb) 
        cursor = mydb.cursor()  
    
        cursor.executemany(game_insert_query, batch_data)
        mydb.commit()  
    
    except Exception as e: 
        print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "games", game_batch_data)
# Out:
# All data was inserted successfully: 89238 out of 89238

# %% [markdown]
# ### Games Extra Info

# %%
game_extra_info_batch_data = [] 

for _, row in steam_dataset.iterrows(): 
    game_extra_info_batch_data.append( 
        (
            row['AppID'],  
            row['Estimated owners'],  
            row['Notes'], 
            row['Average playtime forever'], 
            row['Header image'], 
            row['Website'], 
            row['Support url'], 
            row['Support email'], 
            row['Windows'], 
            row['Mac'], 
            row['Linux']
        )
    ) 

game_extra_info_batch_data
# Out:
# [(20200,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/header.jpg?t=1640121033',
#   'http://www.galacticbowling.net',
#   '',
#   '',
#   True,
#   False,
#   False),
#  (655370,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/header.jpg?t=1617500526',
#   'http://trainbandit.com',
#   '',
#   'support@rustymoyher.com',
#   True,
#   True,
#   False),
#  (1732930,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/header.jpg?t=1637149386',
#   '',
#   '',
#   'ramoncampiaof31@gmail.com',
#   True,
#   False,
#   False),
#  (1355720,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1355720/header.jpg?t=1639875115',
#   'https://henosisgame.com/',
#   'https://henosisgame.com/',
#   'info@henosisgame.com',
#   True,
#   True,
#   True),
#  (1139950,
#   '0 - 20000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: violence, general Mature Content.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1139950/header.jpg?t=1595003825',
#   'https://www.unusual-games.com/home/',
#   'https://www.unusual-games.com/contact/',
#   'welistentoyou@unusual-games.com',
#   True,
#   True,
#   False),
#  (1469160,
#   '50000 - 100000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1469160/header.jpg?t=1617078164',
#   '',
#   'https://7.wan.com',
#   'https://wartune@7road.com',
#   True,
#   False,
#   False),
#  (1659180,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1659180/header.jpg?t=1654195425',
#   '',
#   '',
#   'td.worlds.official@gmail.com',
#   True,
#   False,
#   False),
#  (1968760,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1968760/header.jpg?t=1651734619',
#   'http://magnussoft.biz/',
#   'http://magnussoft.biz/',
#   'support@magnussoft.de',
#   True,
#   False,
#   False),
#  (1178150,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1178150/header.jpg?t=1612253064',
#   'http://www.cfk.kr/',
#   'http://www.cfk.kr',
#   'cfk@cfk.kr',
#   True,
#   False,
#   False),
#  (320150,
#   '50000 - 100000',
#   '',
#   703,
#   'https://cdn.akamai.steamstatic.com/steam/apps/320150/header.jpg?t=1447363358',
#   'http://www.omlgames.com',
#   'http://www.omlgames.com',
#   'support@omlgames.com',
#   True,
#   True,
#   True),
#  (1026420,
#   '20000 - 50000',
#   '',
#   67,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1026420/header.jpg?t=1657716289',
#   'http://warsawthegame.com',
#   '',
#   'contact@pixmilk.com',
#   True,
#   False,
#   False),
#  (485000,
#   '50000 - 100000',
#   '',
#   224,
#   'https://cdn.akamai.steamstatic.com/steam/apps/485000/header.jpg?t=1656685326',
#   'https://www.cthulhurealms.com/',
#   'https://www.wisewizardgames.com/contact-us/',
#   'support@wisewizardgames.com',
#   True,
#   True,
#   False),
#  (1620060,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1620060/header.jpg?t=1630096342',
#   '',
#   '',
#   'beardlin@beardlings.com',
#   True,
#   False,
#   False),
#  (825930,
#   '20000 - 50000',
#   '',
#   11,
#   'https://cdn.akamai.steamstatic.com/steam/apps/825930/header.jpg?t=1657805439',
#   '',
#   '',
#   'mail@educational-games.ru',
#   True,
#   True,
#   True),
#  (1454010,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1454010/header.jpg?t=1654343206',
#   '',
#   '',
#   'kth20970@naver.com',
#   True,
#   False,
#   False),
#  (22670,
#   '200000 - 500000',
#   '',
#   44,
#   'https://cdn.akamai.steamstatic.com/steam/apps/22670/header.jpg?t=1655730869',
#   'http://www.team17.com/',
#   '',
#   '',
#   True,
#   False,
#   False),
#  (1330820,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1330820/header.jpg?t=1604674624',
#   '',
#   'https://www.ziggurat.games/',
#   'support@ziggurat.games',
#   True,
#   False,
#   False),
#  (346560,
#   '100000 - 200000',
#   '',
#   280,
#   'https://cdn.akamai.steamstatic.com/steam/apps/346560/header.jpg?t=1635411355',
#   'https://www.lonelytroops.com/hotk2/index.htm',
#   '',
#   'support@lonelytroops.com',
#   True,
#   True,
#   True),
#  (1097880,
#   '0 - 20000',
#   'This game depicts sexual acts between the player and a female character. All characters depicted are over the age of 18.',
#   34,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1097880/header.jpg?t=1634585855',
#   '',
#   'https://denpasoft.com/contact/',
#   '',
#   True,
#   False,
#   False),
#  (1362670,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1362670/header.jpg?t=1595629192',
#   'https://khiogame.com/',
#   'khiogame.com',
#   'necavare@gmail.com',
#   True,
#   False,
#   False),
#  (290870,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/290870/header.jpg?t=1572601412',
#   'http://steamsquad.net/',
#   'http://steamsquad.net/',
#   'steamsquad@bretwalda.net',
#   True,
#   True,
#   True),
#  (575760,
#   '20000 - 50000',
#   '',
#   337,
#   'https://cdn.akamai.steamstatic.com/steam/apps/575760/header.jpg?t=1610204415',
#   '',
#   '',
#   'volensnolensgames@gmail.com',
#   True,
#   False,
#   False),
#  (434030,
#   '100000 - 200000',
#   '',
#   127,
#   'https://cdn.akamai.steamstatic.com/steam/apps/434030/header.jpg?t=1611007152',
#   'https://www.aerofly.com/',
#   'https://www.aerofly.com/support',
#   '',
#   True,
#   True,
#   True),
#  (810740,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/810740/header.jpg?t=1564767072',
#   '',
#   '',
#   '',
#   True,
#   False,
#   False),
#  (2073470,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/2073470/header.jpg?t=1658578826',
#   '',
#   '',
#   'stanislawgamess@gmail.com',
#   True,
#   False,
#   False),
#  (589250,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/589250/header.jpg?t=1602346000',
#   '',
#   '',
#   'christianignatov@gmail.com',
#   True,
#   False,
#   False),
#  (677880,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/677880/header.jpg?t=1502354684',
#   '',
#   'http://www.draw-your-game.com/',
#   'contact@zerokcm.fr',
#   True,
#   False,
#   False),
#  (1294780,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1294780/header.jpg?t=1636574184',
#   'https://menssanainteractive.com/pathfinders-memories/',
#   'https://menssanainteractive.com/contact/',
#   'contact@menssanainteractive.com',
#   True,
#   True,
#   False),
#  (1342850,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1342850/header.jpg?t=1647367796',
#   '',
#   '',
#   'deltaarcade.devs@gmail.com',
#   True,
#   False,
#   False),
#  (1177420,
#   '0 - 20000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work Download only for players over 18 years old.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1177420/header.jpg?t=1643961973',
#   '',
#   'https://weibo.com/u/5163464450',
#   '574584405@qq.com',
#   True,
#   True,
#   False),
#  (793990,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/793990/header.jpg?t=1554112778',
#   '',
#   '',
#   'nedostudiogames@gmail.com',
#   True,
#   False,
#   False),
#  (1727670,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1727670/header.jpg?t=1650725590',
#   '',
#   '',
#   'lonchdev@gmail.com',
#   True,
#   False,
#   False),
#  (955490,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/955490/header.jpg?t=1553261389',
#   'https://www.facebook.com/TensionSplice',
#   'https://www.facebook.com/TensionSplice',
#   'tensionsplicegaming@gmail.com',
#   True,
#   False,
#   False),
#  (552350,
#   '20000 - 50000',
#   '',
#   218,
#   'https://cdn.akamai.steamstatic.com/steam/apps/552350/header.jpg?t=1490429559',
#   '',
#   'http://warpedtales.weebly.com/',
#   'the.warped.tales@gmail.com',
#   True,
#   True,
#   True),
#  (42500,
#   '100000 - 200000',
#   '',
#   739,
#   'https://cdn.akamai.steamstatic.com/steam/apps/42500/header.jpg?t=1447352631',
#   'http://www.dogfighter-game.com',
#   '',
#   'support@instinctengine.com',
#   True,
#   False,
#   False),
#  (1195610,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1195610/header.jpg?t=1593616624',
#   '',
#   '',
#   'night.fall.q8@hotmail.com',
#   True,
#   False,
#   False),
#  (1095380,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1095380/header.jpg?t=1560702926',
#   '',
#   'https://Spikkeee.com',
#   'Team@Spikkeee.com',
#   True,
#   True,
#   True),
#  (1158910,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1158910/header.jpg?t=1575446792',
#   'https://www.dreamdetectivegame.com/',
#   '',
#   'dreamdetective@centurygame.com',
#   True,
#   False,
#   False),
#  (1194940,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1194940/header.jpg?t=1588257230',
#   '',
#   '',
#   'MarkusVC64@gmail.com',
#   True,
#   False,
#   False),
#  (262150,
#   '200000 - 500000',
#   '',
#   425,
#   'https://cdn.akamai.steamstatic.com/steam/apps/262150/header.jpg?t=1637103054',
#   'http://www.eigoMANGA.com/vanguard',
#   'http://www.eigoMANGA.com/',
#   'business@eigomanga.com',
#   True,
#   True,
#   True),
#  (1192900,
#   '50000 - 100000',
#   'Iron Rebellion has elements of sci-fi combat with laser guns, missiles, and explosions.',
#   48,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1192900/header.jpg?t=1658516573',
#   'https://www.iron-rebellion.com/',
#   'iron-rebellion.com',
#   'ironrainvr@gmail.com',
#   True,
#   False,
#   False),
#  (866150,
#   '50000 - 100000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/866150/header.jpg?t=1657805153',
#   '',
#   '',
#   'mail@garage-games.ru',
#   True,
#   False,
#   False),
#  (231330,
#   '100000 - 200000',
#   '',
#   324,
#   'https://cdn.akamai.steamstatic.com/steam/apps/231330/header.jpg?t=1561964976',
#   'http://www.deadfall-game.com/',
#   '',
#   'support@quanticlab.com',
#   True,
#   False,
#   True),
#  (1056520,
#   '0 - 20000',
#   'Please note that Who We Are Now contains explicit sexual scenes between men. These scenes are optional.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1056520/header.jpg?t=1560310334',
#   '',
#   '',
#   'chromafieldgames@gmail.com',
#   True,
#   True,
#   True),
#  (897820,
#   '50000 - 100000',
#   '',
#   83,
#   'https://cdn.akamai.steamstatic.com/steam/apps/897820/header.jpg?t=1645113692',
#   'http://www.reignsgame.com',
#   'http://www.reignsgame.com',
#   '',
#   True,
#   True,
#   True),
#  (658970,
#   '50000 - 100000',
#   '',
#   2,
#   'https://cdn.akamai.steamstatic.com/steam/apps/658970/header.jpg?t=1652288047',
#   'https://casinorpg.com',
#   'https://goldfire.me/contact',
#   'support@goldfire.me',
#   True,
#   True,
#   False),
#  (1777550,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1777550/header.jpg?t=1634291794',
#   '',
#   '',
#   'rosaspecialstuidio@gmail.com',
#   True,
#   False,
#   False),
#  (552520,
#   '2000000 - 5000000',
#   '',
#   1756,
#   'https://cdn.akamai.steamstatic.com/steam/apps/552520/header.jpg?t=1628209646',
#   'https://far-cry.ubisoft.com/',
#   'http://support.ubi.com',
#   '',
#   True,
#   False,
#   False),
#  (718350,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/718350/header.jpg?t=1636832962',
#   'https://store.steampowered.com/publisher/boogygames',
#   '',
#   'kitkat322@hotmail.com',
#   True,
#   False,
#   False),
#  (433450,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/433450/header.jpg?t=1634718060',
#   'http://www.arcsystemworks.jp/InfernoClimber/',
#   'https://arcsystemworks.com/support/',
#   '',
#   True,
#   False,
#   False),
#  (1709450,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1709450/header.jpg?t=1627730551',
#   '',
#   'https://bigfishgames.zendesk.com/hc/en-us/',
#   'support@bigfishgames.zendesk.com',
#   True,
#   False,
#   False),
#  (1431470,
#   '0 - 20000',
#   'Sexual innuendo.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1431470/header.jpg?t=1635032056',
#   '',
#   '',
#   'support@stegalosaurus.com',
#   True,
#   False,
#   True),
#  (1794920,
#   '0 - 20000',
#   'WARNING! This game is for adults only and it includes explicit, sexual content that some viewers may find offensive. The characters shown in the game are all over 18 years old.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1794920/header.jpg?t=1636334031',
#   '',
#   '',
#   'quarlellle@gmail.com',
#   True,
#   False,
#   False),
#  (763550,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/763550/header.jpg?t=1633891267',
#   'https://valhalla-game.com',
#   'https://valhalla-game.com/contact.html',
#   '',
#   True,
#   False,
#   False),
#  (1445370,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1445370/header.jpg?t=1629312010',
#   '',
#   'https://www.hellofriendgames.com',
#   'hellofriendllc@gmail.com',
#   True,
#   False,
#   False),
#  (464230,
#   '20000 - 50000',
#   '',
#   340,
#   'https://cdn.akamai.steamstatic.com/steam/apps/464230/header.jpg?t=1531925953',
#   'https://www.facebook.com/coloursofmagicgame/',
#   'http://runserver.net/support/fluids',
#   'fluids@runserver.net',
#   True,
#   True,
#   True),
#  (1293830,
#   '2000000 - 5000000',
#   '',
#   2518,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1293830/header.jpg?t=1622068013',
#   'http://www.forzamotorsport.net',
#   'https://support.forzamotorsport.net/',
#   '',
#   True,
#   False,
#   False),
#  (1509640,
#   '0 - 20000',
#   'This game contain violence as fighting, shooting with different type of enemies',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1509640/header.jpg?t=1624902073',
#   '',
#   '',
#   '777.ideas@gmail.com',
#   True,
#   False,
#   False),
#  (1135380,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1135380/header.jpg?t=1570161605',
#   '',
#   '',
#   'misaka10777game@yahoo.com',
#   True,
#   False,
#   False),
#  (1944730,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1944730/header.jpg?t=1654781524',
#   'https://www.jandusoft.com/squarekeeper',
#   'https://www.jandusoft.com',
#   '',
#   True,
#   False,
#   False),
#  (1144900,
#   '20000 - 50000',
#   'There is a small amount of mildly offensive language.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1144900/header.jpg?t=1651033778',
#   '',
#   '',
#   'jhenley123@outlook.com',
#   True,
#   False,
#   False),
#  (306350,
#   '200000 - 500000',
#   '',
#   183,
#   'https://cdn.akamai.steamstatic.com/steam/apps/306350/header.jpg?t=1530529929',
#   'http://www.funboxmedia.co.uk/',
#   'http://www.funboxmedia.co.uk/',
#   '',
#   True,
#   False,
#   False),
#  (1684530,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1684530/header.jpg?t=1650277935',
#   '',
#   'https://peaksel.com/',
#   'support@peaksel.email',
#   True,
#   True,
#   False),
#  (1557480,
#   '20000 - 50000',
#   '',
#   670,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1557480/header.jpg?t=1652940346',
#   'https://www.project-mikhail.com',
#   'https://project-mikhail.com/en/support/',
#   'support-mikhail-en@ancr.jp',
#   True,
#   False,
#   False),
#  (1128520,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1128520/header.jpg?t=1589792761',
#   '',
#   '',
#   'hydrargyrum2.0@gmail.com',
#   True,
#   False,
#   False),
#  (12140,
#   '500000 - 1000000',
#   '',
#   168,
#   'https://cdn.akamai.steamstatic.com/steam/apps/12140/header.jpg?t=1618852800',
#   'http://www.rockstargames.com/maxpayne/',
#   'http://www.rockstargames.com/maxpayne/',
#   '',
#   True,
#   False,
#   False),
#  (1647430,
#   '20000 - 50000',
#   'The black mansion includes bloodshed, such as being fragmented by a cog wheel or being stamped on a thorn when a character is caught in various traps.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1647430/header.jpg?t=1623740532',
#   '',
#   '',
#   'pictologisteam@gmail.com',
#   True,
#   False,
#   False),
#  (1845050,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1845050/header.jpg?t=1656942670',
#   '',
#   '',
#   'berryberryniceu@outlook.com',
#   True,
#   True,
#   True),
#  (1163340,
#   '0 - 20000',
#   '',
#   78,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1163340/header.jpg?t=1645784121',
#   'https://carrier-battles.com',
#   '',
#   'support@avalon-digital.com',
#   True,
#   True,
#   False),
#  (1608620,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1608620/header.jpg?t=1650227019',
#   '',
#   '',
#   'ballisticmachinegames@gmail.com',
#   True,
#   False,
#   False),
#  (541570,
#   '500000 - 1000000',
#   'Strong Language, Violence, Blood and Gore',
#   282,
#   'https://cdn.akamai.steamstatic.com/steam/apps/541570/header.jpg?t=1619036403',
#   'http://portablemoose.com/',
#   '',
#   'portablemoose@gmail.com',
#   True,
#   True,
#   True),
#  (1119070,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1119070/header.jpg?t=1657820107',
#   'http://www.soiree.info/shibui.html',
#   'http://www.soiree.info',
#   'robert@soiree.info',
#   True,
#   False,
#   False),
#  (1292520,
#   '0 - 20000',
#   'This game contains suspenseful horror and some fantasy violence including blood, but not extreme gore. There is vulgar language and cursing. Sexual content includes fade-to-black sexual descriptions and illustrations, but not explicit. There is also drug usage and references to drug abuse.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1292520/header.jpg?t=1628611195',
#   'http://woodsy-studio.com/crimson-spires/',
#   'http://woodsy-studio.com/contact/',
#   '',
#   True,
#   False,
#   False),
#  (1467330,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1467330/header.jpg?t=1617033910',
#   '',
#   '',
#   'MinicedStudio@gmail.com',
#   True,
#   False,
#   True),
#  (1624600,
#   '0 - 20000',
#   'Realms VR can contain low levels of violence In some game modes. Such as shooting characters and AI, in some cases may show very little blood like effects.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1624600/header.jpg?t=1657577056',
#   '',
#   '',
#   'MadmanGames.Help@Outlook.com',
#   True,
#   False,
#   False),
#  (870000,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/870000/header.jpg?t=1564179671',
#   'http://www.retrovergames.net',
#   'www.retrovergames.net',
#   'contact@retrovergames.net',
#   True,
#   True,
#   False),
#  (1621490,
#   '0 - 20000',
#   'This game contains full body nudity, erotic dialogue, strong language, and consensual sex acts. Contains cosplay , parody sexual themes.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1621490/header.jpg?t=1655643714',
#   '',
#   'https://discord.gg/ruKQfktqDs',
#   'firearmgamesovah@gmail.com',
#   True,
#   False,
#   False),
#  (768060,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/768060/header.jpg?t=1531848218',
#   '',
#   'steamcommunity.com/id/mastermindfin',
#   'tero.lunkka@gmail.com',
#   True,
#   False,
#   False),
#  (1746130,
#   '0 - 20000',
#   'This game contains explicit sexual content, including depictions of sexual behavior. All characters are over the age of 18.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1746130/header.jpg?t=1632273671',
#   '',
#   'https://docs.google.com/forms/d/e/1FAIpQLSfedwln2PPZqqaX-otwQllw1YTj_GQkWwH0uyR7gqczOO3bRA/viewform',
#   '',
#   True,
#   False,
#   False),
#  (1281400,
#   '20000 - 50000',
#   'The game contains stylish abstract blood, hack slash style violence, demonic world, and naked demon with a doll anatomy.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1281400/header.jpg?t=1657960590',
#   'https://www.doublethinkgames.com',
#   '',
#   'support@doublethinkgames.com',
#   True,
#   False,
#   True),
#  (372890,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/372890/header.jpg?t=1654263522',
#   'https://cateia.com/game/red-crow-mysteries-legion/',
#   '',
#   'support@cateia.com',
#   True,
#   False,
#   False),
#  (1023420,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1023420/header.jpg?t=1598108398',
#   'https://wargame.jp/?page_id=1913',
#   'https://wargame.jp/?page_id=73',
#   '',
#   True,
#   False,
#   False),
#  (1141880,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1141880/header.jpg?t=1603273958',
#   'https://alignedgames.com/',
#   'https://alignedgames.com/',
#   'Alignedgames@mailbox.co.za',
#   True,
#   False,
#   False),
#  (1022840,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1022840/header.jpg?t=1576423102',
#   '',
#   '',
#   'support@gamepublishing.de',
#   True,
#   False,
#   False),
#  (652160,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/652160/header.jpg?t=1497573312',
#   'http://anthonytylerjr.wixsite.com/portfolio/dc-wonder',
#   '',
#   'Riageki@gmail.com',
#   True,
#   False,
#   False),
#  (968580,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/968580/header.jpg?t=1636832682',
#   'https://store.steampowered.com/publisher/boogygames',
#   '',
#   'gulhan300@gmail.com',
#   True,
#   False,
#   False),
#  (1131550,
#   '0 - 20000',
#   'This game contains graphic depictions of gore and violence involving humans and zombies. Also contains mature content or situations not suitable for some audiences.',
#   34,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1131550/header.jpg?t=1609371083',
#   '',
#   'http://support.sekaiproject.com/',
#   '',
#   True,
#   False,
#   False),
#  (1729790,
#   '0 - 20000',
#   'Contains Blood',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1729790/header.jpg?t=1651141362',
#   '',
#   '',
#   'er.escapefromschool@gmail.com',
#   True,
#   False,
#   False),
#  (368080,
#   '20000 - 50000',
#   '',
#   360,
#   'https://cdn.akamai.steamstatic.com/steam/apps/368080/header.jpg?t=1656698454',
#   'https://www.aurionthegame.com/',
#   'http://www.kiroogames.com/en/kiro-o-business/contact-our-studio.html',
#   'supports@kiroogames.com',
#   True,
#   False,
#   False),
#  (572510,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/572510/header.jpg?t=1657807374',
#   'https://www.jandusoft.com',
#   'www.jandusoft.com',
#   '',
#   True,
#   False,
#   False),
#  (1225870,
#   '0 - 20000',
#   'All characters in this game are over 18! This game contains scenes of a sexual nature.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1225870/header.jpg?t=1580497037',
#   '',
#   '',
#   'snake25igame@gmail.com',
#   True,
#   False,
#   False),
#  (1232510,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1232510/header.jpg?t=1608122503',
#   'https://teleporter.gg',
#   'https://feedback.teleporter.gg/',
#   'needbackup@teleporter.gg',
#   True,
#   False,
#   False),
#  (1066890,
#   '200000 - 500000',
#   '',
#   1880,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1066890/header.jpg?t=1638569628',
#   'https://www.game-automobilista2.com/',
#   'https://forum.reizastudios.com',
#   'support@reizastudios.com',
#   True,
#   False,
#   False),
#  (817370,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/817370/header.jpg?t=1535378161',
#   '',
#   '',
#   'marchingsimulator@gmail.com',
#   True,
#   False,
#   False),
#  (457140,
#   '2000000 - 5000000',
#   '',
#   3574,
#   'https://cdn.akamai.steamstatic.com/steam/apps/457140/header_alt_assets_6.jpg?t=1654189805',
#   'https://www.kleientertainment.com/games/oxygen-not-included',
#   '',
#   'livesupport@kleientertainment.com',
#   True,
#   True,
#   True),
#  (1774810,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1774810/header.jpg?t=1634532375',
#   '',
#   'https://www.facebook.com/LGT-SIA-106479211568636',
#   'frhgames@gmail.com',
#   True,
#   False,
#   False),
#  (1886290,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/header.jpg?t=1657283667',
#   '',
#   '',
#   'pinblendstudios@gmail.com',
#   True,
#   False,
#   False),
#  (1514360,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1514360/header.jpg?t=1648018736',
#   'https://yurucamp-v.com/',
#   'http://www.gemdrops.co.jp/',
#   '',
#   True,
#   False,
#   False),
#  (1374280,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1374280/header.jpg?t=1643304058',
#   'https://goadstool.itch.io/kor',
#   'https://twitter.com/goadstool',
#   '',
#   True,
#   False,
#   False),
#  (863490,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/863490/header.jpg?t=1653306007',
#   '',
#   '',
#   'support@nukgames.com',
#   True,
#   False,
#   False),
#  (396640,
#   '0 - 20000',
#   '',
#   53,
#   'https://cdn.akamai.steamstatic.com/steam/apps/396640/header.jpg?t=1452807494',
#   'http://www.davioware.com',
#   'http://www.davioware.com/forum/',
#   'davioware@gmail.com',
#   True,
#   False,
#   False),
#  (726020,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/726020/header.jpg?t=1648610974',
#   'http://www.hotgunsgame.com',
#   'http://www.quantized-bit.com',
#   'quantizedbit@gmail.com',
#   True,
#   True,
#   True),
#  (424060,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/424060/header.jpg?t=1449813811',
#   'http://brainwashing.pl/',
#   '',
#   'contact@brainwashing.pl',
#   True,
#   False,
#   False),
#  (514870,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/514870/header.jpg?t=1540238466',
#   'http://www.fatcitygame.com/index.html',
#   '',
#   'fatcitysupport@heavy-iron.com',
#   True,
#   False,
#   False),
#  (548290,
#   '50000 - 100000',
#   '',
#   1,
#   'https://cdn.akamai.steamstatic.com/steam/apps/548290/header.jpg?t=1480380033',
#   'https://www.gamengame.com/games/online-game-media.asp?game_no=117',
#   'http://www.gamengame.com/support/',
#   '',
#   True,
#   False,
#   False),
#  (695420,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/695420/header.jpg?t=1506349129',
#   'http://www.prettybatgames.com',
#   '',
#   'support@prettybatgames.com',
#   True,
#   True,
#   True),
#  (1241110,
#   '500000 - 1000000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1241110/header.jpg?t=1617581131',
#   '',
#   '',
#   'newprojektstudio@outlook.com',
#   True,
#   False,
#   False),
#  (587490,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/587490/header.jpg?t=1493630456',
#   '',
#   '',
#   'DarkThrone_Help@outlook.com',
#   True,
#   False,
#   False),
#  (546050,
#   '500000 - 1000000',
#   '',
#   6557,
#   'https://cdn.akamai.steamstatic.com/steam/apps/546050/header.jpg?t=1611834147',
#   '',
#   'https://support.sega.co.uk',
#   '',
#   True,
#   False,
#   False),
#  (301700,
#   '200000 - 500000',
#   '',
#   119,
#   'https://cdn.akamai.steamstatic.com/steam/apps/301700/header.jpg?t=1617086824',
#   'http://www.cobramobile.com/',
#   'http://www.cobramobile.com/contact.html',
#   '',
#   True,
#   False,
#   False),
#  (2004200,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/2004200/header.jpg?t=1654247053',
#   '',
#   '',
#   '17408631qqcom',
#   True,
#   False,
#   False),
#  (1588070,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1588070/header.jpg?t=1657799740',
#   '',
#   '',
#   'reforged@garage-games.ru',
#   True,
#   False,
#   False),
#  (730310,
#   '1000000 - 2000000',
#   '',
#   215,
#   'https://cdn.akamai.steamstatic.com/steam/apps/730310/header.jpg?t=1657631096',
#   'http://www.koeitecmoamerica.com/dw9/?lang=us',
#   'http://www.koeitecmoeurope.com/support/',
#   'support@koeitecmo.co.uk',
#   True,
#   False,
#   False),
#  (242530,
#   '100000 - 200000',
#   '',
#   139,
#   'https://cdn.akamai.steamstatic.com/steam/apps/242530/header.jpg?t=1574864269',
#   'http://www.thechaosenginegame.com/',
#   '',
#   '',
#   True,
#   True,
#   True),
#  (1372570,
#   '0 - 20000',
#   'Trigger warning: self-harm',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1372570/header.jpg?t=1604885226',
#   '',
#   'https://purplecable.ca/',
#   'support@purplecable.ca',
#   True,
#   True,
#   True),
#  (1345820,
#   '50000 - 100000',
#   '',
#   171,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1345820/header_alt_assets_6.jpg?t=1655110701',
#   'https://www.ragnarock-vr.com/',
#   'https://discord.com/invite/DKHk5rQ',
#   'contact@wanadevstudio.com',
#   True,
#   False,
#   False),
#  (420270,
#   '0 - 20000',
#   '',
#   269,
#   'https://cdn.akamai.steamstatic.com/steam/apps/420270/header.jpg?t=1464029693',
#   'https://www.facebook.com/MozgLabs/',
#   'http://steamcommunity.com/groups/mozg_labs',
#   'mailbox@mozglabs.com',
#   True,
#   True,
#   True),
#  (435790,
#   '200000 - 500000',
#   '',
#   142,
#   'https://cdn.akamai.steamstatic.com/steam/apps/435790/header.jpg?t=1634742090',
#   'http://10second.ninja',
#   'https://curvegames.com/contact/',
#   'support@curvegames.com',
#   True,
#   False,
#   False),
#  (926310,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/926310/header.jpg?t=1602849748',
#   '',
#   '',
#   'wangshuo.16@gmail.com',
#   True,
#   True,
#   False),
#  (788020,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/788020/header.jpg?t=1643303355',
#   '',
#   'https://discord.gg/SMewxTX',
#   'mogacreative@gmail.com',
#   True,
#   False,
#   False),
#  (467400,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/467400/header.jpg?t=1625429999',
#   'http://goforlaunch.co.uk',
#   '',
#   'admin@goforlaunch.co.uk',
#   True,
#   False,
#   False),
#  (856730,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/856730/header.jpg?t=1658412078',
#   '',
#   '',
#   'artur.projetista@hotmail.com',
#   True,
#   False,
#   False),
#  (1106950,
#   '0 - 20000',
#   "The game's main story involves references to drugs. There is also sexual innuendo.",
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1106950/header.jpg?t=1625448789',
#   'http://stegalosaurus.org',
#   '',
#   'support@stegalosaurus.com',
#   True,
#   False,
#   True),
#  (1274570,
#   '1000000 - 2000000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Frequent Violence or Gore, General Mature Content',
#   303,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1274570/header.jpg?t=1658167349',
#   'http://www.devourgame.com',
#   '',
#   'support@straightbackgames.com',
#   True,
#   True,
#   False),
#  (1470790,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1470790/header.jpg?t=1609248749',
#   'http://www.maxfootballgame.com',
#   'https://discord.gg/22apWRr',
#   '',
#   True,
#   False,
#   False),
#  (1087620,
#   '0 - 20000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Nudity, Sexual Themes, Strong Language, and Use of Alcohol. All characters in the game are over the age of 18.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1087620/header.jpg?t=1622612208',
#   '',
#   '',
#   'playkon@hotmail.com',
#   True,
#   False,
#   False),
#  (1348430,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1348430/header.jpg?t=1598441127',
#   '',
#   'goessoft.com/contact',
#   'contact@goessoft.com',
#   True,
#   True,
#   True),
#  (1547580,
#   '0 - 20000',
#   'Being involuntary drugged Partial nudity',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1547580/header.jpg?t=1657986174',
#   '',
#   '',
#   'triority_developer@outlook.com',
#   True,
#   True,
#   True),
#  (1253680,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1253680/header.jpg?t=1623428873',
#   'http://supersoccerblast.com/',
#   'http://www.unfinishedpixel.com',
#   'team@unfinishedpixel.com',
#   True,
#   False,
#   False),
#  (1881210,
#   '0 - 20000',
#   'Sword combat violence, minor cursing',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1881210/header.jpg?t=1652321146',
#   'https://www.royalflushstudioz.com/masterssurvival',
#   'https://www.royalflushstudioz.com/contact',
#   'royalflushstudioz230@gmail.com',
#   True,
#   False,
#   False),
#  (497670,
#   '0 - 20000',
#   '',
#   119,
#   'https://cdn.akamai.steamstatic.com/steam/apps/497670/header.jpg?t=1562062073',
#   'https://www.gamerainteractive.it',
#   'http://www.gamerainteractive.it',
#   'support@gameragames.net',
#   True,
#   True,
#   True),
#  (850040,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/850040/header.jpg?t=1526582747',
#   '',
#   '',
#   'allu.rajamaki@gmail.com',
#   True,
#   False,
#   False),
#  (7940,
#   '1000000 - 2000000',
#   '',
#   1034,
#   'https://cdn.akamai.steamstatic.com/steam/apps/7940/header.jpg?t=1646762118',
#   'http://www.charlieoscardelta.com/',
#   'http://support.activision.com/',
#   '',
#   True,
#   True,
#   False),
#  (741770,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/741770/header.jpg?t=1511381462',
#   'https://www.facebook.com/supercrazysanta',
#   'https://www.facebook.com/supercrazysanta',
#   'elzzap2015@gmail.com',
#   True,
#   True,
#   False),
#  (110630,
#   '20000 - 50000',
#   '',
#   39,
#   'https://cdn.akamai.steamstatic.com/steam/apps/110630/header.jpg?t=1447355365',
#   'http://pompomgames.com/mutantstormreloaded.htm',
#   '',
#   '',
#   True,
#   False,
#   False),
#  (572330,
#   '0 - 20000',
#   '',
#   11,
#   'https://cdn.akamai.steamstatic.com/steam/apps/572330/header.jpg?t=1593004829',
#   'http://thefan-game.blogspot.fr/p/about-thefan.html',
#   'http://thefan-game.blogspot.fr/p/about-thefan.html',
#   'cyril.danon@gmail.com',
#   True,
#   False,
#   False),
#  (1683240,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1683240/header.jpg?t=1650282826',
#   '',
#   '',
#   'kazakovstudios@gmail.com',
#   True,
#   False,
#   False),
#  (567150,
#   '20000 - 50000',
#   '',
#   335,
#   'https://cdn.akamai.steamstatic.com/steam/apps/567150/header.jpg?t=1532694023',
#   'https://www.facebook.com/8FloorGames/',
#   'https://www.facebook.com/8FloorGames',
#   'mikhail.zverev@8floor.net',
#   True,
#   True,
#   False),
#  (700880,
#   '100000 - 200000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/700880/header.jpg?t=1634184179',
#   'http://www.interplay.com',
#   'http://interplay.com/support/customer_service.php',
#   '',
#   True,
#   True,
#   True),
#  (1413090,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1413090/header.jpg?t=1649333800',
#   '',
#   '',
#   'myoldschoolconsoleX@gmail.com',
#   True,
#   False,
#   False),
#  (1610860,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1610860/header.jpg?t=1632485222',
#   'https://bigvillagegames.com/mereks-market/',
#   'https://bigvillagegames.com/contact/',
#   '',
#   True,
#   False,
#   False),
#  (1302840,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1302840/header.jpg?t=1629363841',
#   'http://vrani.co.kr',
#   'www.vrani.co.kr',
#   'dev@vrani.co.kr',
#   True,
#   False,
#   False),
#  (1305570,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1305570/header.jpg?t=1618388890',
#   'https://apollosoft.wixsite.com/pinbollua',
#   'https://apollosoft.wixsite.com/pinbollua',
#   'infopinv@apollosoft.co.jp',
#   True,
#   False,
#   False),
#  (1609730,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1609730/header.jpg?t=1657132207',
#   '',
#   '',
#   'sayan2244@hotmail.co.uk',
#   True,
#   False,
#   False),
#  (717980,
#   '0 - 20000',
#   '',
#   3,
#   'https://cdn.akamai.steamstatic.com/steam/apps/717980/header.jpg?t=1632905429',
#   'https://weibo.com/1985919717',
#   'https://weibo.com/1985919717',
#   '443560886@qq.com',
#   True,
#   False,
#   False),
#  (1417450,
#   '0 - 20000',
#   'This game contains blood and violence',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1417450/header.jpg?t=1605170939',
#   '',
#   '',
#   'intergalactic95@gmail.com',
#   True,
#   False,
#   False),
#  (778900,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/778900/header.jpg?t=1570809377',
#   '',
#   '',
#   'jortiz@toolkitzgames.com',
#   True,
#   False,
#   False),
#  (1004200,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1004200/header.jpg?t=1581649676',
#   'https://animarmedia.com/biathlon-battle-vr/',
#   'https://animarmedia.com/contact/',
#   'support@animarmedia.com',
#   True,
#   False,
#   False),
#  (1506230,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1506230/header.jpg?t=1610133292',
#   '',
#   '',
#   'jooomly@gmail.com',
#   True,
#   False,
#   False),
#  (638230,
#   '500000 - 1000000',
#   '',
#   216,
#   'https://cdn.akamai.steamstatic.com/steam/apps/638230/header.jpg?t=1646936237',
#   '',
#   '',
#   'help@annapurnainteractive.com',
#   True,
#   False,
#   False),
#  (1839080,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1839080/header.jpg?t=1658545363',
#   'https://www.remstudios.xyz/',
#   'https://www.remstudios.xyz/',
#   'support@remstudios.xyz',
#   True,
#   False,
#   False),
#  (907460,
#   '0 - 20000',
#   'With the increase in level, more explicit pictures open, depicting girls in sexy lingerie with bare chest and scenes of lesbian sex In total there are 16 pictures in the game and 5 of them fit the above described',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/907460/header.jpg?t=1619039042',
#   '',
#   '',
#   'meokigame@inbox.ru',
#   True,
#   False,
#   False),
#  (1307070,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1307070/header.jpg?t=1618008488',
#   'https://pixelracers.com/vetrix/',
#   'https://discord.gg/VtzJPaA',
#   '',
#   True,
#   False,
#   False),
#  (1221640,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1221640/header.jpg?t=1582206343',
#   'http://www.ultrafoodmess.com/',
#   '',
#   'contato@painfulsmile.com.br',
#   True,
#   False,
#   False),
#  (703120,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/703120/header.jpg?t=1602004049',
#   '',
#   'http://biggame.group/',
#   'game@biggame.group',
#   True,
#   False,
#   False),
#  (328710,
#   '0 - 20000',
#   '',
#   16,
#   'https://cdn.akamai.steamstatic.com/steam/apps/328710/header.jpg?t=1653941277',
#   'http://bloodwolfstudio.com/OLD',
#   'http://bloodwolfstudio.com/OLD/',
#   'motbest@gmail.com',
#   True,
#   True,
#   False),
#  (926140,
#   '100000 - 200000',
#   'CHANGE includes the following things which may not make this game age appropriate for some ages: Tobacco & alcohol use Infrequent swearing Drug use Text sections depicting scenes of abuse',
#   827,
#   'https://cdn.akamai.steamstatic.com/steam/apps/926140/header.jpg?t=1654866402',
#   'https://www.delveinteractive.com/',
#   'http://www.delveinteractive.com',
#   'contact@delveinteractive.com',
#   True,
#   True,
#   True),
#  (1700630,
#   '0 - 20000',
#   'The content contained in this game may not be suitable for all ages or should not be accessed during work: common adult content',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1700630/header.jpg?t=1653901030',
#   '',
#   '',
#   '403705663@qq.com',
#   True,
#   False,
#   False),
#  (845290,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/845290/header.jpg?t=1605980572',
#   'https://destructions.luxo-interactive.com/',
#   '',
#   'support@destructions.lukkussoft.com',
#   True,
#   False,
#   False),
#  (739720,
#   '0 - 20000',
#   'This Game contains content not appropriate for all ages (alcohol, drugs, and a moderate amount of violence).',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/739720/header.jpg?t=1651958864',
#   'https://lionsart.pl/',
#   'https://lionsart.pl/',
#   'support@lionsart.pl',
#   True,
#   False,
#   False),
#  (1776800,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1776800/header.jpg?t=1636000608',
#   '',
#   '',
#   'devfuryface@gmail.com',
#   True,
#   False,
#   False),
#  (873970,
#   '0 - 20000',
#   '',
#   232,
#   'https://cdn.akamai.steamstatic.com/steam/apps/873970/header.jpg?t=1529930948',
#   'http://www.ldw.com/privacy_legal.php',
#   'https://ldw.zendesk.com/hc/en-us/requests/new',
#   'support@ldw.zendesk.com',
#   True,
#   False,
#   False),
#  (1238130,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1238130/header.jpg?t=1585187997',
#   '',
#   '',
#   '957204408@qq.com',
#   True,
#   False,
#   False),
#  (1593100,
#   '0 - 20000',
#   'blood, meat, death',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1593100/header.jpg?t=1626186549',
#   '',
#   '',
#   'ren-87@mail.ru',
#   True,
#   False,
#   False),
#  (1365900,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1365900/header.jpg?t=1596892297',
#   '',
#   '',
#   'contact@unikagame.com',
#   True,
#   False,
#   False),
#  (962950,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/962950/header.jpg?t=1541509543',
#   '',
#   '',
#   '100256605@qq.com',
#   True,
#   False,
#   False),
#  (778120,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/778120/header.jpg?t=1657331193',
#   'http://heartshipgames.com/',
#   '',
#   'info@heartshipgames.com',
#   True,
#   False,
#   False),
#  (1187910,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1187910/header.jpg?t=1577326623',
#   '',
#   '',
#   'mifosgames@gmail.com',
#   True,
#   False,
#   False),
#  (763350,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/763350/header.jpg?t=1578167783',
#   'http://www.dribblegames.com/',
#   '',
#   'support@dribblegames.com',
#   True,
#   True,
#   False),
#  (1537410,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1537410/header.jpg?t=1625562286',
#   'https://www.twilight-drive.com/',
#   '',
#   'support@eponymouse.com',
#   True,
#   False,
#   False),
#  (761910,
#   '0 - 20000',
#   '',
#   205,
#   'https://cdn.akamai.steamstatic.com/steam/apps/761910/header.jpg?t=1617111303',
#   'https://www.worbital.com/',
#   'https://www.worbital.com/',
#   'info@teamjollyroger.fi',
#   True,
#   True,
#   False),
#  (975470,
#   '20000 - 50000',
#   'This game contains content that might not be suitable for all ages. (violent references, blood & gore)',
#   54,
#   'https://cdn.akamai.steamstatic.com/steam/apps/975470/header.jpg?t=1655382203',
#   'https://www.headupgames.com/game/silver-chains',
#   'http://www.headupgames.com/',
#   'support@headupgames.com',
#   True,
#   False,
#   False),
#  (990900,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/990900/header.jpg?t=1633128519',
#   'http://neonnoodles.com',
#   'http://vividhelix.com/support/',
#   '',
#   True,
#   False,
#   True),
#  (372770,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/372770/header.jpg?t=1447374965',
#   'http://threeprongproductions.com',
#   'http://threeprongproductions.com',
#   'threeprongproductionsgames@gmail.com',
#   True,
#   False,
#   True),
#  (462580,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/462580/header.jpg?t=1658421331',
#   '',
#   'http://www.buka.ru/cgi-bin/tech_support.pl?option=first_page',
#   'help@buka.ru',
#   True,
#   False,
#   False),
#  (926870,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/926870/header.jpg?t=1601488651',
#   '',
#   'https://steamcommunity.com/app/926870/discussions/',
#   'joechatfield@me.com',
#   True,
#   False,
#   False),
#  (848720,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/848720/header.jpg?t=1526414306',
#   '',
#   '',
#   'inhibitor1@yandex.ru',
#   True,
#   False,
#   False),
#  (1343040,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1343040/header.jpg?t=1620651284',
#   'https://www.langestudios.com/blocky-ball',
#   'https://www.langestudios.com/contact-us',
#   '',
#   True,
#   False,
#   True),
#  (519140,
#   '200000 - 500000',
#   '',
#   30,
#   'https://cdn.akamai.steamstatic.com/steam/apps/519140/header.jpg?t=1569810949',
#   '',
#   '',
#   'Stash329@gmail.com',
#   True,
#   False,
#   False),
#  (1987030,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1987030/header.jpg?t=1658673662',
#   '',
#   'https://discord.gg/6VjcTCfh',
#   'tangerine.juice3@gmail.com',
#   True,
#   False,
#   False),
#  (821260,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/821260/header.jpg?t=1522955786',
#   '',
#   '',
#   'lightsteamsuppport@gmail.com',
#   True,
#   False,
#   False),
#  (1565720,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1565720/header.jpg?t=1617984977',
#   '',
#   '',
#   'businesscatstudio@gmail.com',
#   True,
#   False,
#   False),
#  (748490,
#   '50000 - 100000',
#   '',
#   4495,
#   'https://cdn.akamai.steamstatic.com/steam/apps/748490/header.jpg?t=1624575761',
#   'http://www.trailsofcoldsteel.com/cs2/',
#   '',
#   'support@xseedgames.com',
#   True,
#   False,
#   False),
#  (545000,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/545000/header.jpg?t=1650598187',
#   '',
#   'http://www.gamecity.ne.jp/support/',
#   '',
#   True,
#   False,
#   False),
#  (1623720,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1623720/header.jpg?t=1623779652',
#   '',
#   '',
#   'orlovasteam@gmail.com',
#   True,
#   False,
#   False),
#  (544220,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/544220/header.jpg?t=1481453954',
#   'http://sadisticbutchering.com',
#   'http://sadisticbutchering.com',
#   'info@suomi-peli.fi',
#   True,
#   False,
#   False),
#  (338190,
#   '20000 - 50000',
#   '',
#   359,
#   'https://cdn.akamai.steamstatic.com/steam/apps/338190/header.jpg?t=1567625310',
#   'http://retrific.net/just-get-through-game.php',
#   'https://twitter.com/Retrific',
#   'help@retrific.net',
#   True,
#   False,
#   False),
#  (1375270,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1375270/header.jpg?t=1600599548',
#   '',
#   '',
#   'shapegame.contact@gmail.com',
#   True,
#   False,
#   False),
#  (551680,
#   '0 - 20000',
#   '',
#   242,
#   'https://cdn.akamai.steamstatic.com/steam/apps/551680/header.jpg?t=1577126896',
#   '',
#   '',
#   'StrongCubeMail@gmail.com',
#   True,
#   False,
#   False),
#  (1874510,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1874510/header.jpg?t=1657814818',
#   '',
#   '',
#   'leturslabs@gmail.com',
#   True,
#   False,
#   False),
#  (1693780,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1693780/header.jpg?t=1653960769',
#   '',
#   '',
#   'dododigital07@gmail.com',
#   True,
#   False,
#   False),
#  (1466930,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1466930/header.jpg?t=1651600887',
#   'https://sqcgame.com/',
#   'https://phoenixx.ne.jp/contactus/',
#   'support@phoenixx.ne.jp',
#   True,
#   False,
#   False),
#  (1748070,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1748070/header.jpg?t=1632812989',
#   '',
#   '',
#   'help.nikigames@gmail.com',
#   True,
#   False,
#   False),
#  (964920,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/964920/header.jpg?t=1546595397',
#   '',
#   '',
#   'fei@darknat.com',
#   True,
#   False,
#   False),
#  (1085570,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1085570/header.jpg?t=1620242450',
#   '',
#   '',
#   'cheesemastergamesdev@gmail.com',
#   True,
#   False,
#   False),
#  (1528020,
#   '0 - 20000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing: Frequent Violence or General Mature Content Afterlife VR contains scenes of violence and blood: - shooting at enemies, - appearing blood when shooting, - jumpscares, - dead people and embryos, - mutant animals, - bloody clothes of characters, - indoor blood, - ghosts and dark characters, - depictions of suicide (e.g. people hanging on ropes).',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1528020/header.jpg?t=1655198481',
#   'http://splitlightstudio.com/pages/movies_afterlife.html',
#   'http://splitlightstudio.com/',
#   'contact@splitlightstudio.com',
#   True,
#   False,
#   False),
#  (1796350,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1796350/header.jpg?t=1647983794',
#   '',
#   '',
#   'adaptivegame.games@gmail.com',
#   True,
#   False,
#   False),
#  (1444320,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1444320/header.jpg?t=1636390218',
#   'http://letmeowt.com',
#   'http://letmeowt.com',
#   'letmeowtgames@outlook.com',
#   True,
#   False,
#   False),
#  (906050,
#   '0 - 20000',
#   'The pictures contained in this game show girls Japanese animations in undress or even completely naked. Sexual acts are also represented. Some of these images may also suggest a sexual act without consent. These pictures can be seen at any time in the game. It is therefore suitable only for an adult audience',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/906050/header.jpg?t=1649427406',
#   '',
#   '',
#   'rewindappstudio@gmail.com',
#   True,
#   False,
#   False),
#  (351910,
#   '200000 - 500000',
#   '',
#   283,
#   'https://cdn.akamai.steamstatic.com/steam/apps/351910/header.jpg?t=1578501348',
#   'http://www.valhalla-hills.com/',
#   'http://forum.daedalic.de/',
#   'support@daedalic.de',
#   True,
#   True,
#   True),
#  (513480,
#   '20000 - 50000',
#   '',
#   341,
#   'https://cdn.akamai.steamstatic.com/steam/apps/513480/header.jpg?t=1588169993',
#   'http://www.windybeard.com',
#   'www.windybeard.com',
# ...
#  (1411460,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1411460/header.jpg?t=1649681409',
#   'https://www.itsbasem.com/z-arena',
#   'itsbasem.com',
#   'itsbasem@gmail.com',
#   True,
#   False,
#   False),
#  (680250,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/680250/header.jpg?t=1510773795',
#   'https://www.facebook.com/APMTStudio/',
#   'https://www.facebook.com/APMTStudio/',
#   'teamapmt@gmail.com',
#   True,
#   False,
#   False),
#  (1421410,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1421410/header.jpg?t=1618522745',
#   'https://bthomas2622.github.io/bt-presskit/notg/',
#   'http://bthomas2622.github.io/',
#   'benthomasdeveloper@gmail.com',
#   True,
#   False,
#   False),
#  (1275660,
#   '0 - 20000',
#   'Sanity of Morris is a horror adventure game. Some scenes might be considered disturbing, contain explicit violence and cases of paranoia.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1275660/header.jpg?t=1616754126',
#   'http://www.sanityofmorris.com/',
#   'https://sanityofmorris.com',
#   '',
#   True,
#   True,
#   True),
#  (781520,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/781520/header.jpg?t=1606239324',
#   '',
#   '',
#   'adrixd2000@gmail.com',
#   True,
#   True,
#   True),
#  (1479540,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1479540/header.jpg?t=1643303968',
#   '',
#   '',
#   'jcosj1992@gmail.com',
#   True,
#   False,
#   False),
#  (1854510,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1854510/header.jpg?t=1646911037',
#   'https://moustachecabal.com/',
#   'https://moustachecabal.com/',
#   'contact@moustachecabal.com',
#   True,
#   False,
#   True),
#  (1462560,
#   '0 - 20000',
#   'This game has NO seeable mature content and is NOT accessible or presented in the game scenes. The Avatars are anatomically correct and even though fully clothed, in the game files the Avatars skin textures are accurate. These files will be revised very soon and the game files will be updated to remove this warning.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1462560/header.jpg?t=1619850404',
#   'https://holostarcommand.com/',
#   'https://holostarcommand.com/',
#   'commanderwolff@holostarcommand.com',
#   True,
#   False,
#   False),
#  (1314290,
#   '0 - 20000',
#   'This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Nudity or Sexual Content, General Mature Content, Hentai, Coarse Language, Public Sex, Magic Mind Control, Tentacle, Bondage',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1314290/header.jpg?t=1594285363',
#   '',
#   '',
#   'ragingusagi@gmail.com',
#   True,
#   False,
#   False),
#  (1753100,
#   '0 - 20000',
#   '·All the characters in this game are older than 20 Years old. ·Included in the game:Foul language,Sexually suggestive content,Alcoholism. ·Does not contain sexual behavior and extreme violence content.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1753100/header.jpg?t=1642383179',
#   '',
#   '',
#   'ch1368126@163.com',
#   True,
#   False,
#   False),
#  (1554970,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1554970/header.jpg?t=1655989572',
#   'http://www.roguespiritgame.com/',
#   'https://support.505games.com/hc/en-us',
#   '',
#   True,
#   False,
#   False),
#  (612590,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/612590/header.jpg?t=1491327050',
#   'http://www.smu.edu/Guildhall/Academics/Student-Work/Team-Game-Projects/Mouse-Playhouse',
#   'Guildhall.smu.edu',
#   'tinkertainment@gmail.com',
#   True,
#   False,
#   False),
#  (700170,
#   '50000 - 100000',
#   '',
#   1,
#   'https://cdn.akamai.steamstatic.com/steam/apps/700170/header.jpg?t=1511125746',
#   'https://www.facebook.com/DeservingLifeGame/',
#   'https://www.facebook.com/DeservingLifeGame/',
#   'gabriel.mittermair@mail.de',
#   True,
#   False,
#   False),
#  (798590,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/798590/header.jpg?t=1651011739',
#   'https://redvibestudio.com',
#   'https://redvibestudio.com',
#   'contact@redvibestudio.com',
#   True,
#   False,
#   False),
#  (718740,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/718740/header.jpg?t=1543847881',
#   'http://takefivegames.com/games/chop-chop-princess/',
#   'http://takefivegames.com/contact-take-five/',
#   'alex@takefivegames.com',
#   True,
#   True,
#   False),
#  (481950,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/481950/header.jpg?t=1575643162',
#   'https://warchildgaming.org.uk/campaign/help-pc-mobile/',
#   'http://www.bossastudios.com/',
#   'emilyfeedback@bossastudios.com',
#   True,
#   True,
#   False),
#  (113420,
#   '1000000 - 2000000',
#   '',
#   1130,
#   'https://cdn.akamai.steamstatic.com/steam/apps/113420/header.jpg?t=1645468079',
#   'http://www.fallenearth.com',
#   'http://support.gamersfirst.com/',
#   'support@gamersfirst.com',
#   True,
#   False,
#   False),
#  (714880,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/714880/header.jpg?t=1515803746',
#   '',
#   '',
#   '573456721@qq.com',
#   True,
#   False,
#   False),
#  (328550,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/328550/header.jpg?t=1632676947',
#   'https://www.choiceofgames.com/',
#   'https://www.choiceofgames.com/contact-us/',
#   'support-blackcat-steam@choiceofgames.com',
#   True,
#   True,
#   True),
#  (429430,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/429430/header.jpg?t=1518558954',
#   'http://www.tyrfingcycle.com/',
#   'http://www.tyrfingcycle.com/',
#   '',
#   True,
#   False,
#   False),
#  (1511130,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1511130/header.jpg?t=1613463057',
#   '',
#   '',
#   '1234567890kola6@gmail.com',
#   True,
#   False,
#   False),
#  (454540,
#   '200000 - 500000',
#   '',
#   54,
#   'https://cdn.akamai.steamstatic.com/steam/apps/454540/header.jpg?t=1609157478',
#   '',
#   '',
#   'support@luckcatchers.ru',
#   True,
#   False,
#   False),
#  (829260,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/829260/header.jpg?t=1523032162',
#   '',
#   '',
#   'hello@thinkinsidethebox.games',
#   True,
#   False,
#   False),
#  (1384990,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1384990/header.jpg?t=1600050472',
#   '',
#   '',
#   's71904@foxmail.com',
#   True,
#   False,
#   False),
#  (1108020,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1108020/header.jpg?t=1562921933',
#   'https://spikkeee.com',
#   'https://spikkeee.com',
#   'Team@Spikkeee.com',
#   True,
#   True,
#   True),
#  (781760,
#   '0 - 20000',
#   '',
#   635,
#   'https://cdn.akamai.steamstatic.com/steam/apps/781760/header.jpg?t=1639612262',
#   '',
#   '',
#   'ripknotsystemsllc@gmail.com',
#   True,
#   False,
#   False),
#  (988070,
#   '0 - 20000',
#   'Include blood and gore content',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/988070/header.jpg?t=1620523398',
#   'https://koexstudio.wordpress.com/all-of-zhem/',
#   'https://koexstudio.wordpress.com/',
#   'choo5d@yahoo.com.sg',
#   True,
#   False,
#   False),
#  (1222370,
#   '100000 - 200000',
#   '',
#   568,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1222370/header.jpg?t=1654708696',
#   'https://www.focus-home.com/en-us/games/necromunda-hired-gun',
#   'https://support.focus-home.com/hc/',
#   'support@focus-home.com',
#   True,
#   False,
#   False),
#  (533960,
#   '0 - 20000',
#   '',
#   30,
#   'https://cdn.akamai.steamstatic.com/steam/apps/533960/header.jpg?t=1490711492',
#   'http://scary-humans.com',
#   'http://scary-humans.com/support/',
#   'support@gabhel.com',
#   True,
#   True,
#   True),
#  (1152200,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1152200/header.jpg?t=1645436631',
#   '',
#   '',
#   'support@stegalosaurus.com',
#   True,
#   False,
#   True),
#  (760640,
#   '0 - 20000',
#   '',
#   28,
#   'https://cdn.akamai.steamstatic.com/steam/apps/760640/header.jpg?t=1654160610',
#   'https://www.managames.com/tennis',
#   'https://www.managames.com/mail_en/?subject=TE4%2520[Steam]',
#   '',
#   True,
#   True,
#   False),
#  (22380,
#   '2000000 - 5000000',
#   '',
#   3044,
#   'https://cdn.akamai.steamstatic.com/steam/apps/22380/header.jpg?t=1586905021',
#   'http://fallout.bethsoft.com',
#   'http://support.bethsoft.com/',
#   '',
#   True,
#   False,
#   False),
#  (1678450,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1678450/header.jpg?t=1640028541',
#   '',
#   'https://twitter.com/StOoPiDU_',
#   '',
#   True,
#   False,
#   False),
#  (1475940,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1475940/header.jpg?t=1607014741',
#   '',
#   '',
#   'contact@eode.studio',
#   True,
#   False,
#   False),
#  (529780,
#   '100000 - 200000',
#   '',
#   33,
#   'https://cdn.akamai.steamstatic.com/steam/apps/529780/header.jpg?t=1623356162',
#   'https://store.steampowered.com/developer/iblackpen',
#   'https://www.facebook.com/iblackpen/',
#   '',
#   True,
#   True,
#   True),
#  (753090,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/753090/header.jpg?t=1515164853',
#   'http://granolastudios.com',
#   'http://granolastudios.com',
#   'hello@granolastudios.com',
#   True,
#   False,
#   False),
#  (499230,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/499230/header.jpg?t=1555684593',
#   'http://www.survhive.com',
#   '',
#   'info@survhive.com',
#   True,
#   False,
#   False),
#  (1136240,
#   '20000 - 50000',
#   '',
#   5,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1136240/header.jpg?t=1631959611',
#   '',
#   'https://sugoi-yellow.itch.io/crowd-control',
#   '',
#   True,
#   False,
#   False),
#  (450390,
#   '1000000 - 2000000',
#   '',
#   126,
#   'https://cdn.akamai.steamstatic.com/steam/apps/450390/header.jpg?t=1567099772',
#   '',
#   'http://steamcommunity.com/app/450390',
#   '',
#   True,
#   False,
#   False),
#  (1907420,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1907420/header.jpg?t=1646166849',
#   '',
#   '',
#   'laushds@gmail.com',
#   True,
#   False,
#   False),
#  (1268840,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1268840/header.jpg?t=1631038574',
#   '',
#   '',
#   'Behnam.Saeedi.M.Sc@gmail.com',
#   True,
#   False,
#   False),
#  (1050910,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1050910/header.jpg?t=1554467734',
#   '',
#   '',
#   'G.L.D.Games@yandex.ru',
#   True,
#   False,
#   False),
#  (403100,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/403100/header.jpg?t=1658340288',
#   '',
#   'http://www.buka.ru/cgi-bin/tech_support.pl?option=first_page',
#   'help@buka.ru',
#   True,
#   False,
#   False),
#  (1245930,
#   '0 - 20000',
#   'Gore, Violent, Monster, Blood',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1245930/header.jpg?t=1646641027',
#   '',
#   'https://frenziedfridaynight.myportfolio.com/contact',
#   '',
#   True,
#   False,
#   False),
#  (1021260,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1021260/header.jpg?t=1647680991',
#   '',
#   'https://store.steampowered.com/app/1021260',
#   'blendergamez@gmail.com',
#   True,
#   False,
#   False),
#  (837720,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/837720/header.jpg?t=1627042655',
#   '',
#   'drageusgames.com',
#   'support@drageusgames.com',
#   True,
#   False,
#   False),
#  (1548540,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1548540/header.jpg?t=1640531896',
#   '',
#   '',
#   'kxfa84a@gmail.com',
#   True,
#   False,
#   False),
#  (463150,
#   '200000 - 500000',
#   '',
#   147,
#   'https://cdn.akamai.steamstatic.com/steam/apps/463150/header.jpg?t=1568226582',
#   '',
#   '',
#   'pinkappgames@gmail.com',
#   True,
#   False,
#   False),
#  (514700,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/514700/header.jpg?t=1531503491',
#   'http://www.bigfishgames.com/games/6040/mystery-case-files-13th-skull-collectors/?pc',
#   'https://bigfishgames.custhelp.com/app/home',
#   'info@bigfishgames.com',
#   True,
#   False,
#   False),
#  (1769630,
#   '20000 - 50000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1769630/header.jpg?t=1632523062',
#   '',
#   'https://bigfishgames.zendesk.com/hc/en-us/',
#   'support@bigfishgames.zendesk.com',
#   True,
#   False,
#   False),
#  (1898570,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1898570/header.jpg?t=1651319054',
#   '',
#   '',
#   'danilo.mbakun@gmail.com',
#   True,
#   False,
#   False),
#  (1821150,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1821150/header.jpg?t=1642436377',
#   '',
#   '',
#   'help.nikigames@gmail.com',
#   True,
#   False,
#   False),
#  (1572220,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1572220/header.jpg?t=1635775401',
#   '',
#   'https://billwhite.ca/#contact',
#   'simonpushelberg@gmail.com',
#   True,
#   False,
#   False),
#  (508710,
#   '0 - 20000',
#   '',
#   471,
#   'https://cdn.akamai.steamstatic.com/steam/apps/508710/header.jpg?t=1625839051',
#   '',
#   '',
#   'industrys116@gmail.com',
#   True,
#   False,
#   False),
#  (1347130,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1347130/header.jpg?t=1612548233',
#   '',
#   'www.seacorptech.com',
#   'support@seacorptech.com',
#   True,
#   False,
#   False),
#  (1689930,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1689930/header.jpg?t=1649783974',
#   'https://alleycatzgames.co.uk',
#   'http://alleycatzgames.co.uk/contact.html',
#   'john@alley-catz.info',
#   True,
#   False,
#   False),
#  (910540,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/910540/header.jpg?t=1546849888',
#   '',
#   '',
#   'guillaume.ce@gmail.com',
#   True,
#   True,
#   True),
#  (514920,
#   '100000 - 200000',
#   '',
#   262,
#   'https://cdn.akamai.steamstatic.com/steam/apps/514920/header.jpg?t=1648074772',
#   'http://quietriver.info/',
#   'http://quietriver.info/',
#   '',
#   True,
#   False,
#   False),
#  (1286030,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1286030/header.jpg?t=1590228032',
#   'http://www.gofencing.cn',
#   'http://www.gofencing.cn',
#   'zahon@qq.com',
#   True,
#   False,
#   False),
#  (574180,
#   '20000 - 50000',
#   "In-game characters start off nude and need to find or craft clothing. However, it’s the player's choice if they want to wear clothes or not. As for violence, players do go head-to-head in order to survive against each other and the game's AI characters, which includes some mild blood effects.",
#   233,
#   'https://cdn.akamai.steamstatic.com/steam/apps/574180/header.jpg?t=1652692029',
#   'http://remnantsgame.com',
#   'https://immortalhandstudios.com/',
#   'immortalhandstudios@gmail.com',
#   True,
#   False,
#   False),
#  (1680530,
#   '0 - 20000',
#   "This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Frequent jump scares, scary atmosphere, General horror Content, mentions of suicide, images of hanging bodies. Don't play if you are sensitive to these topics.",
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1680530/header.jpg?t=1638194985',
#   'https://www.3am-game.com',
#   'https://www.3am-game.com',
#   'manim8games@outlook.com',
#   True,
#   False,
#   False),
#  (550600,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/550600/header.jpg?t=1491631141',
#   'http://www.spherecomplex.com',
#   'http://www.ocgamestudio.com',
#   'contact@ocgamestudio.com',
#   True,
#   False,
#   False),
#  (1492590,
#   '0 - 20000',
#   '',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1492590/header.jpg?t=1609527045',
#   'http://gzstorm.com',
#   'http://gzstorm.com',
#   'jesse@gzstorm.com',
#   True,
#   False,
#   False),
#  (1173870,
#   '0 - 20000',
#   'The game contains parody violence which includes decapitations and the severing of limbs (blood can be turned off via options). The game also features some silly illustrated nudity and double entendres.',
#   0,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1173870/header.jpg?t=1582835252',
#   'http://willsykesgames.com/endless%20knight.html',
#   '',
#   'willsykes@willsykesgames.com',
#   True,
#   False,
#   False),
#  ...]

# %%
game_extra_info_insert_query = """ 
    INSERT IGNORE INTO game_extra_info (app_id, estimated_owners, extra_description, avg_playtime_mins, header_image, 
    website, support_url, support_email, window_supported, mac_supported, linux_supported) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) 
"""

batch_size = 25 
count = 0 

for x in range(0, len(game_extra_info_batch_data), batch_size): 
    batch_data = game_extra_info_batch_data[x: x+ batch_size] 

    try: 
        mydb = check_sql_connection(mydb) 
        cursor = mydb.cursor()   
        
        cursor.executemany(game_extra_info_insert_query, batch_data)
        mydb.commit()  
    
    except Exception as e: 
        print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "game_extra_info", game_extra_info_batch_data)
# Out:
# All data was inserted successfully: 89238 out of 89238

# %% [markdown]
# ### Games Review

# %%
game_review_batch_data = [] 

for _, row in steam_dataset.iterrows(): 
    game_review_batch_data.append( 
        (
            row['AppID'],  
            row['Reviews'],  
            row['Metacritic score'], 
            row['Metacritic url'], 
            row['Positive'], 
            row['Negative'], 
            row['Recommendations']
        )
    ) 

game_review_batch_data
# Out:
# [(20200, '[]', 0, '', 6, 11, 0),
#  (655370, '[]', 0, '', 53, 5, 0),
#  (1732930, '[]', 0, '', 0, 0, 0),
#  (1355720, '[]', 0, '', 3, 0, 0),
#  (1139950, '[]', 0, '', 50, 8, 0),
#  (1469160, '[]', 0, '', 87, 49, 0),
#  (1659180, '[]', 0, '', 21, 7, 0),
#  (1968760, '[]', 0, '', 0, 0, 0),
#  (1178150, '[]', 0, '', 76, 6, 0),
#  (320150, '[]', 0, '', 225, 45, 0),
#  (1026420,
#   '["New WW2 Strategy Game Offers A Harrowing Look At Poland\'s Ill-Fated 1944 Uprising", \' in execution Warsaw manages to deliver its own experience entirely.\', \' Beautiful hand-painted artwork and turn-based combat \']',
#   62,
#   'https://www.metacritic.com/game/pc/warsaw?ftag=MCD-06-10aaa1f',
#   589,
#   212,
#   427),
#  (485000,
#   "['The art in Cthulhu Realms is hilarious and beautifully done, somehow complimenting the horror theme perfectly. The production value is top-notch.', 'It’s a surprisingly effective package that delivers a great little deck builder with a low price tag. If you can embrace the playful theme, you’ll find a pleasant gem in Cthulhu Realms.', 'It certainly is not just another deck-building game, but has original and fresh mechanics that will challenge your brain.']",
#   0,
#   '',
#   147,
#   58,
#   0),
#  (1620060, '[]', 0, '', 5, 0, 0),
#  (825930, '[]', 0, '', 36, 11, 0),
#  (1454010, '[]', 0, '', 100, 5, 0),
#  (22670,
#   '[]',
#   64,
#   'https://www.metacritic.com/game/pc/alien-breed-3-descent?ftag=MCD-06-10aaa1f',
#   349,
#   134,
#   285),
#  (1330820, '[]', 0, '', 17, 0, 0),
#  (346560,
#   "['Hero of the Kingdom II is a title that casual gamers should find to be very enjoyable, especially those who have appreciated the prequel.']",
#   0,
#   '',
#   2046,
#   120,
#   1615),
#  (1097880, '[]', 0, '', 0, 0, 1144),
#  (1362670, '[]', 0, '', 3, 1, 0),
#  (290870, '[]', 0, '', 61, 29, 0),
#  (575760, '[]', 0, '', 29, 28, 0),
#  (434030, '[]', 0, '', 1490, 408, 1831),
#  (810740, '[]', 0, '', 4, 10, 0),
#  (2073470, '[]', 0, '', 392, 57, 493),
#  (589250, '[]', 0, '', 37, 22, 0),
#  (677880, '[]', 0, '', 18, 50, 0),
#  (1294780, '[]', 0, '', 38, 4, 0),
#  (1342850, '[]', 0, '', 24, 5, 0),
#  (1177420, '[]', 0, '', 0, 0, 668),
#  (793990, '[]', 0, '', 23, 18, 0),
#  (1727670, '[]', 0, '', 11, 4, 0),
#  (955490, '[]', 0, '', 8, 4, 0),
#  (552350,
#   "['Unhappy Ever After is the result of a wicked mind’s imagination!']",
#   0,
#   '',
#   16,
#   10,
#   0),
#  (42500, '[]', 0, '', 258, 166, 210),
#  (1195610, '[]', 0, '', 1, 0, 0),
#  (1095380, '[]', 0, '', 7, 2, 0),
#  (1158910, '[]', 0, '', 16, 8, 0),
#  (1194940, '[]', 0, '', 35, 8, 0),
#  (262150, '[]', 0, '', 2014, 841, 1477),
#  (1192900, '[]', 0, '', 168, 39, 186),
#  (866150, '[]', 0, '', 55, 91, 0),
#  (231330,
#   '[]',
#   53,
#   'https://www.metacritic.com/game/pc/deadfall-adventures?ftag=MCD-06-10aaa1f',
#   1716,
#   628,
#   1140),
#  (1056520, '[]', 0, '', 0, 0, 0),
#  (897820,
#   "['Reigns: Game of Thrones is so much better than any other attempt to bring Game of Thrones to video games so far.', 'A Westerosi romp with welcome wrinkles to the established Reigns formula', 'Reigns is probably the best Game of Thrones game we’ve played to date.']",
#   84,
#   'https://www.metacritic.com/game/pc/reigns-game-of-thrones?ftag=MCD-06-10aaa1f',
#   698,
#   203,
#   815),
#  (658970, '[]', 0, '', 138, 84, 0),
#  (1777550, '[]', 0, '', 2, 2, 0),
#  (552520, '[]', 0, '', 100620, 25286, 114588),
#  (718350, '[]', 0, '', 2, 3, 0),
#  (433450, '[]', 0, '', 60, 46, 0),
#  (1709450, '[]', 0, '', 7, 1, 0),
#  (1431470, '[]', 0, '', 1, 0, 0),
#  (1794920, '[]', 0, '', 0, 0, 0),
#  (763550, '[]', 0, '', 3, 3, 0),
#  (1445370, '[]', 0, '', 6, 1, 0),
#  (464230, '[]', 0, '', 69, 17, 0),
#  (1293830, '[]', 0, '', 122539, 15095, 126316),
#  (1509640, '[]', 0, '', 2, 17, 0),
#  (1135380, '[]', 0, '', 6, 4, 0),
#  (1944730, '[]', 0, '', 10, 0, 0),
#  (1144900, '[]', 0, '', 0, 1, 0),
#  (306350, '[]', 0, '', 283, 92, 0),
#  (1684530, '[]', 0, '', 7, 2, 0),
#  (1557480, '[]', 0, '', 328, 253, 563),
#  (1128520, '[]', 0, '', 8, 0, 0),
#  (12140,
#   '[]',
#   89,
#   'https://www.metacritic.com/game/pc/max-payne?ftag=MCD-06-10aaa1f',
#   9516,
#   1114,
#   8684),
#  (1647430, '[]', 0, '', 1, 0, 0),
#  (1845050,
#   "['Pretty fun but it did sort of start to hurt my brain towards the end']",
#   0,
#   '',
#   17,
#   0,
#   0),
#  (1163340, '[]', 0, '', 180, 27, 185),
#  (1608620, '[]', 0, '', 0, 0, 0),
#  (541570,
#   "['Wholly unique gaming experience that has to be played to be believed', 'A psychological horror masterpiece', 'Positively oozes personality']",
#   0,
#   '',
#   11739,
#   367,
#   11287),
#  (1119070, '[]', 0, '', 0, 0, 0),
#  (1292520, '[]', 0, '', 51, 6, 0),
#  (1467330, '[]', 0, '', 1, 0, 0),
#  (1624600, '[]', 0, '', 7, 2, 0),
#  (870000, '[]', 0, '', 4, 6, 0),
#  (1621490, '[]', 0, '', 0, 0, 0),
#  (768060, '[]', 0, '', 31, 13, 0),
#  (1746130, '[]', 0, '', 0, 0, 0),
#  (1281400,
#   "['This game here is a sleeper hit! And if doesnt blow up, you can color me surprised! [This is the perfect example of innovative amazing indie games]', 'Who could have known filipino mythology is soo fucking RAD!', 'Good Knight is steeped in Filipino mythos. That’s unique for video games, let alone a traditionally-leaning shooter.']",
#   0,
#   '',
#   69,
#   0,
#   0),
#  (372890, '[]', 0, '', 10, 26, 0),
#  (1023420, '[]', 0, '', 0, 1, 0),
#  (1141880, '[]', 0, '', 15, 3, 0),
#  (1022840, '[]', 0, '', 20, 4, 0),
#  (652160, '[]', 0, '', 1, 0, 0),
#  (968580, '[]', 0, '', 1, 2, 0),
#  (1131550, '[]', 0, '', 168, 18, 179),
#  (1729790, '[]', 0, '', 102, 32, 0),
#  (368080,
#   '[\'A masterpiece that everyone should experience\', "A \'must have\' for every RPG gamer", \'Quite unexpected twists, to an epic final which is eaten with relish\']',
#   70,
#   'https://www.metacritic.com/game/pc/aurion-legacy-of-the-kori-odan?ftag=MCD-06-10aaa1f',
#   207,
#   98,
#   102),
#  (572510, '[]', 0, '', 12, 0, 0),
#  (1225870, '[]', 0, '', 0, 0, 0),
#  (1232510, '[]', 0, '', 44, 9, 0),
#  (1066890, '[]', 0, '', 4278, 491, 3874),
#  (817370, '[]', 0, '', 35, 11, 0),
#  (457140,
#   '[]',
#   86,
#   'https://www.metacritic.com/game/pc/oxygen-not-included?ftag=MCD-06-10aaa1f',
#   82902,
#   3014,
#   80467),
#  (1774810, '[]', 0, '', 1, 1, 0),
#  (1886290, '[]', 0, '', 12, 0, 0),
#  (1514360, '[]', 0, '', 245, 70, 293),
#  (1374280, '[]', 0, '', 50, 0, 0),
#  (863490, '[]', 0, '', 82, 26, 0),
#  (396640, '[]', 0, '', 288, 28, 228),
#  (726020, '[]', 0, '', 61, 16, 0),
#  (424060, '[]', 0, '', 8, 16, 0),
#  (514870,
#   '[\'Has some genuinely fun and clever moment-to-moment mechanics\', "Fat City is a tightly designed, refreshingly simple little title that will appeal to fans of arcade games. There\'s a level of accessibility afforded by intuitive controls and easy-to-understand rules; casual players should have no problem learning the basics and getting assisstance from optional items, while more skilled gamers will likely enjoy trying to get through each level using the fastest route... surprisingly fun time."]',
#   0,
#   '',
#   3,
#   0,
#   0),
#  (548290, '[]', 0, '', 124, 132, 0),
#  (695420, '[]', 0, '', 8, 0, 0),
#  (1241110,
#   '["Run for your life! ANARCHY is a challenging and fast-paced first person shooter game about escaping and shooting horde of robots! 4 differents levels with traps and parkour element. It\'s fun.", \'A clearly annoying game 😂😂, stressful since you are being chased, you also have the determination to want to finish all 4 areas, joy when you pass the courses as they are still difficult!\']',
#   0,
#   '',
#   12,
#   6,
#   0),
#  (587490, '[]', 0, '', 17, 17, 0),
#  (546050, '[]', 0, '', 4181, 806, 4195),
#  (301700, '[]', 0, '', 164, 95, 0),
#  (2004200, '[]', 0, '', 0, 1, 0),
#  (1588070, '[]', 0, '', 2, 8, 0),
#  (730310, '[]', 0, '', 3075, 6009, 5946),
#  (242530,
#   '[]',
#   40,
#   'http://www.metacritic.com/game/pc/the-chaos-engine',
#   245,
#   130,
#   226),
#  (1372570, '[]', 0, '', 21, 1, 0),
#  (1345820,
#   '["You know that scene in \'Mad Max: Fury Road\' where the cars are coming out after the good guys and they start drumming and rocking on the front of this war vehicle? That’s this whole game — every song is you feeling like you’re out there getting your crew to go faster and it’s just brilliant.", \'Ragnarock is a must-own title for anyone with a VR setup. It’s simply glorious!\', \'Ragnarock is a fantastic new addition to the rhythm action genre and is one of the most enjoyable games to hit VR\']',
#   87,
#   'https://www.metacritic.com/game/pc/ragnarock?ftag=MCD-06-10aaa1f',
#   2108,
#   111,
#   1996),
#  (420270, '[]', 0, '', 80, 50, 0),
#  (435790, '[]', 0, '', 2083, 481, 171),
#  (926310, '[]', 0, '', 242, 27, 259),
#  (788020, '[]', 0, '', 6, 2, 0),
#  (467400, '["Doesn\'t it look really rather good!"]', 0, '', 53, 11, 0),
#  (856730, '[]', 0, '', 1, 3, 0),
#  (1106950, '[]', 0, '', 1, 0, 0),
#  (1274570, '[]', 0, '', 41425, 3672, 34613),
#  (1470790, '[]', 0, '', 26, 24, 0),
#  (1087620, '[]', 0, '', 14, 2, 0),
#  (1348430, '[]', 0, '', 68, 3, 0),
#  (1547580,
#   '["F you\'re a fan of the Chichester series, this is an important prequel that ties up a lot of loose ends.", \'Welcome To Chichester 2, Chichester 2 takes the new instalment to a new level, that expands upon her story that will draw you in from the start.\', \'Well written and light-hearted, the story gives a few hours of content with great visuals to go along with it.\']',
#   0,
#   '',
#   6,
#   0,
#   0),
#  (1253680, '[]', 0, '', 79, 29, 0),
#  (1881210, '[]', 0, '', 0, 0, 0),
#  (497670,
#   '[\'[...] LineDash is profoundly addictive. Its lines and blocks collide with a pleasing thud. The whole screen shakes. What starts as a black-and-white color scheme gradually expands to neon shades on alternating black-or-white backgrounds. The game rewards reflexes with linear tableaus.\', "Soon, it\'s not about saving your lives, but about keeping the blocks from ruining the picture you\'ve created on your desktop. Dang squares, always trying to run my art!", \'LineDash is basically all there, but it is an entirely appropriate there to the purchase price and definitely a game that can offer involvement, fun, a sensible nontrivial challenge, and that bit of addiction that can make the fortune of such games.\']',
#   0,
#   '',
#   25,
#   7,
#   0),
#  (850040, '[]', 0, '', 15, 1, 0),
#  (7940,
#   '[]',
#   92,
#   'https://www.metacritic.com/game/pc/call-of-duty-4-modern-warfare?ftag=MCD-06-10aaa1f',
#   16788,
#   1211,
#   13997),
#  (741770, '[]', 0, '', 9, 4, 0),
#  (110630, '[]', 0, '', 33, 15, 0),
#  (572330, '[]', 0, '', 72, 43, 0),
#  (1683240, '[]', 0, '', 10, 10, 0),
#  (567150, '[]', 0, '', 68, 20, 0),
#  (700880, '[]', 0, '', 2, 0, 0),
#  (1413090, '[]', 0, '', 26, 0, 0),
#  (1610860,
#   '[\'One of my favourite indie games I’ve had the pleasure to play this year\', "Basically, Merek\'s Market is a lot of fun", \'I thoroughly enjoyed falling out with friends and family\']',
#   0,
#   '',
#   16,
#   0,
#   0),
#  (1302840, '[]', 0, '', 8, 0, 0),
#  (1305570, '[]', 0, '', 11, 9, 0),
#  (1609730, '[]', 0, '', 69, 2, 0),
#  (717980, '[]', 0, '', 72, 8, 0),
#  (1417450, '[]', 0, '', 1, 0, 0),
#  (778900, '[]', 0, '', 1, 0, 0),
#  (1004200,
#   '[\'The skiing feels good.\', "This is a cool early access skiing game. It\'s a good variation for your cardio / upper body workout. To burn extra calories, instead of finishing the course, turn around and ski back up the hill! There\'s a shooting range as well if you want some target practice."]',
#   0,
#   '',
#   15,
#   11,
#   0),
#  (1506230, '[]', 0, '', 73, 15, 0),
#  (638230,
#   '[\'Journey stands as a prime example of the truly remarkable things that can be done via this medium.\', \'The mechanics are simple, but they establish a direct connection to the heart.\', "Journey\'s visual and sound design sets new standards for interactive entertainment. This alone makes it an extraordinary work, but it\'s the way that these aesthetic elements come together with beautifully subtle direction and storytelling to create a lasting emotional effect that elevates this to one of the very best games of our time."]',
#   0,
#   '',
#   20432,
#   1120,
#   19825),
#  (1839080,
#   "['Hours of enjoyment, and limitless pointless possibilities', 'Now this is epic', 'This game looks so fun']",
#   0,
#   '',
#   26,
#   3,
#   0),
#  (907460, '[]', 0, '', 11, 18, 0),
#  (1307070,
#   "['Vetrix is the VR Tetris Everyone Should Have in Their Library', 'If you have a PC VR system that is compatible with Vetrix I recommend, Family Friendly Gaming Universe checks this game out.']",
#   0,
#   '',
#   41,
#   0,
#   0),
#  (1221640, '[]', 0, '', 65, 3, 0),
#  (703120, '[]', 0, '', 14, 8, 0),
#  (328710, '[]', 0, '', 65, 38, 0),
#  (926140,
#   "['With this rich, emotional overlay, coupled with some deep, appealing mechanics, CHANGE is an enthralling survival experience from start to finish.', 'Change is a gritty, hand-crafted, labor of love that transcends its simple, pixilated aesthetic. It asks questions of the player which will hopefully be pondered at some point during playthroughs. I know I did.', 'PREVIEW: ...the game says a bit more, a bit more deeply, about being homeless. And it starts to sink in, the bleak reality, even though the graphics are pixelated and even though it is, inescapably, a game experience.']",
#   0,
#   '',
#   1640,
#   145,
#   1656),
#  (1700630, '[]', 0, '', 79, 43, 117),
#  (845290, '[]', 0, '', 24, 6, 0),
#  (739720, '[]', 0, '', 37, 3, 0),
#  (1776800, '[]', 0, '', 2, 0, 0),
#  (873970, '[]', 0, '', 14, 11, 0),
#  (1238130, '[]', 0, '', 0, 0, 0),
#  (1593100, '[]', 0, '', 13, 5, 0),
#  (1365900, '[]', 0, '', 10, 1, 0),
#  (962950, '[]', 0, '', 14, 2, 0),
#  (778120, '[]', 0, '', 3, 3, 0),
#  (1187910, '[]', 0, '', 2, 1, 0),
#  (763350, '[]', 0, '', 8, 1, 0),
#  (1537410, '[]', 0, '', 5, 0, 0),
#  (761910,
#   '[]',
#   76,
#   'https://www.metacritic.com/game/pc/worbital?ftag=MCD-06-10aaa1f',
#   332,
#   33,
#   317),
#  (975470,
#   '[]',
#   51,
#   'https://www.metacritic.com/game/pc/silver-chains?ftag=MCD-06-10aaa1f',
#   420,
#   147,
#   377),
#  (990900,
#   "['Like Opus Magnum, the only thing stopping you from having the recipe being as wonky as a dropped omelette is your own sense of aesthetics.', 'Do you like Overcooked? Do you hate playing with other people? Do you wish you could replace them with little robots and code them to do the cooking for you?', 'The controls and design are intuitive, and also immensely satisfying. Programming a robot to cook might not sound like thrilling gameplay, but trust me—get that little guy making sushi for you and you’ll be singing its praises, too.']",
#   0,
#   '',
#   33,
#   1,
#   0),
#  (372770, '[]', 0, '', 5, 2, 0),
#  (462580, '[]', 0, '', 12, 5, 0),
#  (926870, '[]', 0, '', 1, 0, 0),
#  (848720, '[]', 0, '', 3, 1, 0),
#  (1343040, '[]', 0, '', 58, 13, 0),
#  (519140, '[]', 0, '', 1078, 440, 0),
#  (1987030, '[]', 0, '', 0, 0, 0),
#  (821260,
#   '[]',
#   49,
#   'https://www.metacritic.com/game/pc/light?ftag=MCD-06-10aaa1f',
#   5,
#   4,
#   0),
#  (1565720, '[]', 0, '', 5, 0, 0),
#  (748490,
#   '[]',
#   81,
#   'https://www.metacritic.com/game/pc/the-legend-of-heroes-trails-of-cold-steel-ii?ftag=MCD-06-10aaa1f',
#   2113,
#   125,
#   1992),
#  (545000, '[]', 0, '', 2, 1, 0),
#  (1623720, '[]', 0, '', 1, 2, 0),
#  (544220, '[]', 0, '', 5, 13, 0),
#  (338190, '[]', 0, '', 185, 28, 156),
#  (1375270, '[]', 0, '', 8, 0, 0),
#  (551680, '[]', 0, '', 14, 17, 0),
#  (1874510, '[]', 0, '', 0, 0, 0),
#  (1693780, '[]', 0, '', 7, 9, 0),
#  (1466930, '[]', 0, '', 115, 73, 122),
#  (1748070, '[]', 0, '', 0, 0, 0),
#  (964920, '[]', 0, '', 7, 8, 0),
#  (1085570, '[]', 0, '', 8, 0, 0),
#  (1528020, '[]', 0, '', 71, 9, 0),
#  (1796350, '[]', 0, '', 0, 1, 0),
#  (1444320, '[]', 0, '', 20, 1, 0),
#  (906050, '[]', 0, '', 54, 29, 205),
#  (351910,
#   "['As simulation games go few can match Valhalla Hills […]. It combines all the best parts of other simulation games into one great package.', 'I was right at home when playing Valhalla Hills. It carries the spirit of strategy simulations like Settlers and Cultures really well.', 'Valhalla Hills is a fun game that any fan of The Settlers or any similar game would enjoy.']",
#   69,
#   'https://www.metacritic.com/game/pc/valhalla-hills?ftag=MCD-06-10aaa1f',
#   646,
#   544,
#   604),
#  (513480, '[]', 0, '', 138, 22, 0),
#  (1089830,
#   '[]',
#   72,
#   'https://www.metacritic.com/game/pc/monster-energy-supercross---the-official-videogame-3?ftag=MCD-06-10aaa1f',
#   900,
#   126,
#   735),
#  (403070, '[]', 0, '', 41, 8, 0),
#  (811440, '[]', 0, '', 1, 0, 0),
#  (491010, '[]', 0, '', 61, 15, 0),
#  (681290, '[]', 0, '', 11, 1, 0),
#  (1233460, '[]', 0, '', 1, 1, 0),
#  (350530, '[]', 0, '', 94, 107, 101),
#  (1481840, '[]', 0, '', 7, 0, 0),
#  (1444890, '[]', 0, '', 13, 2, 0),
#  (1217340, '[]', 0, '', 16, 14, 0),
#  (872340, '[]', 0, '', 5, 2, 0),
#  (523680, '[]', 0, '', 32, 9, 0),
#  (439460, '[]', 0, '', 63, 114, 148),
#  (1308880, '[]', 0, '', 46, 25, 0),
#  (296650,
#   "['A frighteningly fun ride that shouldn’t be missed by fans of quirky action puzzles!', 'Fun carnival haunted house vibe.', 'Pudding Panic, most definitely not a game for the faint of heart, will provide hours of entertainment if you love action, horror and rollercoaster rides.']",
#   0,
#   '',
#   48,
#   26,
#   0),
#  (1549420, '[]', 0, '', 25, 1, 0),
#  (418270, '[]', 0, '', 388, 373, 121),
#  (390220,
#   "['A funny retro style economic simulation. Toilet Tycoon is big fun for a game every now and then.']",
#   0,
#   '',
#   102,
#   47,
#   115),
#  (549860,
#   "['All things are possible in this beautifully observed visual novel.', 'One Night Stand is a small, polished slice of what feels like a real human interaction.', 'This is the kind of indie experimental experience that proves games really can cover a gamut of emotions.']",
#   0,
#   '',
#   546,
#   67,
#   521),
#  (612380, '[]', 0, '', 5, 3, 0),
#  (1559340, '[]', 0, '', 0, 0, 0),
#  (1632640, '[]', 0, '', 7, 3, 0),
#  (350480,
#   "['It’s a solid game, full of wit and humor.', 'The look and design appealed enormously.', 'If you love sci-fi, the theme of isolation, and weird animal astronauts, you’ll have a good time with Tales of Cosmos.']",
#   0,
#   '',
#   41,
#   8,
#   0),
#  (220900, "['Verdict: Trees suck']", 0, '', 225, 128, 0),
#  (539090, '[]', 0, '', 23, 8, 0),
#  (908500, '[]', 0, '', 12, 11, 0),
#  (1852760, '[]', 0, '', 0, 0, 0),
#  (809890,
#   '[]',
#   68,
#   'https://www.metacritic.com/game/pc/shining-resonance-refrain?ftag=MCD-06-10aaa1f',
#   770,
#   316,
#   751),
#  (570770, '[]', 0, '', 1802, 518, 2166),
#  (448500, '[]', 0, '', 34, 2, 0),
#  (854160, '[]', 0, '', 10, 30, 0),
#  (1359170, '[]', 0, '', 8, 3, 0),
#  (897010, '[]', 0, '', 2, 0, 0),
#  (1607870, '[]', 0, '', 1, 0, 0),
#  (553260,
#   "['Interesting mechanics, exciting story and a few bugs make this global strategy game great choice for all the lovers of foreign affairs and military interventions', 'Realpolitiks is a very fun, polished, easy to use grand strategy game that will suck up your time and you won’t regret any of it', 'Realpolitiks is the right solution for anyone who wants to try their hand at the role of leader of one of the world superpowers or even a state of minor importance']",
#   52,
#   'https://www.metacritic.com/game/pc/realpolitiks?ftag=MCD-06-10aaa1f',
#   671,
#   404,
#   798),
#  (453130,
#   '[\'Wee Free Studio’s Powargrid pumps out witty writing, devilish AI, and simply serious strategy.\', "Winning a game of Powargrid isn\'t exactly an easy feat thanks to the intelligent AI that tries - and often succeeds - to outsmart the player at every turn.", \'Powargrid is funny... and a very good game!\']',
#   0,
#   '',
#   27,
#   5,
#   0),
#  (1508890, '[]', 0, '', 0, 0, 0),
#  (3010,
#   '[]',
#   82,
#   'https://www.metacritic.com/game/pc/xpand-rally?ftag=MCD-06-10aaa1f',
#   293,
#   73,
#   311),
#  (1297480, '[]', 0, '', 1, 1, 0),
#  (1217830, '[]', 0, '', 116, 2, 0),
#  (628830,
#   "['Ultra Hat Dimension is a perfect example of how wonderful things can happen if you polish up a simple idea and execute it well. If you like your puzzle games smart and heavy on the charm, this is the title for you.', 'Contrary to how it may at first sound, Ultra Hat Dimension is not a washed up European trance DJ duo, but is an excellent puzzle game that features all of the aforementioned head dressings.']",
#   0,
#   '',
#   24,
#   0,
#   0),
#  (686440, '[]', 0, '', 152, 25, 160),
#  (521710, '[]', 0, '', 9, 9, 0),
#  (1259660, '[]', 0, '', 3, 0, 0),
#  (108200, '[]', 0, '', 3942, 419, 2753),
#  (614150, '[]', 0, '', 10, 0, 0),
#  (304970, '[]', 0, '', 1, 0, 0),
#  (1630940, '[]', 0, '', 5, 1, 0),
#  (878520, '[]', 0, '', 66, 27, 0),
#  (1927300, '[]', 0, '', 0, 0, 0),
#  (340630,
#   "['This is the stuff memes are made of. It’s pretty easy to figure out why Immunity Studios decided to create a game about a ninja trainee with an overdone accent, who takes orders from a beret-wearing cow: it’s ripe ground for some of the most hilarious one-liners ever delivered on iOS.']",
#   0,
#   '',
#   42,
#   119,
#   0),
#  (704310, '[]', 0, '', 10, 5, 0),
#  (619150,
#   '["WT:L has truly turned out to be a one-of-a-kind title. It\'s a rare case when a studio tackles a bold task and manages to create a game never seen before.", \'WT:L is a fantastic puzzle game\', \'Want to understand neural networks? This game might teach you how.\']',
#   0,
#   '',
#   5491,
#   477,
#   5423),
#  (1373890, '[]', 0, '', 1, 0, 0),
#  (1869200, '[]', 0, '', 14, 0, 0),
#  (392030, '[]', 0, '', 85, 8, 0),
#  (605850, '[]', 0, '', 47, 14, 0),
#  (441670, '[]', 0, '', 237, 65, 266),
#  (962150, '[]', 0, '', 20, 6, 0),
#  (50990, '[]', 0, '', 68, 7, 0),
#  (648510, '[]', 0, '', 8, 3, 0),
#  (1071070, '[]', 0, '', 2, 0, 0),
#  (1761740, '[]', 0, '', 25, 5, 0),
#  (538700, '[]', 0, '', 1, 2, 0),
#  (1564150, '[]', 0, '', 24, 0, 0),
#  (726870,
#   '[\'[...] in my book this game is the ultimate work of interactive fiction, overflowing with intrigue and compelling story elements, scary and engrossing, exceptionally written and impressively coded with a remarkable eye for detail.\', "As IF goes, though, this is a deeply beautiful piece. [...] There\'s lots of disgusting, unpleasant imagery, but first -- and en route to that imagery -- is a masterful build-up of setting and mood unparalleled by almost any other game I have ever played.", \'Overall, the experience of playing Anchorhead was incredibly rich and memorable—not for the difficulty navigating, or for the puzzles, but for the immersive experience it provided.\']',
#   0,
#   '',
#   35,
#   2,
#   0),
#  (1074390, '[]', 0, '', 5, 0, 0),
#  (1554780, '[]', 0, '', 14, 3, 0),
#  (1065750, '[]', 0, '', 57, 3, 0),
#  (714780, '[]', 0, '', 35, 5, 0),
#  (1321040, '[]', 0, '', 47, 0, 0),
#  (1204930, '[]', 0, '', 83, 1, 0),
#  (1588760, '[]', 0, '', 59, 7, 0),
#  (924740, '[]', 0, '', 22, 16, 0),
#  (416340, '[]', 0, '', 25, 5, 0),
#  (242610, '[]', 0, '', 17, 3, 0),
#  (1168980, '[]', 0, '', 6, 14, 0),
#  (1277340, '[]', 0, '', 2, 0, 0),
#  (1233610, '[]', 0, '', 1, 5, 0),
#  (302610,
#   "['A brilliant, twitchy arcade masterpiece that pulsates with originality and heart', 'A massively unique take on the endless runner genre', 'An amazingly compelling game']",
#   0,
#   '',
#   1426,
#   109,
#   1284),
#  (1638730, '[]', 0, '', 0, 0, 0),
#  (1484150, '[]', 0, '', 1, 2, 0),
#  (922520, '[]', 0, '', 18, 0, 0),
#  (1157200, '[]', 0, '', 3, 0, 0),
#  (1862100, '[]', 0, '', 5, 0, 0),
#  (2022020, '[]', 0, '', 11, 1, 0),
#  (1099400, '[]', 0, '', 29, 13, 0),
#  (503060, '[]', 0, '', 14, 0, 0),
#  (1275970, '[]', 0, '', 3, 5, 0),
#  (847490, '[]', 0, '', 5, 0, 0),
#  (1101580, '[]', 0, '', 0, 0, 363),
#  (201010, '[]', 0, '', 95, 7, 0),
#  (837610,
#   '[\'There are many ways this game could’ve come off as just another Japanese DRPG. To its enormous credit, it avoids all those pitfalls, and makes an interesting game in the process.\', "Mary Skelter is sublime. By turns darkly sensual and horrific, it\'s also beautiful, ravishing, and backed by truly expert level design and a clean, clever combat system. This game is too different to effectively compare to other dungeon crawlers, but I must say, of all the many games in this genre that I\'ve played, this one will sit with me for a very long time into the future.", \'Mary Skelter: Nightmares provides the dungeon crawling experience fans of the genre crave. The game offers a unique battle system that requires attention and skill to master, many different ways to customize characters, and large dungeons to explore with many hidden rooms and valuable loot.\']',
#   0,
#   '',
#   421,
#   54,
#   429),
#  (1029870, '[]', 0, '', 54, 15, 0),
#  (205690, '[]', 0, '', 250, 71, 122),
#  (632240, '[]', 0, '', 2, 0, 0),
#  (898910, '[]', 0, '', 15, 0, 0),
#  (1042930, '[]', 0, '', 16, 7, 0),
#  (109500, '[]', 0, '', 106, 74, 124),
#  (539290, '[]', 0, '', 35, 42, 0),
#  (1603600, '[]', 0, '', 3, 0, 0),
#  (489100, '[]', 0, '', 9, 1, 0),
#  (1310620, '[]', 0, '', 1, 0, 0),
#  (740450, '[]', 0, '', 2, 0, 0),
#  (1646090, '[]', 0, '', 12, 0, 0),
#  (448670, '[]', 0, '', 52, 32, 0),
#  (542740, '[]', 0, '', 57, 72, 0),
#  (687980, '[]', 0, '', 351, 19, 0),
#  (612120, '[]', 0, '', 9, 8, 0),
#  (1259000, '[]', 0, '', 189, 54, 0),
#  (1380060, '[]', 0, '', 15, 9, 0),
#  (814560,
#   '[\'The amount of enjoyment we get from it is a retarded huge return on investment.\', "I\'m Tim the dragon!"]',
#   0,
#   '',
#   1,
#   0,
#   0),
#  (701100, '[]', 0, '', 49, 15, 0),
#  (1407060, '[]', 0, '', 19, 3, 0),
#  (1495860, '[]', 0, '', 205, 15, 203),
#  (1126970, '[]', 0, '', 1, 0, 0),
#  (1639530, '[]', 0, '', 5, 5, 0),
#  (1995420, '[]', 0, '', 0, 0, 0),
#  (358000,
#   "['…this golf-simulator-slash-action-adventure title thinks outside the box. I saw it on the PAX East show floor last weekend and thought it was so bizarre, I had to tape it.', 'The Curse of Nordic Cove is a very unique title set in a world unlike anything you’ve probably seen or played before. Combining your golf  skills with your surely honed FPS talents to create a title that is borderline insanity…in a good way! When I asked the creator of how this odd combo of golf/FPS came about, he told me he was hitting the links and had a simple thought- “What if Vikings invaded the course right now?']",
#   0,
#   '',
#   15,
#   15,
#   0),
#  (1856080, '[]', 0, '', 0, 2, 0),
#  (239430,
#   "['Q.U.B.E. offers a delightful on-screen Rubik’s Cube to puzzle-lovers', 'Q.U.B.E. is one of those works that you should not miss', 'The narrative is suspenseful and the puzzles are fantastic brainteasers']",
#   0,
#   '',
#   1438,
#   285,
#   723),
#  (961490, '[]', 0, '', 298, 43, 311),
#  (363500,
#   "['Bizarrely funny and often downright confusing, the game aspires to confuse the player’s interpretation of sensible reality, leaving their interpretation of the game world and its inhabitants pliant.', 'Proving once again that the adventure genre will never die, this game shows just how much life there is in the genre, even amidst the crumbling bones of the dead.', 'If you’ve ever stared at a list of upcoming releases and wished for something extraordinary to shake things up, pay attention to Ossuary.']",
#   0,
#   '',
#   33,
#   3,
#   0),
#  (286750,
#   '[]',
#   59,
#   'https://www.metacritic.com/game/pc/zoo-empire?ftag=MCD-06-10aaa1f',
#   98,
#   32,
#   111),
#  (388080,
#   '["Games are best when played full screen, but many won\'t play nice with Alt+Tab in full screen mode—which means you can\'t look at your browser for a guide or change the music playing in the background. Borderless Gaming fixes that problem.", \'Without a doubt, this is essential software when considering how many publishers treat PC gaming as an afterthought.\']',
#   0,
#   '',
#   2461,
#   336,
#   2619),
#  (1565630, '[]', 0, '', 4, 0, 0),
#  (925360, '[]', 0, '', 5, 1, 0),
#  (482300, '[]', 0, '', 654, 277, 775),
#  (964910, '[]', 0, '', 3, 3, 0),
#  (16130, '[]', 0, '', 58, 12, 0),
#  (1716950, '[]', 0, '', 14, 0, 0),
#  (411530, '[]', 0, '', 27, 9, 0),
#  (237430,
#   '[]',
#   77,
#   'https://www.metacritic.com/game/pc/expeditions-conquistador?ftag=MCD-06-10aaa1f',
#   1079,
#   268,
#   1011),
#  (485120,
#   "['If you like couch games like me, I advise you to try Frog Climbers.', 'Frog Climbers is an insane, strange little party/arcade game from indie studio TeamCrew']",
#   0,
#   '',
#   131,
#   28,
#   0),
#  (1907570, '[]', 0, '', 0, 0, 0),
#  (528670, '[]', 0, '', 11, 7, 0),
#  (417540, '[]', 0, '', 9, 6, 0),
#  (1496530,
#   "['I’m normally not a gamer, but I love playing Cinders of Hades! It’s easy to pick up and learn. Right off the bat, I felt like I had first-timer’s luck winning 35,000 points shooting at flying dragons, burning rocks, and a host of other creatures. What fun!']",
#   0,
#   '',
#   1,
#   2,
#   0),
#  (465070, '[]', 0, '', 22, 2, 0),
#  (448010, '[]', 0, '', 31, 6, 0),
#  (782630, '[]', 0, '', 12, 4, 0),
#  (1162170, '[]', 0, '', 0, 0, 0),
#  (1941850, '[]', 0, '', 1, 0, 0),
#  (1467740, '[]', 0, '', 15, 13, 0),
#  (1212930, '[]', 0, '', 5, 1, 0),
#  (1580990, '[]', 0, '', 0, 0, 0),
#  (1975670, '[]', 0, '', 30, 3, 0),
#  (1808480, '[]', 0, '', 3, 2, 0),
#  (818070, '[]', 0, '', 0, 1, 0),
#  (1271190, '[]', 0, '', 0, 0, 523),
#  (944590, '[]', 0, '', 29, 3, 0),
#  (1299400, '["Are you kidding me? That\'s a troll."]', 0, '', 409, 31, 430),
#  (958090, "['Good game']", 0, '', 30, 7, 0),
#  (607040, '[]', 0, '', 44, 15, 0),
#  (1301850, '[]', 0, '', 49, 16, 0),
#  (299380, '[]', 0, '', 15, 42, 0),
#  (1626950,
#   "['Case of Maneki, explore the worlds and their cultures but not all seems innocent as a series of gruesome murders happens.']",
#   0,
#   '',
#   3,
#   0,
#   0),
#  (342260, '[]', 0, '', 319, 93, 320),
#  (1684920, '[]', 0, '', 8, 2, 0),
#  (888010,
#   "['A point-and-click adventure based heavily on history’s greatest tango singer, Tango benefits from excellent production values and a promising story premise']",
#   0,
#   '',
#   50,
#   9,
#   0),
#  (538950, '[]', 0, '', 48, 8, 0),
#  (293520, '[]', 0, '', 573, 209, 654),
#  (502940, '[]', 0, '', 846, 99, 864),
#  (1395560, '[]', 0, '', 2535, 248, 2186),
#  (1038680, '[]', 0, '', 11, 10, 0),
#  (291690,
#   "['A title you should definitely play if you enjoy puzzles and enjoy a good story that is not spelled out for you.', 'I found Empathy: Path of Whispers to be incredible.', 'The story might be the most interesting one I have encountered in the genre']",
#   59,
#   'https://www.metacritic.com/game/pc/empathy-path-of-whispers?ftag=MCD-06-10aaa1f',
#   110,
#   69,
#   133),
#  (1246200, '[]', 0, '', 1, 0, 0),
#  (1581010, '[]', 0, '', 0, 3, 0),
#  (1690250, '[]', 0, '', 0, 0, 0),
#  (653210, '[]', 0, '', 22, 15, 0),
#  (267360, '[]', 0, '', 427, 43, 306),
#  (1694430, '[]', 0, '', 55, 19, 0),
#  (1886850, '[]', 0, '', 17, 16, 0),
#  (499910, '[]', 0, '', 98, 8, 105),
#  (1863170, '[]', 0, '', 6, 2, 0),
#  (1644840,
#   "['This game had me smiling during a tough time in my life...']",
#   0,
#   '',
#   108,
#   6,
#   0),
#  (1422880,
#   '[\'4 Zones with different aesthetics 4 types of puzzles with a frisbee to solve And most importantly... 4 fun!\', "This game is amazing! So much fun. It\'s been really fun to play!"]',
#   0,
#   '',
#   17,
#   2,
#   0),
#  (12460, '[]', 0, '', 113, 75, 167),
#  (410320,
#   '[]',
#   79,
#   'https://www.metacritic.com/game/pc/earth-defense-force-41-the-shadow-of-new-despair?ftag=MCD-06-10aaa1f',
#   7129,
#   401,
#   5577),
#  (1345440, '[]', 0, '', 33, 1, 0),
#  (757600,
#   "['Hotel Transylvania 3: Monsters Overboard is great for kids and those who like both the movies and Pikmin.', 'This review request was driven by my kids, but I’m thankful they pushed me towards it because Hotel Transylvania 3: Monsters Overboard is a fantastic experience on the system.']",
#   0,
#   '',
#   10,
#   4,
#   0),
#  (952000, '[]', 0, '', 4, 0, 0),
#  (1735930, '[]', 0, '', 13, 13, 0),
#  (336670,
#   '[\'An objective-driven co-op shooter set in the big colourful world of ’70s espionage flicks sounds splendid. One where a member of your spy team is also a traitor, that’s even better.\', "Dude, there\'s so much more to this game...", \'The Debutante, a Jessica Rabbit look-alike in a tight pink dress, bounds through a mansion trying to stop a missile launch, all while dodging bullets and knife blades.\']',
#   0,
#   '',
#   181,
#   298,
#   0),
#  (733420, '[]', 0, '', 3, 1, 0),
#  (1528770, '[]', 0, '', 4, 2, 0),
#  (542260, '[]', 0, '', 559, 35, 514),
#  (369560,
#   "['I have been ungodly addicted to this game...', 'Every time I thought I had experienced everything, I encountered something new and unexpected.', 'One for hack ‘n’ slash fans to keep an eye out for...']",
#   0,
#   '',
#   102,
#   19,
#   0),
#  (1494400, '[]', 0, '', 40, 12, 0),
#  (394850, '[]', 0, '', 117, 31, 120),
#  (953900, '[]', 0, '', 148, 29, 145),
#  (299480,
#   '[]',
#   68,
#   'https://www.metacritic.com/game/pc/rogue-stormers?ftag=MCD-06-10aaa1f',
#   656,
#   297,
#   626),
#  (1530670, '[]', 0, '', 11, 5, 0),
#  (1260220, '[]', 0, '', 0, 0, 0),
#  (1503530, '[]', 0, '', 184, 6, 184),
#  (750960, '[]', 0, '', 67, 5, 0),
#  (1898130, '[]', 0, '', 0, 0, 0),
#  (523210,
#   '[\'It shares some of the feeling of Her Story, albeit featuring today’s technology and with less of a focus on the crime angle. But it has the same small moments of revelation, all of which come together to form a story in its own neat yet meandering way.\', \'A Normal Lost Phone is thoughtfully designed, leveraging voyeurism, curiosity, responsibility, and compassion to tell a strong, character-driven story unlocked through satisfying puzzle-solving.\', "This is a game that\'ll suck you in to its movements quickly, and hold you there until you reach the end of its tale."]',
#   71,
#   'https://www.metacritic.com/game/pc/a-normal-lost-phone?ftag=MCD-06-10aaa1f',
#   1845,
#   231,
#   1720),
#  (1278170, '[]', 0, '', 52, 31, 0),
#  (950400,
#   "['Graphics looks nice... this game kinda looks serious', 'Reminded me a lot of Resident Evil and Outlast 2', 'This could be promising after seeing the trailer at the end']",
#   0,
#   '',
#   59,
#   70,
#   119),
#  (766570, '[]', 0, '', 19370, 5757, 0),
#  (1694450, '[]', 0, '', 0, 0, 0),
#  (1343220, '[]', 0, '', 0, 0, 0),
#  (1672700, '[]', 0, '', 6, 0, 0),
#  (1338020, '[]', 0, '', 58, 2, 0),
#  (1213420, '[]', 0, '', 24, 17, 0),
#  (1385820, '[]', 0, '', 1, 0, 0),
#  (848460, '[]', 0, '', 0, 1, 0),
#  (735650, '[]', 0, '', 4, 0, 0),
#  (1048100, '[]', 0, '', 2509, 651, 2699),
#  (345700, '[]', 0, '', 94, 57, 0),
#  (65600, '[]', 0, '', 474, 459, 702),
#  (674250, '[]', 0, '', 23, 4, 0),
#  (439250, '[]', 0, '', 291, 48, 277),
#  (1788650, '[]', 0, '', 2, 0, 0),
#  (1239710, '[]', 0, '', 0, 0, 0),
#  (1275060, '[]', 0, '', 7, 4, 0),
#  (940350, '[]', 0, '', 5, 8, 0),
#  (868060,
#   "['... Immortal Darkness is a fun dungeon romp with clever environmental puzzles.', '... a deliciously unforgettable RPG dungeon crawler.']",
#   0,
#   '',
#   39,
#   7,
#   0),
#  (1284550, '[]', 0, '', 32, 8, 0),
#  (924670,
#   "['醉汉视角的赛车游戏？Steam最近上线了一款非常魔性的独立搞笑游戏《醉驾模拟器》（《Need for Spirit: Drink &amp; Drive Simulator》），玩家扮演一名憨厚的货车司机师傅，游戏中最大的障碍是你浓郁的醉意[吐]，', '《醉驾模拟器》登陆Steam 深刻感悟醉驾带来的危害', 'DRIVING DRUNK? WHY NOT! l Need for Spirit Simulator - review on his gaming channel']",
#   0,
#   '',
#   70,
#   51,
#   0),
#  (598590, '[]', 0, '', 9, 2, 0),
#  (620050, '[]', 0, '', 38, 26, 0),
#  (454330,
#   "['Excellent cliff-hangers. The dev has really nailed the cliffhangers that each episode ends with.', '[The Game] does its frights up right, using a superb, intentionally crude yet perfect and gorgeous “2.5D']",
#   0,
#   '',
#   18,
#   5,
#   0),
#  (1723050, '[]', 0, '', 1, 2, 0),
#  (763230,
#   "['WOW! From humour to gameplay, it all is there already!', 'Oh I f*cking love this game. It is adorable.']",
#   0,
#   '',
#   175,
#   24,
#   0),
#  (959710,
#   '[\'The earth is a better person than me is a game that offers a ludic contribution to the ongoing cultural commentary about how humanity sometimes needs to disconnect from the trappings of society in order to regain a broader perspective.\', "The earth is a better person than me walks a complex tightrope with its bond with nature, coming so close Delphine can become its literal lover through her growing connection, yet still lonely in this bond outside of human contact. It\'s a heady journey into self image and sexuality and connections to the natural world, one that creates a dizzying bond with Delphine as you help her speak her mind to these living places."]',
#   0,
#   '',
#   0,
#   0,
#   0),
#  (1140060, '[]', 0, '', 1, 3, 0),
#  (1644920, '[]', 0, '', 42, 4, 0),
#  (957070, '[]', 0, '', 93, 4, 0),
#  (1270780, '[]', 0, '', 1, 0, 0),
#  (1702210, '[]', 0, '', 12, 0, 0),
#  (1302270, '[]', 0, '', 7, 0, 0),
#  (974930, '[]', 0, '', 0, 0, 0),
#  (1017480, '[]', 0, '', 11, 9, 0),
#  (676030,
#   "['If you’re looking for something with a real-time strategy  flavour, pick-up and play gameplay and some decent replay options then White Noise Games’ new virtual reality  title Eternal Starlight ticks plenty of those boxes.']",
#   0,
#   '',
#   44,
#   3,
#   0),
#  (1728410, '[]', 0, '', 3, 0, 0),
#  (1165280, '[]', 0, '', 7, 5, 0),
#  (1095120, '[]', 0, '', 136, 8, 0),
#  (818390, '[]', 0, '', 22, 9, 0),
#  (1245470, '[]', 0, '', 44, 14, 0),
#  (839770,
#   "['Elegant, atmospheric, and energetic, [Julian] Gollop’s latest remains remarkably hard to put down.', 'If you like XCOM then you’re going to love Phoenix Point.', 'Phoenix Point is, without a doubt, one of the best strategy games to come out in the last few years.']",
#   74,
#   'https://www.metacritic.com/game/pc/phoenix-point?ftag=MCD-06-10aaa1f',
#   3087,
#   1188,
#   3237),
#  (1874660, '[]', 0, '', 69, 38, 0),
#  (562640, '[]', 0, '', 74, 28, 0),
#  (360840,
#   "['If you are in the mood for something restful, I’d say it’s well worth dipping a toe in the water.', 'Lumini is a beautiful, relaxing and captivating experience… even if you think it’s not for you, I urge you to grab a gamepad and spend some time with it', 'The type of game where you find yourself making detours or flying in loops just because it feels awesome doing so']",
#   69,
#   'https://www.metacritic.com/game/pc/lumini?ftag=MCD-06-10aaa1f',
#   128,
#   20,
#   0),
#  (1007890, '[]', 0, '', 0, 0, 0),
#  (1030840, '[]', 0, '', 37900, 5785, 32979),
#  (1234450, '[]', 0, '', 15, 27, 0),
#  (890130, '[]', 0, '', 46, 3, 0),
#  (1093880, '[]', 0, '', 72, 71, 128),
#  (1896980, '[]', 0, '', 4, 0, 0),
#  (368730, '[]', 0, '', 1852, 496, 1170),
#  (1041300, '[]', 0, '', 3, 3, 0),
#  (572620, '[]', 0, '', 104, 20, 110),
#  (1581500, '[]', 0, '', 25, 0, 0),
#  (318260, '[]', 0, '', 70, 38, 0),
#  (821880,
#   '[]',
#   73,
#   'https://www.metacritic.com/game/pc/idol-manager?ftag=MCD-06-10aaa1f',
#   2479,
#   301,
#   2533),
#  (886360, '[]', 0, '', 17, 11, 0),
#  (1408480, '[]', 0, '', 6, 1, 0),
#  (696760,
#   "['It’s this sort of attention to detail that makes HoloLAB Champions a shining example of what can be achieved when mixing the worlds of VR entertainment and education together, thoroughly focusing your attention for the entire time.', 'Although built as an educational tool, HoloLAB Champions also succeeds as a completely new way to experience practical science. It engages the mind as well as dexterity courtesy of challenging measurements, mixing puzzles, and mathematical elements, which should be fun for the science nerd in kids and adults.', '...the game flowed pretty smoothly and kept me engaged enough to want to keep going. Which is great news for teachers and parents who are looking to inspire their students to learn. Or even for people who are simply looking to challenge their own knowledge in a game-like setting. HoloLAB Champions feels polished enough that it can be enjoyed by young and old alike.']",
#   0,
#   '',
#   19,
#   1,
#   0),
#  (780210, '[]', 0, '', 851, 157, 980),
#  (451600, '[]', 0, '', 225, 23, 177),
#  (1109350, '[]', 0, '', 6, 1, 0),
#  (781240, '[]', 0, '', 4, 13, 0),
#  (929570,
#   "['A Familiar Fairytale has one goal: to show non-dyslexic players the experience of reading through dyslexic eyes. Essentially just a story to read, this is an extraordinarily effective achievement that could only ever be delivered through a game.']",
#   0,
#   '',
#   2,
#   3,
#   0),
#  (841830, '[]', 0, '', 4, 0, 0),
#  (1165460, '[]', 0, '', 1, 1, 0),
#  (485980,
#   "['Качественная реалистичная RTS, практически не имеющая современных аналогов и конкурентов и способная растопить сердце самого либерального любителя стратегий. А для патриотических тактиков это просто жемчужина.', 'Фанаты жанра в лице «Сирии» получили отличную стратегию — зрелищную, сложную и реалистичную, а также позволяющую почти для каждого боя придумать с полдесятка вариантов прохождения.', 'Резюмируя (и перефразируя одного из персонажей “Белого солнца пустыни']",
#   0,
#   '',
#   3383,
#   533,
#   3727),
#  (679400, '[]', 0, '', 139, 30, 0),
#  (1514480, '[]', 0, '', 32, 12, 0),
#  (1368750, '[]', 0, '', 5, 0, 0),
#  (1121310, '[]', 0, '', 0, 0, 0),
#  (1453640, '[]', 0, '', 19, 7, 0),
#  (1389360, '[]', 0, '', 264, 46, 274),
#  (429480, '[]', 0, '', 4, 6, 0),
#  (1368400, '[]', 0, '', 26, 13, 0),
#  (1005050, '[]', 0, '', 41, 5, 0),
#  (529040,
#   "['Lots of destructive fun with solid visuals for a steal. Get it!']",
#   0,
#   '',
#   9,
#   3,
#   0),
#  (694070,
#   "['BadLands RoadTrip is a promising open world physics based shooter with RPG elements', 'Give it a shot, if only for the pleasure of turning your lousy old pea shooter into a four-barreled semi-automatic revolver that shoots exploding rubber balls.']",
#   0,
#   '',
#   8,
#   5,
#   0),
#  (1311210, '[]', 0, '', 1, 1, 0),
#  (1453660, '[]', 0, '', 4, 0, 0),
#  (587580,
#   "['It’s the Bruce Lee of virtual reality; it paraphrases his “style of no style', 'Game of no gameplay']",
#   0,
#   '',
#   228,
#   42,
#   259),
#  (294440,
#   "['If you are a fan of the genre, looking for something difficult to tackle, or wondering why you haven’t played Shadowgate in 30 years, absolutely pick this up.', 'Shadowgate will offer you a journey into darkness, and an adventure unlike anything you have experienced in a long time.', 'This new Shadowgate is a superlative remake that should stand as a great example of how to take a cult classic and update it for both new and nostalgic audiences.']",
#   68,
#   'https://www.metacritic.com/game/pc/shadowgate?ftag=MCD-06-10aaa1f',
#   544,
#   83,
#   435),
#  (1309290,
#   '["One of the bloodiest, most visceral immersive experiences available on VR headsets. It\'s pretty gruesome!"]',
#   0,
#   '',
#   29,
#   7,
#   0),
#  (364980, '[]', 0, '', 13, 8, 0),
#  (269250, '[]', 0, '', 564, 101, 428),
#  (1228870,
#   '[]',
#   70,
#   'https://www.metacritic.com/game/pc/bartlows-dread-machine?ftag=MCD-06-10aaa1f',
#   43,
#   6,
#   0),
#  (633660, '[]', 0, '', 14, 3, 0),
#  (1274280, '[]', 0, '', 8, 0, 0),
#  (1127500,
#   '["Meant to be played over and over again... Building on the excellent Mini Metro that came before it, Mini Motorways is a great evolution of Dinosaur Polo Club\'s minimalist transport sim.", \'A city builder that balances precision and beauty.\', \'Endlessly replayable, beautiful to look at and featuring engrossing gameplay, this is another roaring success.\']',
#   87,
#   'https://www.metacritic.com/game/pc/mini-motorways?ftag=MCD-06-10aaa1f',
#   13145,
#   548,
#   13204),
#  (508650, '[]', 0, '', 52, 12, 0),
#  (358700, '[]', 0, '', 10, 16, 0),
#  (656740,
#   "['Old school arcade-shoot-em-up thrills and a deep RPG-style progression system... a very impressive RPG-em-up!', 'Feels like the sequel that Tyrian never had... the power-up system runs deep, the challenge ramps up nicely to take advantage of the player learning how to exploit it, and the levels keep coming up with new enemies and challenges to keep you on your toes.']",
#   0,
#   '',
#   74,
#   9,
#   0),
#  (1047950, '[]', 0, '', 30, 6, 0),
#  (1076100, '[]', 0, '', 6, 0, 0),
#  (648150, '[]', 0, '', 1, 0, 0),
#  (630900, '[]', 0, '', 370, 28, 384),
#  (883160, '[]', 0, '', 0, 0, 0),
#  (783840, '[]', 0, '', 494, 84, 533),
#  (1487140, '[]', 0, '', 2, 1, 0),
#  (1696810, '[]', 0, '', 1961, 353, 2191),
#  (1178000, '[]', 0, '', 28, 0, 0),
#  (1138580, '[]', 0, '', 83, 17, 0),
#  (416090, '[]', 0, '', 4, 2, 0),
#  (595360, '[]', 0, '', 20, 12, 0),
#  (1581240, '[]', 0, '', 8, 0, 0),
#  (1751990, '[]', 0, '', 2, 0, 0),
#  (1445500, '[]', 0, '', 3, 0, 0),
#  (404530, '[]', 0, '', 426, 63, 444),
#  (1137650, '[]', 0, '', 3, 0, 0),
#  (461550, '[]', 0, '', 0, 0, 0),
#  (1408380, '[]', 0, '', 2, 1, 0),
#  (1049690, '[]', 0, '', 9, 0, 0),
#  (612840, '[]', 0, '', 10, 1, 0),
#  (1463120, '[]', 0, '', 0, 0, 123),
#  (243890, '[]', 0, '', 11, 13, 0),
#  (428410,
#   "['Sharp gameplay that’s right at the sweet-spot between too tough and too easy', 'PRiO is punishing, but in the best possible way']",
#   0,
#   '',
#   27,
#   3,
#   0),
#  (988110, '[]', 0, '', 6, 2, 0),
#  (1921760, '[]', 0, '', 77, 3, 0),
#  (791370,
#   "['Xploquest 2 is the sequel to the wonderful retro RPG Xploquest.']",
#   0,
#   '',
#   10,
#   1,
#   0),
#  (622460, '[]', 0, '', 239, 68, 261),
#  (883130, '[]', 0, '', 311, 42, 332),
#  (913570, '[]', 0, '', 2, 1, 0),
#  (1930230, '[]', 0, '', 1, 0, 0),
#  (351490, '[]', 0, '', 927, 234, 993),
#  (378360, '[]', 0, '', 708, 242, 699),
#  (1273450, '[]', 0, '', 31, 7, 0),
#  (1059660, '[]', 0, '', 4, 1, 0),
#  (820830, '[]', 0, '', 11, 1, 0),
#  (668290, '[]', 0, '', 6, 4, 0),
#  (646100, '[]', 0, '', 96, 216, 0),
#  (1382310, '[]', 0, '', 1, 0, 0),
#  (1944970, '[]', 0, '', 15, 21, 0),
#  (1534240,
#   '["\'If you love speed and attentiveness games, then Drop Blox is perfect for you. You need to quickly sort boxes of different colors and issue them according to the color of the recipient.\'"]',
#   0,
#   '',
#   0,
#   3,
#   0),
#  (1339310, '[]', 0, '', 9, 0, 0),
#  (575800, '[]', 0, '', 6, 3, 0),
#  (1968280, '[]', 0, '', 0, 0, 0),
#  (634120,
#   "['Davit Andreasyan has done a wonderful job restoring faith in the horror genre that has seen too many copycats in recent years.']",
#   0,
#   '',
#   155,
#   103,
#   204),
#  (1843230, '[]', 0, '', 2, 0, 0),
#  (1434550, '[]', 0, '', 1, 0, 0),
#  (316260, '[]', 0, '', 197, 40, 174),
#  (604040, '[]', 0, '', 10, 3, 0),
#  (1050170, '[]', 0, '', 1, 1, 0),
#  (1546120, '[]', 0, '', 2, 0, 0),
#  (762850, '[]', 0, '', 5, 4, 0),
#  (1221560, '[]', 0, '', 0, 0, 0),
#  (1939600, '[]', 0, '', 4, 1, 0),
#  (437530,
#   '["A Blind Legend is one of the first in what I hope is a long line of VI-friendly video games from developer DOWiNO, renowned for developing serious games to educate and inform players of social values. The most interesting aspect of this title is its total reliance on audio, and zero use of visual art. The game features full 3D environments, outlined in details through directional audio and cues, and even features a surprisingly challenging combat system. It\'s a game full of twists, throwing in numerous styles of gameplay from stealth, horse-riding, combat, and even careful navigation of treacherous terrain. Needless to say it\'s full of surprises that you might not expect to be possible to develop in a game without visual direction."]',
#   0,
#   '',
#   180,
#   47,
#   125),
#  (1583650, '[]', 0, '', 0, 0, 0),
#  (526130,
#   '["This is a very polished collection of bow and sword minigames. The arc of the bow\'s arrows feel great and makes good use of the midfield space that works best in VR.", \'With its awesome graphics and its soundtrack that brings a lot to the ambience, Sky Sanctuary will please everyone, whether young or old.\', \'This little gem popped up out of nowhere, and covers some familiar ground, but more importantly, provides an arena for growth and shows great potential.\']',
#   0,
#   '',
#   40,
#   5,
#   0),
#  (1651880, '[]', 0, '', 7, 2, 0),
#  (311120, '[]', 0, '', 237, 262, 456),
#  (410670, '[]', 0, '', 755, 103, 771),
#  (1131410, '[]', 0, '', 42, 0, 0),
#  (1417890, '[]', 0, '', 50, 2, 0),
#  (2006770, '[]', 0, '', 5, 0, 0),
#  (1583840, '[]', 0, '', 2, 0, 0),
#  (516940, '[]', 0, '', 31, 8, 0),
#  (1304320, '[]', 0, '', 29, 6, 0),
#  (1471960,
#   "['There’s more to this cutesy puzzler than meets the eye', 'A perfect combination of simple but unique mechanics and hard but satisfying puzzles', 'Room to Grow is an incredibly clever puzzler']",
#   76,
#   'https://www.metacritic.com/game/pc/room-to-grow?ftag=MCD-06-10aaa1f',
#   117,
#   4,
#   109),
#  (1350540, '[]', 0, '', 10, 2, 0),
#  (1512910, '[]', 0, '', 1, 1, 0),
#  (511110, '[]', 0, '', 0, 0, 0),
#  (1578750, '[]', 0, '', 1, 0, 0),
#  (1674300, '[]', 0, '', 0, 0, 0),
#  (465750, '[]', 0, '', 22, 8, 0),
#  (1053660, '[]', 0, '', 26, 18, 0),
#  (605490, '[]', 0, '', 8, 2, 0),
#  (1253320, '[]', 0, '', 1, 0, 0),
#  (448960, '[]', 0, '', 28, 7, 0),
#  (1457150, '[]', 0, '', 428, 175, 0),
#  (1129660, '[]', 0, '', 35, 10, 0),
#  (1550750, '[]', 0, '', 0, 0, 0),
#  (1787520, '[]', 0, '', 2, 0, 0),
#  (292180,
# ...
#   0,
#   '',
#   1359,
#   119,
#   1364),
#  (1998840,
#   '["If you like arcade games, buy Arcadia, you won\'t be disappointed. ... The true test of a game like this is the \'just one more go\' syndrome. And with Arcadia you will find yourself suffering from just that. It is so tempting to try again."]',
#   0,
#   '',
#   0,
#   0,
#   0),
#  (704760, '[]', 0, '', 10, 3, 0),
#  (528460, '[]', 0, '', 336, 143, 303),
#  (12670, '[]', 0, '', 13, 8, 0),
#  (765860, '[]', 0, '', 19, 12, 0),
#  (1514580,
#   "['The best chicken-stealing game ever!', 'A magnificent work of art.', 'The beginning of a great legend!']",
#   0,
#   '',
#   1,
#   1,
#   0),
#  (1431040, '[]', 0, '', 132, 31, 148),
#  (1579590, '[]', 0, '', 8, 1, 0),
#  (1553850, '[]', 0, '', 2, 0, 0),
#  (1875560,
#   "['A Breathless Beauty Of A VR Game', 'Mare is a class act from start to finish. It’s a macabre and mysterious adventure that offers a haunting experience', 'It’s a strikingly beautiful yet solemn adventure that pushes you ever forward toward the unknown.']",
#   0,
#   '',
#   15,
#   2,
#   0),
#  (1143810, '[]', 0, '', 979, 126, 836),
#  (1321220, '[]', 0, '', 3, 9, 0),
#  (1500750, '[]', 0, '', 23, 15, 0),
#  (1819900, '[]', 0, '', 2, 1, 0),
#  (1433070, '[]', 0, '', 3, 3, 0),
#  (45750,
#   '[]',
#   63,
#   'https://www.metacritic.com/game/pc/lost-planet-2?ftag=MCD-06-10aaa1f',
#   1640,
#   794,
#   2021),
#  (850710, '[]', 0, '', 11, 2, 0),
#  (821860, '[]', 0, '', 3, 11, 0),
#  (577850, '[]', 0, '', 22, 5, 0),
#  (1715970, '[]', 0, '', 14, 21, 0),
#  (1008000, '[]', 0, '', 59, 27, 0),
#  (1006920, '[]', 0, '', 11, 2, 0),
#  (1011310, '[]', 0, '', 1, 1, 0),
#  (536950,
#   "['The game offers a variety of PvP-oriented content that is catered to solo players and groups, including guild-wide battles that determine turf ownership.', 'Legend of Ares is a solid game to immerse yourself into and spend a good bit of time playing, if you’re a person that enjoys large group PvP.']",
#   0,
#   '',
#   30,
#   24,
#   0),
#  (1669350, '[]', 0, '', 0, 0, 0),
#  (1436810, '[]', 0, '', 78, 7, 0),
#  (2050890, '[]', 0, '', 0, 0, 0),
#  (1280780, '[]', 0, '', 1421, 427, 1785),
#  (994200, '[]', 0, '', 352, 319, 0),
#  (1148680, '[]', 0, '', 2, 0, 0),
#  (1347390, '[]', 0, '', 1, 0, 0),
#  (460630, '[]', 0, '', 160, 12, 166),
#  (562050, '[]', 0, '', 68, 30, 0),
#  (613880, '[]', 0, '', 909, 538, 1124),
#  (371710, '[]', 0, '', 19, 43, 0),
#  (1959400, '[]', 0, '', 0, 1, 0),
#  (1420080,
#   '["Asha is a decent platformer, handled with love and attention to the details, and it\'s a part of one of console gaming\'s most interesting lineages.", \'The straightforward, yet tried and true story, its lovable and cute characters, and the old-fashioned gameplay all add to its nostalgic charm.\', \'Check as of 6 August 2021.\']',
#   0,
#   '',
#   82,
#   18,
#   0),
#  (38160, '[]', 0, '', 7, 0, 0),
#  (1283430, '[]', 0, '', 39, 0, 0),
#  (703000, '[]', 0, '', 4, 0, 0),
#  (1071220, '[]', 0, '', 89, 8, 0),
#  (536430, '[]', 0, '', 49, 8, 0),
#  (742990, '[]', 0, '', 6, 6, 0),
#  (1000040, '[]', 0, '', 0, 1, 0),
#  (380990, '[]', 0, '', 27, 27, 0),
#  (565080, '[]', 0, '', 0, 0, 0),
#  (377010, '[]', 0, '', 0, 1, 0),
#  (1630760, '[]', 0, '', 6, 0, 0),
#  (612440, '[]', 0, '', 9, 2, 0),
#  (327980, '[]', 0, '', 36, 7, 0),
#  (266330, '[]', 0, '', 140, 89, 0),
#  (1436990, '[]', 0, '', 1697, 183, 1605),
#  (654710,
#   "['Сурвайвл кликер, где нашей задачей является добыча ресурсов для постепенной прокачки убежища , и выживания. Забавная инди-выживалка на пару часов.', 'Кликер-выживалка. Прячемся в бункере и вылезаем на поверхность для сбора ресурсов, чтобы протянуть как можно дольше в своем подземном укрытии. Инди-игра для любителей пощелкать мышью по зомби!']",
#   0,
#   '',
#   36,
#   21,
#   0),
#  (873250, '[]', 0, '', 10, 4, 0),
#  (868570, '[]', 0, '', 24, 12, 0),
#  (1571600, '[]', 0, '', 14, 0, 0),
#  (1605190, '[]', 0, '', 7, 0, 0),
#  (635900, '[]', 0, '', 44, 20, 0),
#  (1789660, '[]', 0, '', 16, 6, 0),
#  (1236700, '[]', 0, '', 0, 0, 285),
#  (590600, '[]', 0, '', 1, 2, 0),
#  (870010, '[]', 0, '', 0, 3, 0),
#  (1192610, '[]', 0, '', 110, 41, 385),
#  (457690, '[]', 0, '', 9, 36, 0),
#  (371120,
#   '[\'Depression and anxiety aren’t often well-represented in gaming. Enter Yggdrasil Studio’s VN to offer a glimpse behind the veil.\', "The extremely dark atmosphere and realism make for an interesting departure that\'s pretty far removed from what you\'d normally expect out of a visual novel, and it\'s worth giving a try for that alone.", \'This game, despite its frustrating design, will hit unemployed or underemployed millennial gamers right where it hurts. It’s a satirical take on Korean soap operas, but the plot — powerlessly navigating a sluggish economy with debt and a useless degree — feels distinctly American as well.\']',
#   0,
#   '',
#   61,
#   38,
#   0),
#  (1018950, '[]', 0, '', 1, 2, 0),
#  (1786280, '[]', 0, '', 1, 0, 0),
#  (910460, '[]', 0, '', 144, 43, 0),
#  (760520, '[]', 0, '', 3, 1, 0),
#  (1251270, '[]', 0, '', 0, 0, 0),
#  (226780, '[]', 0, '', 67, 50, 0),
#  (251990,
#   '["Each time the protagonist dies, you find yourself coming back with a vengeance, determined to try a new strategy, a different approach to her upbringing. It\'s borderline addictive. It\'s also likely to make a monster out of you. By the end of my first successful playthrough, I had summarily butchered everyone who even thought about looking at us funny, forced the princess into a continuous state of docility and lied my way through every social encounter possible. Was it evil? Yes. Was it glorious? Definitely.", \'Somehow it never occurred to my princess, whom I’d lovingly crafted into a tense, paranoid warlord, that she shouldn’t empty a box of mysterious mailcandy into her mouth. You would think studying poison and espionage would have saved me from this espionage poison, but instead, a list of other skills, skills I never studied, princess skills, were key to avoiding this fate. I guess that’s the lesson: you can’t build a successful Arya without adding a little Sansa.\', \'If you’re the sort who can sink your teeth into a full afternoon of tabletop strategy, you’ll be happy here. Long Live The Queen is a slow-paced, cozy evening kind of game, good for folks who like numbers and critical thinking. And death. Pink frosted, chubby cheeked death.\']',
#   67,
#   'https://www.metacritic.com/game/pc/long-live-the-queen?ftag=MCD-06-10aaa1f',
#   6383,
#   331,
#   5432),
#  (1137770, '[]', 0, '', 9, 4, 0),
#  (543240, '[]', 0, '', 379, 90, 443),
#  (1822490, '[]', 0, '', 4, 3, 0),
#  (764180, '[]', 0, '', 12, 2, 0),
#  (1534520, '[]', 0, '', 52, 9, 0),
#  (854190, '[]', 0, '', 22, 21, 0),
#  (1375850, '[]', 0, '', 0, 0, 0),
#  (984610, '[]', 0, '', 72, 11, 0),
#  (1342790, '[]', 0, '', 321, 154, 296),
#  (1285940, '[]', 0, '', 17, 1, 0),
#  (1778110, '[]', 0, '', 4, 0, 0),
#  (1123730, '[]', 0, '', 0, 0, 0),
#  (837780, '[]', 0, '', 7, 6, 0),
#  (11370,
#   '[]',
#   68,
#   'https://www.metacritic.com/game/pc/nikopol-secrets-of-the-immortals?ftag=MCD-06-10aaa1f',
#   190,
#   156,
#   235),
#  (1524690,
#   "['A very good game! It is even better than the first, there is a clear visual upgrade and the levels are sometimes more complex. I just loved the last one. Oh, and the achievements, there seems to be a secret!', 'Its fun and gets you thinking. For the price, 10/10 so far', 'I liked this game. What caught my attention the most was the melancholy atmosphere that matched the background story']",
#   0,
#   '',
#   37,
#   1,
#   0),
#  (1271280, '[]', 0, '', 674, 37, 667),
#  (898260, '[]', 0, '', 20, 2, 0),
#  (426930,
#   '["It will make a great addition to anyone\'s collection, and one of the definitive games for a party to have going on for casual play.", \'En creatividad se lleva 5 estrellitas, porque nunca había visto un juego parecido... Este juego pareciera muy sencillo, pero el detalle es lo increíble.\']',
#   0,
#   '',
#   84,
#   12,
#   0),
#  (499540,
#   "['This small VR game is free, but has more to show than many other paid games on Steam. Definitely worth a look!', 'Wake Up is a Surreal, Immersive Vive Puzzler with Killer Sound Design.', 'Wake up is a fun distraction from, you know, all the shooting, so give it a try.']",
#   0,
#   '',
#   72,
#   16,
#   0),
#  (598620, '[]', 0, '', 4, 4, 0),
#  (1102140, '[]', 0, '', 1, 0, 0),
#  (1143900, '[]', 0, '', 10, 6, 0),
#  (606230, '[]', 0, '', 1466, 414, 1648),
#  (1601260, '[]', 0, '', 0, 1, 0),
#  (894090, '[]', 0, '', 3, 1, 0),
#  (1207390,
#   '["In Ghosts’n DJs you can see Kucho’s devotion for the classic Ghosts\'n Goblins.", \'You’ll have to run, jump, and climb your way across each level.\', \'It is fun to play, feels a lot like it’s GnG inspiration and does make you smile – especially when you see some of the DJs combat moves.\']',
#   0,
#   '',
#   111,
#   15,
#   0),
#  (1797590, '[]', 0, '', 4, 0, 0),
#  (508790,
#   "['A masterclass in game-feel', 'Simple but at the same time hypnotic, Flat Heroes is minimalist in everything except ideas, control and design.', 'A simply perfect control that is at the level of the best representatives of the genre.']",
#   0,
#   '',
#   410,
#   49,
#   150),
#  (1084920, '[]', 0, '', 8, 0, 0),
#  (1146350, '[]', 0, '', 2, 2, 0),
#  (654260, "['该攻略由破晓和光阴联合提供']", 0, '', 536, 93, 531),
#  (828740,
#   "['Palm Pioneer has crafted an adventure with more than its fair share of surprises.', 'The game is a fun throwback to old school adventure games.', 'Tales of the Neon Sea turned its wealth of ideas into a fun game.']",
#   0,
#   '',
#   2250,
#   345,
#   1882),
#  (454680, '[]', 0, '', 49, 62, 0),
#  (449040,
#   "['It comes across as though developers with a bizarre sense of humor honestly wanted to convey Bible stories through video games. And that makes it oddly endearing.', 'Things escalate as Jesus begins to open up a can on evil and dish out Stone Cold levels of justice against demons, because 3:16 says so.', 'If you like to play video games, why not learn about the faith at the same time?']",
#   0,
#   '',
#   1276,
#   211,
#   0),
#  (219830,
#   "['No other game allows you to build a castle, actively fight off invaders, and then jump onto a catapult to be flung over the walls of your rival’s castle to claim its inner sanctum as your own.', 'The developers have done an excellent job balancing building and destruction. Every game it seems people are able to leverage their creativity and construct some really amazing traps. The sword fighting while initially simple has multiple levels of mastery. If you like terraria/ctf/basebuilding/team fortress 2 I recommend this game.']",
#   81,
#   'https://www.metacritic.com/game/pc/king-arthurs-gold?ftag=MCD-06-10aaa1f',
#   4137,
#   782,
#   2679),
#  (1192500, '[]', 0, '', 9, 6, 0),
#  (1554600, '[]', 0, '', 90, 17, 0),
#  (1155230, '[]', 0, '', 2, 3, 0),
#  (720030,
#   '[\'It only took a few seconds for me to fall completely in love with it.\', "It won\'t be for everybody, but Indecision is a micro masterpiece."]',
#   0,
#   '',
#   469,
#   82,
#   369),
#  (1086140, '[]', 0, '', 1, 0, 0),
#  (1535420,
#   '["If your viewers love to chat, they\'ll love to plink!"]',
#   0,
#   '',
#   2,
#   0,
#   0),
#  (415920, '[]', 0, '', 206, 6, 195),
#  (1507600, '[]', 0, '', 9, 5, 0),
#  (240340, '[]', 0, '', 108, 19, 115),
#  (1544810, '[]', 0, '', 0, 1, 0),
#  (793030, '[]', 0, '', 3, 0, 0),
#  (1514730, '[]', 0, '', 2, 0, 0),
#  (1487100,
#   "['Initial impressions will likely suggest that Lost to Time is a broken mess, but if you approach it with an open mind and a lot of patience it can be a true work of art.']",
#   0,
#   '',
#   6,
#   1,
#   0),
#  (726000, '[]', 0, '', 90, 19, 0),
#  (2010540, '[]', 0, '', 2, 0, 0),
#  (651670,
#   '[]',
#   77,
#   'https://www.metacritic.com/game/pc/star-renegades?ftag=MCD-06-10aaa1f',
#   1783,
#   300,
#   1831),
#  (987710, '[]', 0, '', 15, 0, 0),
#  (951050, '[]', 0, '', 19, 3, 0),
#  (1550630, '[]', 0, '', 6, 0, 0),
#  (1711530, '[]', 0, '', 3, 0, 0),
#  (1011420, '[]', 0, '', 82, 58, 0),
#  (1411460, '[]', 0, '', 6, 1, 0),
#  (680250, '[]', 0, '', 1, 0, 0),
#  (1421410, '[]', 0, '', 18, 4, 0),
#  (1275660,
#   "['You need this in your life', 'Sanity of Morris was an enjoyable psychological horror game that focuses on aliens and insanity, rather than ghosts and death – which is a nice change.', 'Sanity of Morris is worthy of your attention thanks to a well written and compelling narrative, bolstered by convincing character performances and engaging gameplay that will draw you further into the mysterious conspiracy surrounding Greenlake, for better or worse.']",
#   0,
#   '',
#   38,
#   13,
#   0),
#  (781520, '[]', 0, '', 16, 22, 0),
#  (1479540, '[]', 0, '', 14, 1, 0),
#  (1854510, '[]', 0, '', 2, 0, 0),
#  (1462560, '[]', 0, '', 0, 0, 0),
#  (1314290, '[]', 0, '', 0, 0, 0),
#  (1753100, '[]', 0, '', 66, 44, 105),
#  (1554970, '[]', 0, '', 96, 25, 0),
#  (612590, '[]', 0, '', 43, 7, 0),
#  (700170, '[]', 0, '', 96, 20, 0),
#  (798590, '[]', 0, '', 70, 66, 126),
#  (718740, '[]', 0, '', 2, 1, 0),
#  (481950, '[]', 0, '', 6, 0, 0),
#  (113420,
#   '[]',
#   71,
#   'https://www.metacritic.com/game/pc/fallen-earth-welcome-to-the-apocalypse?ftag=MCD-06-10aaa1f',
#   4293,
#   3045,
#   0),
#  (714880, '[]', 0, '', 3, 2, 0),
#  (328550, '[]', 0, '', 24, 6, 0),
#  (429430, '[]', 0, '', 8, 27, 0),
#  (1511130, '[]', 0, '', 0, 0, 0),
#  (454540, '[]', 0, '', 438, 365, 0),
#  (829260, '[]', 0, '', 28, 4, 0),
#  (1384990, '[]', 0, '', 2, 0, 0),
#  (1108020, '[]', 0, '', 1, 0, 0),
#  (781760, '[]', 0, '', 39, 28, 0),
#  (988070, '[]', 0, '', 0, 4, 0),
#  (1222370, '[]', 0, '', 3384, 1470, 3964),
#  (533960, '[]', 0, '', 6, 0, 0),
#  (1152200, '[]', 0, '', 0, 0, 0),
#  (760640, '[]', 0, '', 185, 17, 183),
#  (22380,
#   '[]',
#   84,
#   'https://www.metacritic.com/game/pc/fallout-new-vegas?ftag=MCD-06-10aaa1f',
#   154845,
#   5667,
#   127087),
#  (1678450, '[]', 0, '', 10, 3, 0),
#  (1475940, '[]', 0, '', 0, 0, 0),
#  (529780, '[]', 0, '', 1524, 126, 0),
#  (753090, '[]', 0, '', 14, 11, 0),
#  (499230,
#   '[\'They can infect others with a horrible chest spike and they can mutate into their true form at any time, in a HUGE explosion of blood. Wonderful.\', \'SurvHive is certainly ambitious and takes a lot of its cues from both John Carpenter’s The Thing as well as Alien and Aliens. The common themes of a shape-shifting alien that has the ability infect other beings and turn them into themselves, causing paranoia and group tension as they do not know who to trust.\', "Reason to love: It\'s The Thing in video game form. You\'re a group of humans trying to survive and escape a space station, but one of you is actually an alien in disguise, whose goal is to infect the other players. Love that premise."]',
#   0,
#   '',
#   51,
#   31,
#   0),
#  (1136240, '[]', 0, '', 30, 9, 0),
#  (450390, '[]', 0, '', 5105, 258, 220),
#  (1907420, '[]', 0, '', 19, 1, 0),
#  (1268840, '[]', 0, '', 1, 0, 0),
#  (1050910, '[]', 0, '', 0, 3, 0),
#  (403100,
#   '["Rescue Team is one of Alawar\'s best selling Resource-Management franchises"]',
#   0,
#   '',
#   43,
#   10,
#   0),
#  (1245930, '[]', 0, '', 3, 3, 0),
#  (1021260, '[]', 0, '', 21, 13, 0),
#  (837720, '[]', 0, '', 4, 0, 0),
#  (1548540, '[]', 0, '', 26, 7, 0),
#  (463150,
#   "['Expect to get addicted to the thing. You’ve been warned.', 'Worth getting on Steam to me']",
#   0,
#   '',
#   1922,
#   290,
#   833),
#  (514700, '[]', 0, '', 65, 14, 0),
#  (1769630, '[]', 0, '', 7, 3, 0),
#  (1898570, '[]', 0, '', 8, 0, 0),
#  (1821150, '[]', 0, '', 2, 1, 0),
#  (1572220, '[]', 0, '', 6, 0, 0),
#  (508710, '[]', 0, '', 52, 20, 0),
#  (1347130, '[]', 0, '', 20, 3, 0),
#  (1689930,
#   "['Amazing brand new twitch interactive game where viewers can bowl onstream!', 'Lots of fun to bowl for a few, while drinking my morning coffee. Devs really listen to feedback.']",
#   0,
#   '',
#   9,
#   0,
#   0),
#  (910540, '[]', 0, '', 9, 7, 0),
#  (514920, '[]', 0, '', 884, 140, 942),
#  (1286030, '[]', 0, '', 0, 0, 0),
#  (574180, '[]', 0, '', 492, 159, 577),
#  (1680530, '[]', 0, '', 6, 1, 0),
#  (550600, '[]', 0, '', 1, 3, 0),
#  (1492590, '[]', 0, '', 5, 2, 0),
#  (1173870,
#   "['It is amusing, charming, and includes local multiplayer.']",
#   0,
#   '',
#   42,
#   3,
#   0),
#  ...]

# %%
game_review_insert_query = """ 
    INSERT IGNORE INTO game_review (app_id, reviews, metacritic_score, metacritic_url, positive_vote, negative_vote, recommendations) 
    VALUES (%s, %s, %s, %s, %s, %s, %s) 
"""

batch_size = 25 
count = 0 

for x in range(0, len(game_review_batch_data), batch_size): 
    batch_data = game_review_batch_data[x: x+ batch_size] 

    try: 
        mydb = check_sql_connection(mydb) 
        cursor = mydb.cursor()   
        
        cursor.executemany(game_review_insert_query, batch_data)
        mydb.commit()  
    
    except Exception as e: 
        print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "game_review", game_review_batch_data)
# Out:
# All data was inserted successfully: 89238 out of 89238

# %% [markdown]
# ### Screenshots

# %%
steam_dataset['Screenshots'] = steam_dataset['Screenshots'].apply(lambda x: safe_eval(x))

# %%
screenshots_batch_data = [
    (row.AppID, screenshot)
    for row in steam_dataset.itertuples(index=False)
    for screenshot in row.Screenshots
] 

screenshots_batch_data  

# Too slow
# screenshots_batch_data = [] 

# for _, row in steam_dataset.iterrows():    
#     app_id = row['AppID'] 
#     for screenshot in row['Screenshots']:
#         screenshots_batch_data.append( 
#             (
#                 app_id,
#                 screenshot
#             )
#         ) 

# screenshots_batch_data
# Out:
# [(20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005994.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005993.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005992.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000006011.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005685.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005686.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005995.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005688.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005689.1920x1080.jpg?t=1640121033'),
#  (20200,
#   'https://cdn.akamai.steamstatic.com/steam/apps/20200/0000005690.1920x1080.jpg?t=1640121033'),
#  (655370,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/ss_16785eac54b29db688870e832f6997c89cd7804b.1920x1080.jpg?t=1617500526'),
#  (655370,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/ss_599ad201ec3bb869449aaab4d0b103e220645762.1920x1080.jpg?t=1617500526'),
#  (655370,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/ss_a26cfed1bc3e9ca4225fdc9d5c10681cfeb4f106.1920x1080.jpg?t=1617500526'),
#  (655370,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/ss_9b815c0ec4996783088d82d22105caa1c044acad.1920x1080.jpg?t=1617500526'),
#  (655370,
#   'https://cdn.akamai.steamstatic.com/steam/apps/655370/ss_b5aada1bd265ff4b34116794fb937ad62e2882bb.1920x1080.jpg?t=1617500526'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_09d67dec0607be7c4ead80289763033a47c86d89.1920x1080.jpg?t=1637149386'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_119713aa971021a5fe24ee241c4be9329d1a37ab.1920x1080.jpg?t=1637149386'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_04221851fa82047cee95243edf20e413a35ff410.1920x1080.jpg?t=1637149386'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_fb210f530ebe006066bfb5dff35d3c68f858f60e.1920x1080.jpg?t=1637149386'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_f43db212224f5b33a0ef530a75c3f852d35e9342.1920x1080.jpg?t=1637149386'),
#  (1732930,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1732930/ss_eeb31f8499720fc1b20342f74f0040ca2f190881.1920x1080.jpg?t=1637149386'),
#  (1355720,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1355720/ss_20bbae2d9d5aaa2f043f372a551faabc0c47b0b4.1920x1080.jpg?t=1639875115'),
#  (1355720,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1355720/ss
1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_4063af4df1fbdb71ae3aaac594bbf8b823f560e3.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_74f888d4ed620539d81547774400e1f16d2948e6.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_e144f2cea01cd5ccc55281f3bc88b5105ab9332e.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_a37e7bf956d694354463dbb5938801e2256e25b6.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_0dba6aa74c2b537bc3d923c1820a6d86c95ea105.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_aa0028f2fce95f5bd16de4e935cc26fb32897c39.1920x1080.jpg?t=1657283667'),
#  (1886290,
#   'https://cdn.akamai.steamstatic.com/steam/apps/1886290/ss_4b38376a243d4a68616380d7be0db3e859f3a996.1920x1080.jpg?t=1657283667'),
#  ...]

# %%
screenshot_insert_query = """ 
    INSERT IGNORE INTO game_screenshots (app_id, screenshot_url) 
    VALUES (%s, %s) 
"""

batch_size = 25 
count = 0 

for x in range(0, len(screenshots_batch_data), batch_size): 
    batch_data = screenshots_batch_data[x: x+ batch_size] 

    try: 
        mydb = check_sql_connection(mydb) 
        cursor = mydb.cursor()   
        
        cursor.executemany(screenshot_insert_query, batch_data)
        mydb.commit()  
    
    except Exception as e: 
        print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "game_screenshots", screenshots_batch_data)
# Out:
# Not all data was inserted successfully: 791984 out of 794387

# %% [markdown]
# ### Movies

# %%
steam_dataset['Movies'] = steam_dataset['Movies'].apply(lambda x: safe_eval(x))

# %%
movies_batch_data = [
    (row.AppID, movie)
    for row in steam_dataset.itertuples(index=False)
    for movie in row.Movies
] 

movies_batch_data
# Out:
# [(20200,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256863704/movie_max.mp4?t=1638854607'),
#  (655370,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256691108/movie_max.mp4?t=1506089586'),
#  (1732930,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256847488/movie_max.mp4?t=1635980739'),
#  (1732930,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256847487/movie_max.mp4?t=1635980747'),
#  (1355720,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256819153/movie_max.mp4?t=1611314333'),
#  (1139950,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256764430/movie_max.mp4?t=1580660973'),
#  (1469160,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256818274/movie_max.mp4?t=1611036715'),
#  (1659180,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256867570/movie_max.mp4?t=1641709460'),
#  (1659180,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256843858/movie_max.mp4?t=1628006054'),
#  (1968760,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256881983/movie_max.mp4?t=1650185685'),
#  (1178150,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256776944/movie_max.mp4?t=1584591532'),
#  (320150,
#   'http://cdn.akamai.steamstatic.com/steam/apps/2035390/movie_max.mp4?t=1447364829'),
#  (1026420,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256763461/movie_max.mp4?t=1573634285'),
#  (1026420,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256743901/movie_max.mp4?t=1551209280'),
#  (485000,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256665402/movie_max.mp4?t=1466728105'),
#  (1620060,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256845891/movie_max.mp4?t=1628707212'),
#  (825930,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256712096/movie_max.mp4?t=1521724364'),
#  (1454010,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256807620/movie_max.mp4?t=1604147754'),
#  (1330820,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256808367/movie_max.mp4?t=1604638423'),
#  (346560,
#   'http://cdn.akamai.steamstatic.com/steam/apps/2037139/movie_max.mp4?t=1447368939'),
#  (1097880,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256752455/movie_max.mp4?t=1559937666'),
#  (1362670,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256791516/movie_max.mp4?t=1594399088'),
#  (290870,
#   'http://cdn.akamai.steamstatic.com/steam/apps/2032271/movie_max.mp4?t=1447361792'),
#  (290870,
#   'http://cdn.akamai.steamstatic.com/steam/apps/2032272/movie_max.mp4?t=1469529575'),
#  (290870,
#   'http://cdn.akamai.steamstatic.com/steam/apps/2032273/movie_max.mp4?t=1469537657'),
#  (575760,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256677922/movie_max.mp4?t=1485453880'),
#  (434030,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256664157/movie_max.mp4?t=1463158928'),
#  (810740,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256709262/movie_max.mp4?t=1520522175'),
#  (2073470,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256896408/movie_max.mp4?t=1657829930'),
#  (589250,
#   'http://cdn.akamai.steamstatic.com/steam/apps/
,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256886877/movie_max.mp4?t=1652720164'),
#  (1172470,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256886876/movie_max.mp4?t=1652720170'),
#  (1172470,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256884397/movie_max.mp4?t=1652202236'),
#  (1471460,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256817942/movie_max.mp4?t=1612297453'),
#  (1471460,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256820710/movie_max.mp4?t=1612297468'),
#  (1284700,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256796460/movie_max.mp4?t=1597379607'),
#  (1284700,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256793128/movie_max.mp4?t=1594991111'),
#  (841600,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256860266/movie_max.mp4?t=1636779115'),
#  (841600,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256713473/movie_max.mp4?t=1635142331'),
#  (1671180,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256878581/movie_max.mp4?t=1647677965'),
#  (1671180,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256878582/movie_max.mp4?t=1647679402'),
#  (2061060,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256892986/movie_max.mp4?t=1656982803'),
#  (1299120,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256782536/movie_max.mp4?t=1588950290'),
#  (1303170,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256822546/movie_max.mp4?t=1613382650'),
#  (1303170,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256822544/movie_max.mp4?t=1613382681'),
#  (1303170,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256782961/movie_max.mp4?t=1613382706'),
#  (773530,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256784666/movie_max.mp4?t=1588875461'),
#  (1430100,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256803465/movie_max.mp4?t=1602265932'),
#  (1514160,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256818236/movie_max.mp4?t=1610742063'),
#  (404730,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256657232/movie_max.mp4?t=1447378460'),
#  (404730,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256657233/movie_max.mp4?t=1447378460'),
#  (404730,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256657236/movie_max.mp4?t=1447378461'),
#  (404730,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256657239/movie_max.mp4?t=1447378462'),
#  (945490,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256755964/movie_max.mp4?t=1572471787'),
#  (945490,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256749261/movie_max.mp4?t=1556998434'),
#  (945490,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256749175/movie_max.mp4?t=1556485296'),
#  (945490,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256749245/movie_max.mp4?t=1556485305'),
#  (945490,
#   'http://cdn.akamai.steamstatic.com/steam/apps/256729298/movie_max.mp4?t=1556469842'),
#  ...]

# %%
movie_insert_query = """ 
    INSERT IGNORE INTO game_movies (app_id, movie_url) 
    VALUES (%s, %s) 
"""

batch_size = 25 
count = 0 

for x in range(0, len(movies_batch_data), batch_size): 
    batch_data = movies_batch_data[x: x+ batch_size] 

    try: 
        mydb = check_sql_connection(mydb) 
        cursor = mydb.cursor()   
        
        cursor.executemany(movie_insert_query, batch_data)
        mydb.commit()  
    
    except Exception as e: 
        print(f"Error occured: {e}")

# %%
insert_all_data_verification(mydb, "game_movies", movies_batch_data)
# Out:
# All data was inserted successfully: 124048 out of 124048

# %% [markdown]
# ## Relational Table

# %% [markdown]
# ### Game Developer Publisher

# %%
get_company_query = "SELECT name, company_id from companies" 

try:  
    mydb = check_sql_connection(mydb) 
    cursor = mydb.cursor() 

    cursor.execute(get_company_query)  
    get_company_result = dict(cursor.fetchall())  

    print(get_company_result) 
    
except Exception as e:  
    print(f"Error occured: {e}")
# Out:
# {'': 270013, '_k.y.': 42918, '(Archive) duplicate Headup Games / Crenetic': 33231, '(Archive) eGames.com': 28492, '[erka:es]': 37102, '[geim].pro': 44343, '[r]labs': 43460, '@unepic_fran': 39534, '&y': 29919, '∇': 44496, '∞ Infinity Games': 31230, '▲ Pyramid Games': 30037, '△○□× (Miwashiba)': 26904, '☆': 43368, '🚀 Raiser Games': 28481, '0 Deer Soft': 25801, '0-Game Stud
2nd Studio': 39393, '2ndBoss': 30042, '2oclocksoft': 31179, '2OO2': 29429, '2P Games': 29257, '2PGames': 34470, '2PIXELS Games': 42370, '2Play': 32199, '2pt Interactive': 28774, '2SD': 38784, '2tainment': 30087, '2tainment GmbH': 27626, '2weak': 31534, '2x2 Games': 35274, '2xDal': 40850, '2XL Games': 22950, '3 Halves Games': 36292, '3 Minute Games, LLC': 39025, '3 Sprockets': 37838, '3-Fold Games': 42425, '3-Tricks': 30565, '3+ Productions': 36344, '30/30': 34194, '3000AD': 25242, '300AD': 25442, '302 Interactive': 42105, '302 Studio': 28253, '314 Arts': 31761, '33 Games': 25076, '343 Industries': 23691, '34BigThings': 32837, '34BigThings srl': 29067, '38 Studios': 29326, '38,9_Degrees': 29941, '3909': 37537, '3acg': 39984, '3BD GAMES': 42172, '3Blackdot': 35500, '3D Avenue': 28225, '3D Clouds': 3002 ...

# %%
steam_dataset['Developers_id'] = steam_dataset['Developers'].map(get_company_result)
steam_dataset['Publishers_id'] = steam_dataset['Publishers'].map(get_company_result)
steam_dataset[['Developers', 'Developers_id', 'Publishers_id']]
# Out:
#                   Developers  Developers_id  Publishers_id
# 0      Perpetual FX Creative        30209.0        30209.0
# 1               Rusty Moyher        44055.0        40459.0
# 2                                  270013.0       270013.0
# 3          Odd Critter Games        23326.0        23326.0
# 4              Unusual Games        37859.0        37859.0
# ...                      ...            ...            ...
# 44613                              270013.0       270013.0
# 44614                              270013.0       270013.0
# 44615           Hentai Panda        25403.0        25403.0
# 44616                              270013.0       270013.0
# 44617        Ledx Fun Studio        36953.0        36953.0
#
# [89238 rows x 3 columns]

# %%
steam_dataset[(steam_dataset['Developers_id'].isna()) | (steam_dataset['Publishers_id'].isna())][['Developers', 'Developers_id', 'Publishers', 'Publishers_id']]
# Out:
#                  Developers  Developers_id                    Publishers  \
# 23           Falco Software            NaN
# 47         Ubisoft Montreal            NaN         Ubisoft Entertainment
# 57                 HH-Games        24170.0               e-FunSoft Games
# 108              Sonic Team        43693.0                          SEGA
# 137                 Creobit        25896.0                        8Floor
# ...                     ...            ...                           ...
# 44271     Valkeala software            NaN             Valkeala software
# 44279  Ryu Ga Gotoku Studio        26816.0                          SEGA
# 44328                   Egg            NaN                       Netflix
# 44442   TopWare Interactive            NaN  Attic Entertainment Software
# 44605        Exe Create Inc        43609.0                         KEMCO
#
#        Publishers_id
# 23          270013.0
# 47           24775.0
# 57               NaN
# 108              NaN
# 137              NaN
# ...              ...
# 44271            NaN
# 44279            NaN
# 44328        35101.0
# 44442        24960.0
# 44605            NaN
#
# [2336 rows x 4 columns]

# %%
game_dev_pub_batch_data = [] 

for _, row in steam_dataset.iterrows(): 
    game_dev_pub_batch_data.append( 
        (
            row['AppID'],  
            row['Developers_id'],  
            row['Publishers_id']
        )
    )  

game_dev_pub_batch_data

# %% [markdown]
# ### Game Languages

# %% [markdown]
# ### Game Categories

# %% [markdown]
# ### Game Genres

# %% [markdown]
# ### Game Tags

# %% [markdown]
# # Close Connections

# %%
cursor.close() 
mydb.close()
